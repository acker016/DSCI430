# %% [markdown]
# # Project 1 Part 2
#
#
# In this part of the project, you will create `dict`s to link the parcel/property data to the lakes data.  Then we will use `panda`’s to
#
# a. Read each parcel file
# b. Add a column containing the nearest lake
# c. Write the result to a new file.
#
# To accomplish this task, complete the following steps.

# %% [markdown]
# #### Problem 1
#
# Now we want to read in the file `mces_lakes_1999_2014.txt`, which contains water quality measurements for all lakes in the Twin Cities are during the listed years.
#
# Use `!head` to inspect the file and determine the details of it's format (header?, sep=?, etc.).

# %%
# !head ../MinneMUDACProject1/MinneMUDAC_raw_files/mces_lakes_1999_2014.txt
# Out:
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Anderson Pond	South St. Paul	Dakota	19009400-01	Mississippi
# 7105	Lakes Monitoring	Auburn Lake	Laketown Township	Carver	10004401-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	1986-07-14	10:39	1986-0
# 7105	Lakes Monitoring	Auburn Lake	Laketown Township	Carver	10004401-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	1994-04-18	9:15	1994-04-18	9:15	0			0-4 Categorical Calculated Seasonally: 4 good & 0 bad			1-5 Categorical: 1 good & 5 bad			1-5 Categorical: 1 goo
# 7105	Lakes Monitoring	Bald Eagle Lake	White Bear Township	Ramsey	62000200-01	Mississippi
# 7105	Lakes Monitoring	Crystal Lake	Burnsville	Dakota	19002700-01	Lower Minnesota River	Black Dog WMO	1	2012-12-03	14:50	2012-12-03	14:50	0				2	Approved		2	Approved			3.5	Approved	m				mg/L	-93.27036573	44.72296805d	m		0.028	Approved	mg/L	-93.27036573	44.72296805520835617777871066119.72101119199ical: 1 good & 5 bad		2.7	Approved	m		0.02	Approved	mg/L	-93.63778927	44.83812233	mg/L	-92.97144206	44.94461369-5 Categorical: 1 good & 5 bad		1.219	Approved	m				mg/L	-92.89930946	45.18460321d	1-5 Categorical: 1 good & 5 bad	4	Approved	1-5 Categorical: 1 good & 5 bad		1.3	Approved	m		0.05	Approved	mg/L	-92.91774882	45.165158481 good & 5 bad		2.286	Approved	m		0.041	Approved	mg/L	-92.91784653	45.097141821986-08-27	10:17	18			0-4 Categorical Calculated Seasonally: 4 good & 0 bad			1-5 Categorical: 1 good & 5 bad			1-5 Categorical: 1 good & 5 bad				m		0.47	Approved	mg/L	-93.63778927	44.83812233	mg/L	-93.63778927	44.83812233			2.5	Approved	m				mg/L	-93.63778927	44.83812233-06-11	0:00	2001-06-11	0:00	0				3	Approved		4	Approved			0.9	Approved	m		0.11	Approved	mg/L	-93.78461955	44.77483166 St. Croix River	Carnelian-Marine-St. Croix WD	1	1994-05-05	9:15	1994-05-05	9:15	0											3	Approved	m		0.03	Approved	mg/L	-92.80741591	45.13305739Approved	mg/L	-92.94889445	45.32234969	May Township	Washington	82005204-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2009-10-19	8:31	2009-10-19	8:31	0				1	Approved		1	Approved			4.572	Approved	m				mg/L	-92.86574543	45.208861886-28	19:00	2011-06-28	19:00	0				3	Approved		2	Approved			1.5	Approved	m		0.024	Approved	mg/L	-92.86026082	45.28659868ved	m		0.043	Approved	mg/L	-93.42816967	44.87666713urandt Lake	Waconia	Carver	10008400-01	Lower Minnesota River	Carver County WMO	1	2005-07-29	0:00	2005-07-29	0:00	0				2	Approved		2	Approved			1.1	Approved	m		0.058	Approved	mg/L	-93.80327077	44.84907904WD	1	2013-10-06	15:00	2013-10-06	15:00	0				2	Approved		2	Approved			3	Approved	m		0.015	Approved	mg/L	-93.38283992	44.83809461 Lake	Woodbury	Washington	82016600-01	Mississippi River - Twin Cities	Ramsey-Washington Metro WD	1	1995-06-09	11:40	1995-06-09	11:40	0											2.4	Approved	m		0.02	Approved	mg/L	-92.97989336	44.90598763/L	-93.52228564	44.5958207oved	mg/L	-93.30035632	45.14036824iver - Twin Cities	Minnehaha Creek WD	1	1985-07-11	12:23	1985-07-11	12:23	18													m		0.03	Approved	mg/L	-93.54437165	44.89464656	Lakes Monitoring	Clear Lake	Forest Lake Township	Washington	82016300-01	Mississippi River - Twin Cities	Rice Creek WD	1	1990-04-30	10:40	1990-04-30	10:40	0											1.3	Approved	m		0.045	Approved	mg/L	-93.00000905	45.26003767lley Branch WD	1	2002-10-17	0:00	2002-10-17	0:00	0				2	Approved		2	Approved			2.8	Approved	m		0.08	Approved	mg/L	-92.8523515	45.02040173Lakes	Cobblestone Lake	Apple Valley	Dakota	19045600-01	Mississippi River - Lake Pepin	Vermillion River Watershed JPO	1	2006-05-18	0:00	2006-05-18	0:00	0				2	Approved		2	Approved			0.8	Approved	m		0.058	Approved	mg/L	-93.16324515	44.72101119 River WMO	1	1997-07-22	11:15	1997-07-22	11:15	0											2.2	Approved	m		0.04	Approved	mg/L	-93.13714784	45.31767312for Lakes	Crooked Lake	Coon Rapids	Anoka	02008400-01	Mississippi River - Twin Cities	Coon Creek WD	1	1993-05-01	13:00	1993-05-01	13:00	0				3	Approved		2	Approved			1.1	Approved	m		0.03	Approved	mg/L	-93.34158462	45.20835617:00	1986-08-28	12:00	8													m		0.62	Approved	mg/L	-93.27036573	44.72296805573	44.72296805
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Halfbreed Lake	Forest Lake Township	Washington	82008000-01	Lower St. Croix River	Comfort Lake-Forest Lake WD	1
# 710
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Hay Lake
# 7108	Citizen Assisted Monitorin
# 7105	Lakes Monitoring	Holland Lake	Eagan	Dakota	19006500-01	Lower Minnesota River	Eagan-Inver Grove WMO	1	1984-08-17	11:10	1984-0
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Hornbean Lake	Sunfish Lake	Dakota	19004700-01	Mississippi River - Twin Cities	Lower
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Horseshoe Lake	Burnsville	D
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Hydes Lake	Waconia Township	Carver	10008800-01	Lower Minnesota River	Carver County WMO	1	2011-09-0
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Island Lake	Linwood Township	Anoka	02002200
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Markgraf Lake	Woodbury	Washington	82008900-01	Mississippi River - Twin Cities	South Washington WD	1	2009-10-04	14:00	2009-10-04	14:00	0				4	Approved		4	Approved			0.3	Approved	m		0.301	Approved	mg/L	-92.89723902	44.9404631445741127742878646636306807 Assisted Monitoring Program (CAMP) for Lakes	Jellums Lake	Scandia	Washington	82005202-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2001-10-16	12:15	2001-10-16	12:15	0				3	Approved		3	Approved			0.915	Approved	m		0.06	Approved	mg/L	-92.83363926	45.226539250021700-01	Lower Minnesota River	Carver County WMO	1	2002-06-11	8:21	2002-06-11	8:21	0				3	Approved		3	Approved			0.6	Approved	m		0.106	Approved	mg/L	-93.60631618	44.83232288.07400149proved		1	Approved			3	Approved	m		0.015	Approved	mg/L	-93.29915576	44.7070964725	15:25	0				3	Approved		2	Approved			1.524	Approved	m		0.125	Approved	mg/L	-92.8917326	45.09536417en Assisted Monitoring Program (CAMP) for Lakes	Kramer Pond	Lake Elmo	Washington	82011700-01	Lower St. Croix River	Valley Branch WD	1	2008-10-16	9:45	2008-10-16	9:45	0				4	Approved		4	Approved			0.152	Approved	m		0.472	Approved	mg/L	-92.89510948	44.95392659ippi River - Twin Cities	South Washington WD	1	2010-05-01	0:00	2010-09-30	0:00	0	2	Approved											m				mg/L	-92.9713984	44.88725237ake	Apple Valley	Dakota	19044600-01	Lower Minnesota River	Black Dog WMO	1	2008-07-28	16:30	2008-07-28	16:30	0				1	Approved		1	Approved			3.5	Approved	m		0.011	Approved	mg/L	-93.24520003	44.72061708Assisted Monitoring Program (CAMP) for Lakes	Laddie Lake	Spring Lake Park	Anoka	02007200-01	Mississippi River - Twin Cities	Coon Creek WD	1	2003-06-13	9:30	2003-06-13	9:30	0				3	Approved		4	Approved			1.2	Approved	m		0.017	Approved	mg/L	-93.24047	45.12336446esota River	Black Dog WMO	1	1996-05-01	0:00	1996-09-30	0:00	0	2	Approved											m				mg/L	-93.28746428	44.71229881746428	44.71229881-05-27	10:40	0				3	Approved						4.4	Approved	m		0.018	Approved	mg/L	-93.28746428	44.71229881		5	Approved			1.4	Approved	m		0.022	Approved	mg/L	-93.15743903	44.87293228CAMP) for Lakes	Levander Pond	South St. Paul	Dakota	19008800-01	Mississippi River - Twin Cities	Lower Mississippi River WMO	1	2011-07-26	11:00	2011-07-26	11:00	0				2	Approved		4	Approved			0.4	Approved	m		27	Suspect	mg/L	-93.06411512	44.90038921roix River	Middle St. Croix River WMO	1	2007-06-20	0:00	2007-06-20	0:00	0				3	Approved		2	Approved			1.067	Approved	m		0.069	Approved	mg/L	-92.82307526	45.04910509isted Monitoring Program (CAMP) for Lakes	Lily Lake	Stillwater	Washington	82002300-01	Lower St. Croix River	Middle St. Croix River WMO	1	2013-08-13	15:10	2013-08-13	15:10	0				2	Approved		4	Approved			1.67	Approved	m		0.034	Approved	mg/L	-92.82307526	45.04910509	82001400-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2000-07-05	13:40	2000-07-05	13:40	0				2	Approved		1	Approved			5.19	Approved	m		0.03	Approved	mg/L	-92.79566883	45.11864663r Lakes	Little Carnelian Lake	Stillwater Township	Washington	82001400-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2014-06-11	8:52	2014-06-11	8:52	0				2	Approved		1	Approved			6.1	Approved	m		0.034	Approved	mg/L	-92.79566883	45.11864663	Approved			2.4	Approved	m		0.017	Approved	mg/L	-92.93695344	45.31351351308	45.03504895in	27017901-01	South Fork Crow River	Pioneer-Sarah Creek WMC	1	2006-08-18	0:00	2006-08-18	0:00	0				1	Approved		2	Approved			3.5	Approved	m		0.023	Approved	mg/L	-93.7082121	44.94773927	Blaine	Anoka	02058500-01	Mississippi River - Twin Cities	Rice Creek WD	1	2011-05-31	7:10	2011-05-31	7:10	0				2	Approved		4	Approved			1.4	Approved	m		0.044	Approved	mg/L	-93.15409272	45.1725282517	14:10	1995-08-17	14:10	0				3	Approved		3	Approved			1.2	Approved	m		0.07	Approved	mg/L	-93.17364863	44.90275337m				mg/L	-93.17320832	44.7559202	m		0.14	Approved	mg/L	-93.17320832	44.7559202d			1.7	Approved	m		0.04	Approved	mg/L	-93.17320832	44.7559202		0.18	Approved	mg/L	-93.17320832	44.7559202Assisted Monitoring Program ...
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	M
# 7105	Lakes Monitoring	Martin Lake	Linwood
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Mays Lake	May Township	Washington	82003300-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	200
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Pike Lake	Maple Grove	Hennepin	27011102-01	Mississippi River - Twin Cities	Shingle Creek WMC	1	2000-10-02	0:00	2000-10-02	0:00	0				2	Approved		4	Approved			0.2	Approved	m		0.1	Approved	mg/L	-93.41943368	445.0664087111777944644.81579446642or Lakes	Mays Lake	May Township	Washington	82003300-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2010-09-26	9:30	2010-09-26	9:30	0				1	Approved		1	Approved			6.9	Approved	m		0.019	Approved	mg/L	-92.82044805	45.16809879ville	Ramsey	62005400-01	Mississippi River - Twin Cities	Capitol Region WD	1	1986-07-31	10:38	1986-07-31	10:38	16													m		0.79	Approved	mg/L	-93.11192702	44.99779486es Monitoring	McCarrons Lake	Roseville	Ramsey	62005400-01	Mississippi River - Twin Cities	Capitol Region WD	1	1990-08-20	11:30	1990-08-20	11:30	0											2.2	Approved	m		0.015	Approved	mg/L	-93.11192702	44.99779486ties	Capitol Region WD	1	1996-01-25	10:15	1996-01-25	10:15	10													m		0.16	Approved	mg/L	-93.11192702	44.99779486McCarrons Lake	Roseville	Ramsey	62005400-01	Mississippi River - Twin Cities	Capitol Region WD	1	1996-05-30	8:50	1996-05-30	8:50	12													m		0.18	Approved	mg/L	-93.11192702	44.99779486				m		0.32	Approved	mg/L	-93.11192702	44.99779486in Cities	Capitol Region WD	1	1996-10-16	8:30	1996-10-16	8:30	9													m		0.03	Approved	mg/L	-93.11192702	44.99779486roved	mg/L	-93.11192702	44.99779486s	Capitol Region WD	1	1999-07-08	8:15	1999-07-08	8:15	8													m		0.08	Approved	mg/L	-93.11192702	44.99779486McCarrons Lake	Roseville	Ramsey	62005400-01	Mississippi River - Twin Cities	Capitol Region WD	1	1999-09-27	8:15	1999-09-27	8:15	17													m		0.91	Approved	mg/L	-93.11192702	44.99779486							m		0.04	Approved	mg/L	-93.11192702	44.99779486River - Twin Cities	Capitol Region WD	1	2000-09-12	0:00	2000-09-12	0:00	0											2.2	Approved	m		0.03	Approved	mg/L	-93.11192702	44.997794868	0:00	2001-08-28	0:00	0											1.3	Approved	m	~	0.03	Approved	mg/L	-93.11192702	44.99779486oseville	Ramsey	62005400-01	Mississippi River - Twin Cities	Capitol Region WD	1	2002-05-28	0:00	2002-05-28	0:00	0											3.9	Approved	m	~	0.049	Approved	mg/L	-93.11192702	44.997794862-08-20	0:00	16													m		0.639	Approved	mg/L	-93.11192702	44.99779486seville	Ramsey	62005400-01	Mississippi River - Twin Cities	Capitol Region WD	1	2004-05-12	0:00	2004-05-12	0:00	16													m		0.409	Approved	mg/L	-93.11192702	44.99779486										m		0.786	Approved	mg/L	-93.11192702	44.99779486ississippi River - Twin Cities	Capitol Region WD	1	2005-05-03	0:00	2005-05-03	0:00	14.5													m		0.051	Approved	mg/L	-93.11192702	44.99779486alley Branch WD	1	2014-07-14	14:03	2014-07-14	14:03	0				3	Approved		3	Approved			2.44	Approved	m		0.066	Approved	mg/L	-92.84392332	45.01696278021600-01	Lower Minnesota River	Carver County WMO	1	2012-05-15	17:40	2012-05-15	17:40	0				3	Approved		3	Approved			0.55	Approved	m				mg/L	-93.60879364	44.83723777g Program (CAMP) for Lakes	McKusick Lake	Stillwater	Washington	82002000-01	Lower St. Croix River	Middle St. Croix River WMO	1	1996-10-01	10:00	1996-10-01	10:00	0				3	Approved		4	Approved			0.4	Approved	m		0.15	Approved	mg/L	-92.8257844	45.06082100	2001-06-12	0:00	0				2	Approved						2.59	Approved	m		0.74	Approved	mg/L	-92.8257844	45.06082182131CAMP) for Lakes	Meadow Lake	New Hope	Hennepin	27005700-01	Mississippi River - Twin Cities	Shingle Creek WMC	1	1999-05-01	0:00	1999-09-30	0:00	0	0	Approved											m				mg/L	-93.38771952	45.06125669-08-05	9:00	0				3	Approved		2	Approved			0.7	Approved	m		0.053	Approved	mg/L	-93.4232217	44.9994387en Assisted Monitoring Program (CAMP) for Lakes	Miller Lake	Dahlgren Township	Carver	10002900-01	Lower Minnesota River	Carver County WMO	1	2003-08-06	10:30	2003-08-06	10:30	0				4	Approved		4	Approved			0.3	Approved	m		0.209	Approved	mg/L	-93.74305702	44.78713912epin	27008800-01	Lower Minnesota River	Nine Mile Creek WD	1	2008-10-19	9:00	2008-10-19	9:00	0				2	Approved						1.7	App ...
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Schutz Lake	Victoria	Carver	10001800-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	2005-09-10	0:00	2005-08-28	0:00	0				3	Approved		1	Approved			2.2	Approved	m		0.03	Approved	mg/L	-93.64575912	44.876760855854	45.14368468647884e	Hennepin	27011102-01	Mississippi River - Twin Cities	Shingle Creek WMC	1	2002-04-23	0:00	2002-04-23	0:00	0				2	Approved		4	Approved			0.6	Approved	m		0.066	Approved	mg/L	-93.41943368	45.06640871am (CAMP) for Lakes	Pike Lake	Maple Grove	Hennepin	27011102-01	Mississippi River - Twin Cities	Shingle Creek WMC	1	2002-07-15	0:00	2002-07-15	0:00	0				2	Approved		2	Approved			0.8	Approved	m		0.085	Approved	mg/L	-93.41943368	45.066408710.083	Approved	mg/L	-93.41943368	45.066408715-26	0:00	2003-05-26	0:00	0				2	Approved		2	Approved			2	Approved	m		0.064	Approved	mg/L	-93.41943368	45.0664087168	45.06640871Lakes	Pine Tree Lake	Grant	Washington	82012200-01	Mississippi River - Twin Cities	Rice Creek WD	1	2002-07-21	0:00	2002-07-21	0:00	0				2	Approved		1	Approved			1.6	Approved	m	~	0.025	Approved	mg/L	-92.95386928	45.1023135908	Citizen Assisted Monitoring Program (CAMP) for Lakes	Plaisted Lake	Hugo	Washington	82014800-01	Lower St. Croix River	Browns Creek WD	1	2011-05-25	8:22	2011-05-25	8:22	0				2	Approved		2	Approved			2.59	Approved	m		0.051	Approved	mg/L	-92.91253316	45.15178288 Cities	South Washington WD	1	1995-06-23	15:00	1995-06-23	15:00	0				2	Approved		4	Approved			2.8	Approved	m		0.01	Approved	mg/L	-92.89985034	44.92635622	-92.89985034	44.926356220-01	Mississippi River - Twin Cities	South Washington WD	1	1997-07-04	7:30	1997-07-04	7:30	0				1	Approved		1	Approved			1.5	Approved	m		0.01	Approved	mg/L	-92.89985034	44.92635622m		0.03	Approved	mg/L	-92.89985034	44.9263562209200-01	Mississippi River - Twin Cities	South Washington WD	1	2000-05-01	0:00	2000-09-30	0:00	0	3	Approved											m				mg/L	-92.89985034	44.92635622tizen Assisted Monitoring Program (CAMP) for Lakes	Powers Lake	Woodbury	Washington	82009200-01	Mississippi River - Twin Cities	South Washington WD	1	2002-06-16	20:02	2002-06-16	20:02	0				2	Approved		2	Approved			2.6	Approved	m		0.023	Approved	mg/L	-92.89985034	44.92635622- Twin Cities	South Washington WD	1	2003-07-08	9:50	2003-07-08	9:50	0				3	Approved		4	Approved			1.373	Approved	m		0.032	Approved	mg/L	-92.89985034	44.92635622ed			1.829	Approved	m		0.033	Approved	mg/L	-92.89985034	44.9263562226	10													m		0.595	Approved	mg/L	-92.89985034	44.92635622oved	mg/L	-92.89985034	44.92635622	10:54	0				2	Approved		2	Approved			4.41	Approved	m		0.024	Approved	mg/L	-92.89985034	44.926356227577765	44.68670995	0:00	2004-04-26	0:00	5													m		0.034	Approved	mg/L	-93.47638386	44.84796469 River - Twin Cities	South Washington WD	1	2006-06-23	10:06	2006-06-23	10:06	0				4	Approved		5	Approved			0.914	Approved	m		0.15	Approved	mg/L	-92.90248396	44.80553214	1993-07-06	10:30	0											0.7	Approved	m		0.14	Approved	mg/L	-93.74452179	44.83862568											1.1	Approved	m		0.27	Approved	mg/L	-93.74452179	44.83862568ing Program (CAMP) for Lakes	Reitz Lake	Laketown Township	Carver	10005200-01	Lower Minnesota River	Carver County WMO	1	2000-05-01	0:00	2000-09-30	0:00	0	2	Approved											m				mg/L	-93.74452179	44.83862568y WMO	1	2005-05-09	0:00	2005-05-09	0:00	11													m		0.453	Approved	mg/L	-93.74452179	44.8386256808-15	0:00	2005-08-15	0:00	0											1.3	Approved	m		0.1	Approved	mg/L	-93.74452179	44.83862568er	Carver County WMO	1	2006-05-30	0:00	2006-05-30	0:00	0				3	Approved		2	Approved			2.9	Approved	m		0.149	Approved	mg/L	-93.74452179	44.83862568nnesota River	Carver County WMO	1	2007-06-02	0:00	2007-06-02	0:00	0				2	Approved		2	Approved			2	Approved	m		0.032	Approved	mg/L	-93.74452179	44.83862568nship	Carver	10005200-01	Lower Minnesota River	Carver County WMO	1	2008-06-23	15:00	2008-06-23	15:00	0				4	Approved		2	Approved			1.8	Approved	m		0.052	Approved	mg/L	-93.74452179	44.83862568	Laketown Township	Carver	10005200-01	L ...
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Staples Lake	May Township	Washington	82002800-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2007-06-25	10:49	2007-06-25	10:49	0				2	Approved		4	Approved			2.896	Approved	m		0.018	Approved	mg/L	-92.8547918	45.183940568825842333CAMP) for Lakes	Scout Lake	Apple Valley	Dakota	19019800-01	Lower Minnesota River	Vermillion River Watershed JPO	1	2008-08-23	16:45	2008-08-23	16:45	0				3	Approved						0.5	Approved	m		0.066	Approved	mg/L	-93.21534043	44.773007) for Lakes	Scout Lake	Apple Valley	Dakota	19019800-01	Lower Minnesota River	Vermillion River Watershed JPO	1	2009-08-23	18:00	2009-08-23	18:00	0				2	Approved						0.8	Approved	m		0.052	Approved	mg/L	-93.21534043	44.773007ton	82005300-01	Lower St. Croix River	Comfort Lake-Forest Lake WD	1	2009-09-01	18:30	2009-09-01	18:30	0				3	Approved		4	Approved			0.5	Approved	m		0.131	Approved	mg/L	-92.83761977	45.29143691Basin Adj to Valley Lake	Lakeville	Dakota	99002487-01	Mississippi River - Lake Pepin	Vermillion River Watershed JPO	1	2004-09-13	0:00	2004-09-13	0:00	0				3	Approved		2	Approved					m		0.064	Approved	mg/L	-93.21131568	44.715579562005-08-02	0:00	2005-08-02	0:00	0				4	Approved		4	Approved			0.76	Approved	m		0.058	Approved	mg/L	-93.05329582	44.88348937a	19009500-01	Mississippi River - Twin Cities	Lower Mississippi River WMO	1	2006-07-26	0:00	2006-07-26	0:00	0				4	Approved		4	Approved			0.46	Approved	m		0.368	Approved	mg/L	-93.05329582	44.88348937485894	45.25287409Washington	82016200-01	Lower St. Croix River	Comfort Lake-Forest Lake WD	1	1994-10-20	11:25	1994-10-20	11:25	0				2	Approved		1	Approved			2.3	Approved	m		0.23	Approved	mg/L	-92.94485894	45.2528740995-10-02	10:30	0				2	Approved		2	Approved			1.7	Approved	m		0.23	Approved	mg/L	-92.94485894	45.25287409	45.25287409	Washington	82016200-01	Lower St. Croix River	Comfort Lake-Forest Lake WD	1	1997-10-17	11:45	1997-10-17	11:45	0				2	Approved		2	Approved			3.7	Approved	m		0.27	Approved	mg/L	-92.94485894	45.25287409998-09-28	10:00	0				2	Approved		2	Approved			2	Approved	m		0.2	Approved	mg/L	-92.94485894	45.2528740945.2528740982016200-01	Lower St. Croix River	Comfort Lake-Forest Lake WD	1	2000-09-28	0:00	2000-09-28	0:00	0				3	Approved		4	Approved			3.36	Approved	m		0.19	Approved	mg/L	-92.94485894	45.252874090	0				3	Approved		4	Approved			1.34	Approved	m		0.22	Approved	mg/L	-92.94485894	45.25287409Citizen Assisted Monitoring Program (CAMP) for Lakes	Shields Lake	Forest Lake	Washington	82016200-01	Lower St. Croix River	Comfort Lake-Forest Lake WD	1	2002-09-18	0:00	2002-09-18	0:00	0				4	Approved		4	Approved			0.61	Approved	m		0.265	Approved	mg/L	-92.94485894	45.25287409ke	Forest Lake	Washington	82016200-01	Lower St. Croix River	Comfort Lake-Forest Lake WD	1	2003-08-21	0:00	2003-08-21	0:00	0				4	Approved		4	Approved			0.763	Approved	m		0.377	Approved	mg/L	-92.94485894	45.252874090	0											0.762	Approved	m		0.23	Approved	mg/L	-92.94485894	45.25287409n Assisted Monitoring Program (CAMP) for Lakes	Shields Lake	Forest Lake	Washington	82016200-01	Lower St. Croix River	Comfort Lake-Forest Lake WD	1	2005-08-02	0:00	2005-08-02	0:00	0				3	Approved		4	Approved			0.457	Approved	m		0.357	Approved	mg/L	-92.94485894	45.25287409Lake WD	1	2006-06-28	7:52	2006-07-06	7:52	0				5	Approved		4	Approved			0.457	Approved	m		0.318	Approved	mg/L	-92.94485894	45.25287409River	Valley Branch WD	1	2006-04-23	0:00	2006-04-23	0:00	0				1	Approved		1	Approved			3	Approved	m		0.017	Approved	mg/L	-92.98615998	45.02818484kes	Simley Lake	Inver Grove Heights	Dakota	19003700-01	Mississippi River - Twin Cities	Lower Mississippi River WMO	1	2013-06-14	11:50	2013-06-14	11:50	0				1	Approved		1	Approved			2.3	Approved	m		0.029	Approved	mg/L	-93.04268875	44.83258423166	45.00574348issippi River - Twin Cities	Bassett Creek WMC	1	2006-10-20	0:00	2006-10-20	0:00	0				2	Approved		4	Approved			1	Approved	m		0.088	Approved	mg/L	-93.33291166	45.00574348	Approved		3	Approved			1	Approved	m		0.198	Approv ...
# 7105	Lakes Monitoring	Staring Lake	Eden Prairie	Hennepin	27007800-01	Lower Minnesota River	Riley-Purgatory-Bluff Creek WD	1	1985-06-05	12:10	1985-06-05	12:10	4													m		0.06	Approved	mg/L	-93.4538712
# 7105	Lakes Monitoring	Stieger Lake	Victoria	Carver	10004500-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	1989-10-11	10:15	1989-10-11	10:15	0											2	Approved	m		0.04	Approved	mg/L	-93.6566799	4
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Success Lake	Brooklyn Park	Hennepin	27063400-01	Mississippi River - Twin Cities	Shingle Creek WMC	1	2011-05-01	0:00	2011-09-30	0:00	0	1	Approved											m				mg/L	-93.32
# 7108	Citizen Assist
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Twin Lake	Brooklyn Center	Hennepin	27004201-01	Mississippi River - Twin Cities	Shingle Creek WMC	1	2011-05-30	16:00	2011-05-30	16:00	0				2	Approved		4	Approved			0.6	Approved	m		0.048	Approved	mg/L	-93.33618999	45.0507763222412695	m				mg/L	-93.09818273	44.8758072610700-01	Lower St. Croix River	Valley Branch WD	1	2005-05-01	0:00	2005-09-30	0:00	0	1	Approved											m				mg/L	-92.89160242	44.99924011ved	m		0.378	Approved	mg/L	-92.89160242	44.9992401101	Lower St. Croix River	Valley Branch WD	1	2006-08-16	0:00	2006-08-16	0:00	0				3	Approved		1	Approved			0.7	Approved	m		0.04	Approved	mg/L	-92.89160242	44.99924011	Approved			1.5	Approved	m		0.023	Approved	mg/L	-92.89160242	44.999240116	Approved	mg/L	-92.89160242	44.99924011ed		1	Approved			3	Approved	m		0.03	Approved	mg/L	-92.89160242	44.99924011roved		1	Approved			5	Approved	m		0.03	Approved	mg/L	-92.89160242	44.99924011akes	Sunfish Lake	Lake Elmo	Washington	82010700-01	Lower St. Croix River	Valley Branch WD	1	2011-07-29	9:30	2011-07-29	9:30	0				2	Approved		2	Approved			4	Approved	m		0.025	Approved	mg/L	-92.89160242	44.999240114.99924011ng Program (CAMP) for Lakes	Sunnybrook Lake	Grant	Washington	82013300-01	Lower St. Croix River	Valley Branch WD	1	2004-08-16	0:00	2004-08-16	0:00	0				2	Approved		1	Approved			0.3	Approved	m		0.019	Approved	mg/L	-92.91073482	45.050492268-03	10:30	0				2	Approved		2	Approved			1.9	Approved	m		0.021	Approved	mg/L	-92.91073482	45.05049226	Lakes Monitoring	Sunset Lake	Hugo	Washington	82015300-01	Mississippi River - Twin Cities	Rice Creek WD	1	1984-08-13	11:31	1984-08-13	11:31	0											0.9	Approved	m		0.09	Approved	mg/L	-92.94157024	45.13527125pproved	mg/L	-92.94157024	45.13527125- Twin Cities	Rice Creek WD	1	2000-06-18	0:00	2000-06-18	0:00	0				2	Approved		2	Approved			3.6	Approved	m		0.03	Approved	mg/L	-92.94157024	45.13527125Creek WD	1	2003-05-24	0:00	2003-05-24	0:00	0				2	Approved		1	Approved			4.5	Approved	m		0.022	Approved	mg/L	-92.94157024	45.13527125Assisted Monitoring Program (CAMP) for Lakes	Sunset Lake	Hugo	Washington	82015300-01	Mississippi River - Twin Cities	Rice Creek WD	1	2005-05-23	0:00	2005-05-23	0:00	0				2	Approved		2	Approved			4	Approved	m		0.011	Approved	mg/L	-92.94157024	45.13527125roved		3	Approved			3.5	Approved	m		0.011	Approved	mg/L	-92.94157024	45.13527125shington	82015300-01	Mississippi River - Twin Cities	Rice Creek WD	1	2014-09-21	18:20	2014-09-21	18:20	0				2	Approved		1	Approved			2.6	Approved	m		0.013	Approved	mg/L	-92.94157024	45.13527125	Approved	mg/L	-93.32441925	44.75482629ille	Dakota	19045100-01	Lower Minnesota River	Black Dog WMO	1	1997-08-02	20:00	1997-08-02	20:00	0				3	Approved		4	Approved			2.1	Approved	m		0.04	Approved	mg/L	-93.32441925	44.75482629	3	Approved			2.1	Approved	m		0.05	Approved	mg/L	-93.32441925	44.754826292441925	44.75482629	-93.32441925	44.75482629oved	mg/L	-93.32441925	44.754826294.7548262945100-01	Lower Minnesota River	Black Dog WMO	1	2007-05-01	0:00	2007-09-30	0:00	0	3	Approved											m				mg/L	-93.32441925	44.75482629L	-93.32441925	44.75482629100-01	Lower Minnesota River	Black Dog WMO	1	2009-05-17	8:08	2009-05-17	8:08	0				3	Approved		4	Approved			2.1	Approved	m		0.061	Approved	mg/L	-93.32441925	44.75482629urgatory-Bluff Creek WD	1	2010-05-01	0:00	2010-09-30	0:00	0	2	Approved											m				mg/L	-93.54157073	44.85197945	0.7	Approved	m		0.092	Approved	mg/L	-93.54157073	44.85197945/L	-93.8182476	44.930824River	Carver County WMO	1	2008-07-27	14:00	2008-07-27	14:00	0				4	Approved		4	Approved			0.25	Approved	m		0.328	Approved	mg/L	-93.8182476	44.930824	2009-07-09	15:00	2009-07-09	15:00	0				4	Approved		4	Approved			0.2	Approved	m		0.395	Approved	mg/L	-93.8182476	44.930824			0.4	Approved	m		0.266	Approved	mg/L	-93.8182476	44.930824own Township	Carver	10009500-01	South Fork Crow River	Carver County WMO	1	2013-07-22	20:00	2013-07-22	20:00	0				3	Approved		4	Approved			0.8	Approved	m		0.322	Approved	mg/L	-93.8182476	44.9308240	 ...
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Wilmes Lake	Woodbury	Washington	82009002-01	Mississippi River - Twin Cities	South Washington WD	1	2008-05-30	5:00	2008-05-30	5:00	0				2	Approved		2	Approved			1	Approved	m		0.092	Approved	mg/L	-92.91260488	44.92794439443982571144.963396955issippi River - Twin Cities	Shingle Creek WMC	1	2012-10-21	18:00	2012-10-21	18:00	0													m		0.035	Approved	mg/L	-93.33618999	45.05077632ake	Scott	70007200-01	Lower Minnesota River	Prior Lake-Spring Lake WD	1	1990-08-07	11:00	1990-08-07	11:00	5													m		0.04	Approved	mg/L	-93.44208405	44.71536216 Lake	Prior Lake	Scott	70007200-01	Lower Minnesota River	Prior Lake-Spring Lake WD	1	1997-06-13	17:30	1997-06-13	17:30	0				1	Approved		1	Approved			1.7	Approved	m		0.02	Approved	mg/L	-93.44208405	44.71536216Minnesota River	Prior Lake-Spring Lake WD	1	2003-09-14	16:00	2003-09-14	16:00	0				4	Approved		3	Approved			0.6	Approved	m				mg/L	-93.44208405	44.71536216iver	Prior Lake-Spring Lake WD	1	2008-07-23	10:10	2008-07-23	10:10	0				2	Approved		2	Approved			1	Approved	m		0.051	Approved	mg/L	-93.44208405	44.71536216t	70007200-01	Lower Minnesota River	Prior Lake-Spring Lake WD	1	2009-06-24	9:20	2009-06-24	9:20	0				2	Approved		2	Approved			3	Approved	m		0.023	Approved	mg/L	-93.44208405	44.71536216ice Creek WD	1	2001-10-27	17:30	2001-10-27	17:30	0				2	Approved		2	Approved			2.85	Approved	m		0.06	Approved	mg/L	-93.16496542	45.0582411396-06-03	19:00	1996-06-03	19:00	0				2	Approved		2	Approved			1.1	Approved	m		0.05	Approved	mg/L	-93.20902364	44.71508954-19	13:00	0				1	Approved		1	Approved			1.5	Approved	m		0.04	Approved	mg/L	-93.20902364	44.715089546	Approved	m				mg/L	-93.20902364	44.71508954MP) for Lakes	Valley Lake	Lakeville	Dakota	19034800-01	Mississippi River - Lake Pepin	Vermillion River Watershed JPO	1	2000-08-31	0:00	2000-08-31	0:00	0				2	Approved		1	Approved			1.5	Approved	m		0.05	Approved	mg/L	-93.20902364	44.71508954ssippi River - Lake Pepin	Vermillion River Watershed JPO	1	2008-05-01	0:00	2008-09-30	0:00	0	2	Approved											m				mg/L	-93.20902364	44.71508954	mg/L	-93.20902364	44.715089547-24	0:00	0				4	Approved		3	Approved			0.91	Approved	m		0.086	Approved	mg/L	-93.63573281	44.88296987ro WD	1	1989-09-05	8:20	1989-09-05	8:20	18													m		0.21	Approved	mg/L	-93.11664324	45.04514307proved		2	Approved			3.5	Approved	m		0.01	Approved	mg/L	-93.77585994	44.87281942r Minnesota River	Carver County WMO	1	2000-07-31	0:00	2000-07-31	0:00	0				2	Approved		2	Approved			1.8	Approved	m		0.03	Approved	mg/L	-93.77585994	44.87281942ver	10005900-01	Lower Minnesota River	Carver County WMO	1	2003-04-29	0:00	2003-04-29	0:00	0				1	Approved		1	Approved			3.3	Approved	m		0.024	Approved	mg/L	-93.77585994	44.87281942	2008-09-02	8:46	2008-09-02	8:46	0				3	Approved		3	Approved			1	Approved	m				mg/L	-93.77585994	44.8728194205	0				2	Approved		2	Approved			2	Approved	m				mg/L	-93.77585994	44.87281942Cities	Minnehaha Creek WD	1	1986-09-09	9:33	1986-09-09	9:33	12													m		0.43	Approved	mg/L	-93.67353937	44.84145448448ties	Minnehaha Creek WD	1	1987-04-29	11:00	1987-04-29	11:00	8													m		0.11	Approved	mg/L	-93.67353937	44.84145448ing	Wasserman Lake	Victoria	Carver	10004800-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	1987-07-06	10:45	1987-07-06	10:45	0											1.1	Approved	m		0.03	Approved	mg/L	-93.67353937	44.84145448-01	10:30	1987-09-01	10:30	7													m		0.06	Approved	mg/L	-93.67353937	44.84145448man Lake	Victoria	Carver	10004800-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	1994-05-02	10:00	1994-05-02	10:00	6													m		0.08	Approved	mg/L	-93.67353937	44.841454487-25	9:50	8													m		0.34	Approved	mg/L	-93.67353937	44.841454481	Mississippi River - Twin Cities	Minnehaha Creek WD	1	1997-05-14	10:15	1997-05-14	10:15	0											0.8	Approved	m		0.09	Approved	mg/L	-93.67353937	44.84145448				0.5	Approved	m		0.08	Approved	mg/L	-93.67353937	44.84145448ake	Victoria	Carver	10004800-01	Mississippi River ...
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Wilmes Lake	Woodbury	Washington	82009002-01	Mississippi River - Twin Cities	South Wa
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Windsor Lake	Minn
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Wing Lake	Minnetonka	Hennepin	27009100-01	Lower Minnesota River	Nine Mile Cr
# 7108	Citizen Assisted M
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Winkler Lake	Benton Town
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Winkler Lake	Benton Township	Carver	10006600
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Wood Lake	Burnsville	Dakota	19002400-01	Lower Minnesota River	Black Dog WMO	1
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Wood Lake	Burnsville	Dakota	19002400-01	Lower Minnesota River	Black Dog WMO	1	1999-08-05	9:30
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Wood Lake	Burnsville	Dakota	19002400-01	Lower Minnesota River	Black Dog WMO	1	2002-05-29	12:10	2002-05-29	12:10	0				2	Approved		2	Approved			2.8	Approved	m	~	0.036	Approved	mg/L	-93.2658604	44.7
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Wood Lake	Burnsville	Dakota	19002400-01	Lower Minnesota Ri
# 7105	Lakes Monitoring	Zumbra Lake	Victoria	Carver	10004100-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	2002-10-14	0:00	2002-10-14	0:00	7													m	~	0.012	Approved	mg/L	-93.66768906	44.88381717.88381717177d			0.9	Approved	m		0.08	Approved	mg/L	-93.90614956	44.783110270	2	Approved											m				mg/L	-93.2658604	44.74111827	Wood Lake	Burnsville	Dakota	19002400-01	Lower Minnesota River	Black Dog WMO	1	2012-06-26	17:30	2012-06-26	17:30	0				3	Approved		2	Approved			1	Approved	m		0.073	Approved	mg/L	-93.2658604	44.74111827onitoring Program (CAMP) for Lakes	Woodpile Lake	Grant Township	Washington	82013200-01	Lower St. Croix River	Browns Creek WD	1	2008-09-23	9:54	2008-09-23	9:54	0				3	Approved		4	Approved			1.524	Approved	m		0.04	Approved	mg/L	-92.90332792	45.06868739ing Program (CAMP) for Lakes	Woodpile Lake	Grant Township	Washington	82013200-01	Lower St. Croix River	Browns Creek WD	1	2010-05-26	11:45	2010-05-26	11:45	0				3	Approved		3	Approved			4.57	Approved	m		0.025	Approved	mg/L	-92.90332792	45.0686873917

# %% [markdown]
# #### Problem 2
#
# Sometimes the easiest way to deal with a problematic file is to open it in JMP or Excel then save it using that program.  Use JMP to read in `mces_lakes_1999_2014.txt` and export/save it as a csv file.
#
# 1. On a Mac, you will select **File > Export > Text File**.  The default setting are fine here, just change the file extension from `dat` to `csv` to clearly communicate the format.
# 2. On a PC, you will select **File > Save As** and change the output type to csv.
#
# Now read this new version of the file using `pandas`. **Make sure you read the `latitude` and `longitude` columns as string!**

# %%
import pandas as pd
mces_lakes_iter = pd.read_csv('../MinneMUDACProject1/MinneMUDAC_raw_files/mces_lakes_1999_2014.csv')
mces_lakes_iter.dtypes
# Out:
# /home/fs5518xn/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (16,19,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# PROJECT_ID                              int64
# DATA_SET_TITLE                         object
# LAKE_NAME                              object
# CITY                                   object
# COUNTY                                 object
# DNR_ID_Site_Number                     object
# MAJOR_WATERSHED                        object
# WATER_PLANNING_AUTHORITY               object
# LAKE_SITE_NUMBER                        int64
# START_DATE                             object
# START_HOURMIN24                        object
# END_DATE                               object
# END_HOURMIN24                          object
# SAMPLE_DEPTH_IN_METERS                float64
# Seasonal_Lake_Grade_RESULT            float64
# Seasonal_Lake_Grade_QUALIFIER          object
# Seasonal_Lake_Grade_Units              object
# Physical_Condition_RESULT             float64
# Physical_Condition_QUALIFIER           object
# Physical_Condition_Units               object
# Recreational_Suitability_RESULT       float64
# Recreational_Suitability_QUALIFIER     object
# Recreational_Suitability_Units         object
# Secchi_Depth_RESULT_SIGN               object
# Secchi_Depth_RESULT                   float64
# Secchi_Depth_QUALIFIER                 object
# Secchi_Depth_Units                     object
# Total_Phosphorus_RESULT_SIGN           object
# Total_Phosphorus_RESULT               float64
# Total_Phosphorus_QUALIFIER             object
# Total_Phosphorus_Units                 object
# longitude                             float64
# latitude                              float64
# dtype: object

# %%
date_cols = ['START_DATE','END_DATE']
from toolz import first
mces_lakes_iter = pd.read_csv('../MinneMUDACProject1/MinneMUDAC_raw_files/mces_lakes_1999_2014.csv',
                     parse_dates=date_cols)
mces_lakes_iter.longitude = round(mces_lakes_iter.longitude, 5)
mces_lakes_iter.latitude = round(mces_lakes_iter.latitude, 5)
mces_lakes_iter.head()
# Out:
# /home/fs5518xn/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (16,19,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    PROJECT_ID                                     DATA_SET_TITLE   LAKE_NAME  \
# 0        7108  Citizen Assisted Monitoring Program (CAMP) for...  Acorn Lake
# 1        7108  Citizen Assisted Monitoring Program (CAMP) for...  Acorn Lake
# 2        7108  Citizen Assisted Monitoring Program (CAMP) for...  Acorn Lake
# 3        7108  Citizen Assisted Monitoring Program (CAMP) for...  Acorn Lake
# 4        7108  Citizen Assisted Monitoring Program (CAMP) for...  Acorn Lake
#
#       CITY      COUNTY DNR_ID_Site_Number        MAJOR_WATERSHED  \
# 0  Oakdale  Washington        82010200-01  Lower St. Croix River
# 1  Oakdale  Washington        82010200-01  Lower St. Croix River
# 2  Oakdale  Washington        82010200-01  Lower St. Croix River
# 3  Oakdale  Washington        82010200-01  Lower St. Croix River
# 4  Oakdale  Washington        82010200-01  Lower St. Croix River
#
#   WATER_PLANNING_AUTHORITY  LAKE_SITE_NUMBER START_DATE  ...  \
# 0         Valley Branch WD                 1 2006-04-16  ...
# 1         Valley Branch WD                 1 2006-05-01  ...
# 2         Valley Branch WD                 1 2006-05-02  ...
# 3         Valley Branch WD                 1 2006-05-16  ...
# 4         Valley Branch WD                 1 2006-05-30  ...
#
#   Secchi_Depth_RESULT_SIGN Secchi_Depth_RESULT Secchi_Depth_QUALIFIER  \
# 0                      NaN                1.00               Approved
# 1                      NaN                 NaN                    NaN
# 2                      NaN                0.66               Approved
# 3                      NaN                0.66               Approved
# 4                      NaN                0.50               Approved
#
#    Secchi_Depth_Units  Total_Phosphorus_RESULT_SIGN Total_Phosphorus_RESULT  \
# 0                   m                           NaN                   0.156
# 1                   m                           NaN                     NaN
# 2                   m                           NaN                   0.107
# 3                   m                           NaN                   0.141
# 4                   m                           NaN                   0.029
#
#   Total_Phosphorus_QUALIFIER  Total_Phosphorus_Units longitude  latitude
# 0                   Approved                    mg/L -92.97171  45.01656
# 1                        NaN                    mg/L -92.97171  45.01656
# 2                   Approved                    mg/L -92.97171  45.01656
# 3                   Approved                    mg/L -92.97171  45.01656
# 4                   Approved                    mg/L -92.97171  45.01656
#
# [5 rows x 33 columns]

# %%
mces_lakes_iter.longitude = mces_lakes_iter.longitude.astype(str)
mces_lakes_iter.latitude = mces_lakes_iter.latitude.astype(str)
mces_lakes_iter.dtypes
# Out:
# PROJECT_ID                                     int64
# DATA_SET_TITLE                                object
# LAKE_NAME                                     object
# CITY                                          object
# COUNTY                                        object
# DNR_ID_Site_Number                            object
# MAJOR_WATERSHED                               object
# WATER_PLANNING_AUTHORITY                      object
# LAKE_SITE_NUMBER                               int64
# START_DATE                            datetime64[ns]
# START_HOURMIN24                               object
# END_DATE                              datetime64[ns]
# END_HOURMIN24                                 object
# SAMPLE_DEPTH_IN_METERS                       float64
# Seasonal_Lake_Grade_RESULT                   float64
# Seasonal_Lake_Grade_QUALIFIER                 object
# Seasonal_Lake_Grade_Units                     object
# Physical_Condition_RESULT                    float64
# Physical_Condition_QUALIFIER                  object
# Physical_Condition_Units                      object
# Recreational_Suitability_RESULT              float64
# Recreational_Suitability_QUALIFIER            object
# Recreational_Suitability_Units                object
# Secchi_Depth_RESULT_SIGN                      object
# Secchi_Depth_RESULT                          float64
# Secchi_Depth_QUALIFIER                        object
# Secchi_Depth_Units                            object
# Total_Phosphorus_RESULT_SIGN                  object
# Total_Phosphorus_RESULT                      float64
# Total_Phosphorus_QUALIFIER                    object
# Total_Phosphorus_Units                        object
# longitude                                     object
# latitude                                      object
# dtype: object

# %% [markdown]
# #### Problem 3
#
# Now we want to read in the file `Parcel_Lake_Monitoring_Site_Xref.txt`, which is as cross-reference (Xref) file that is used to make the bridge between the parcel data and the lakes data.
#
# 1. Use `!head` to inspect the file and determine the details of it's format (header?, sep=?, etc.).
# 2. Read the file using `pandas`.

# %%
# !head ../MinneMUDACProject1/MinneMUDAC_raw_files/Parcel_Lake_Monitoring_Site_Xref.txt
# Out:
# Parcel_PIN	Monit_MAP_CODE1	Monit_SITE_CODE	Monit_LAKE_SITE	Distance_Parcel_Monitoring_Site_meters	Lake_Hydroid	Distance_Parcel_Lake_meters	centroid_long	centroid_lat	Parcel_pkey
# 	19007900-01	19007900	1	2815.4927104148851	110517277058	2571.5267922258381	-93.11451	44.94283	2163034
# 	19007900-01	19007900	1	2753.4746875312162	110517277058	2515.3738022144425	-93.11539	44.94234	2163035
# 	19007900-01	19007900	1	2748.8106650822624	110517277058	2511.9249588634261	-93.11556	44.94231	2163036
# 	19007900-01	19007900	1	2738.7500558227048	110517277058	2502.9916401143814	-93.11572	44.94223	2163037
# 	19007900-01	19007900	1	2700.5414124735426	110517277058	2465.2062339003005	-93.1158	44.94189	2163038
# 	19007900-01	19007900	1	2890.2197211400312	110517277058	2631.4612562849106	-93.11218	44.94325	2163039
# 	19007900-01	19007900	1	3338.9566080000855	110517277058	3074.8658002505599	-93.11036	44.94711	2163040
# 	19007900-01	19007900	1	3338.129273460172	110517277058	3074.6709497432862	-93.11048	44.94712	2163041
# 	19007900-01	19007900	1	3304.2646291849906	110517277058	3040.0914556198632	-93.11042	44.9468	2163042

# %%
xref_iter = pd.read_csv('../MinneMUDACProject1/MinneMUDAC_raw_files/Parcel_Lake_Monitoring_Site_Xref.txt',
                      header =0, sep= '\t')
xref_iter.centroid_lat = round(xref_iter.centroid_lat, 5)
xref_iter.centroid_long = round(xref_iter.centroid_long, 5)
xref_iter.head()
# Out:
#    Parcel_PIN Monit_MAP_CODE1  Monit_SITE_CODE  Monit_LAKE_SITE  \
# 0         NaN     19007900-01         19007900                1
# 1         NaN     19007900-01         19007900                1
# 2         NaN     19007900-01         19007900                1
# 3         NaN     19007900-01         19007900                1
# 4         NaN     19007900-01         19007900                1
#
#    Distance_Parcel_Monitoring_Site_meters  Lake_Hydroid  \
# 0                             2815.492710  110517277058
# 1                             2753.474688  110517277058
# 2                             2748.810665  110517277058
# 3                             2738.750056  110517277058
# 4                             2700.541412  110517277058
#
#    Distance_Parcel_Lake_meters  centroid_long  centroid_lat  Parcel_pkey
# 0                  2571.526792      -93.11451      44.94283      2163034
# 1                  2515.373802      -93.11539      44.94234      2163035
# 2                  2511.924959      -93.11556      44.94231      2163036
# 3                  2502.991640      -93.11572      44.94223      2163037
# 4                  2465.206234      -93.11580      44.94189      2163038

# %%
xref_iter.centroid_lat = xref_iter.centroid_lat.astype(str)
xref_iter.centroid_long = xref_iter.centroid_long.astype(str)
xref_iter.dtypes
# Out:
# Parcel_PIN                                float64
# Monit_MAP_CODE1                            object
# Monit_SITE_CODE                             int64
# Monit_LAKE_SITE                             int64
# Distance_Parcel_Monitoring_Site_meters    float64
# Lake_Hydroid                                int64
# Distance_Parcel_Lake_meters               float64
# centroid_long                              object
# centroid_lat                               object
# Parcel_pkey                                 int64
# dtype: object

# %% [markdown]
# #### Problem 4
#
# We need to find a way to link these two files.  Inspect the columns for each file and suggest a column from each that can be used to make a link.

# %% [markdown]
# We could use the DNR_ID_Site_Number column from the lakes data set and the Monit_MAP_CODE1 column from the xref data

# %% [markdown]
# #### Problem 5
#
# Let's investigate these columns and use `set`s to explore.
#
# 1. For each file, make a `set` of the contents of the respective file.
# 2. Explore the relationship between the files using `intersection` and `difference`.
#
# What did you learn about these columns in regards to using them as a link between the files?  Any problems?

# %%
mces_lakes = set(mces_lakes_iter.DNR_ID_Site_Number)
len(mces_lakes)
# Out:
# 349

# %%
xref = set(xref_iter.Monit_MAP_CODE1)
len(xref)
# Out:
# 440

# %%
mces_xref = mces_lakes.intersection(xref)
len(mces_xref)
# Out:
# 344

# %%
mces_xref_diff = mces_lakes.difference(xref)
len(mces_xref_diff)
# Out:
# 5

# %%
mces_xref
# Out:
# {'02000300-01',
#  '02000400-01',
#  '02000500-01',
#  '02000600-01',
#  '02000700-01',
#  '02000900-01',
#  '02001300-01',
#  '02002200-01',
#  '02002600-01',
#  '02003400-01',
#  '02004200-01',
#  '02004500-01',
#  '02005300-01',
#  '02007200-01',
#  '02007501-01',
#  '02007900-01',
#  '02008000-01',
#  '02008100-01',
#  '02008400-01',
#  '02009100-01',
#  '02013000-01',
#  '02013300-01',
#  '02058500-01',
#  '02065400-01',
#  '10000200-01',
#  '10000200-02',
#  '10000500-01',
#  '10000600-01',
#  '10000700-01',
#  '10000900-01',
#  '10000900-02',
#  '10001000-01',
#  '10001100-01',
#  '10001200-01',
#  '10001300-01',
#  '10001400-01',
#  '10001500-01',
#  '10001800-01',
#  '10001900-01',
#  '10002800-01',
#  '10002900-01',
#  '10003100-01',
#  '10004100-01',
#  '10004200-01',
#  '10004401-01',
#  '10004500-01',
#  '10004800-01',
#  '10005200-01',
#  '10005300-01',
#  '10005400-01',
#  '10005800-01',
#  '10005900-01',
#  '10006300-01',
#  '10006600-01',
#  '10006800-01',
#  '10006900-01',
#  '10007000-01',
#  '10007800-01',
#  '10008000-01',
#  '10008400-01',
#  '10008500-01',
#  '10008600-01',
#  '10008800-01',
#  '10009300-01',
#  '10009500-01',
#  '10010300-01',
#  '10010400-01',
#  '10010500-01',
#  '10010700-01',
#  '10010800-01',
#  '10010900-01',
#  '10011000-01',
#  '10012100-01',
#  '10012700-01',
#  '10021600-01',
#  '10021700-01',
#  '10021800-01',
#  '10022500-01',
#  '10022600-01',
#  '10024900-01',
#  '13002300-01',
#  '13002400-01',
#  '13004200-01',
#  '13005400-01',
#  '13005600-01',
#  '13005700-01',
#  '19000400-01',
#  '19000600-01',
#  '19000600-03',
#  '19002000-01',
#  '19002100-01',
#  '19002200-01',
#  '19002300-01',
#  '19002400-01',
#  '19002500-01',
#  '19002601-01',
#  '19002700-01',
#  '19002900-01',
#  '19003000-01',
#  '19003100-01',
#  '19003200-01',
#  '19003300-01',
#  '19003700-01',
#  '19004100-01',
#  '19004200-01',
#  '19004700-01',
#  '19005000-01',
#  '19005700-01',
#  '19006500-01',
#  '19006700-01',
#  '19007500-01',
#  '19007600-01',
#  '19008000-01',
#  '19008200-01',
#  '19008800-01',
#  '19009400-01',
#  '19009500-01',
#  '19011700-01',
#  '19019800-01',
#  '19026300-01',
#  '19034800-01',
#  '19034900-01',
#  '19036900-01',
#  '19044600-01',
#  '19045100-01',
#  '19045600-01',
#  '27000400-01',
#  '27001600-01',
#  '27001900-01',
#  '27002802-01',
#  '27002900-01',
#  '27003100-01',
#  '27003501-01',
#  '27004000-01',
#  '27004201-01',
#  '27004700-01',
#  '27005300-01',
#  '27005700-01',
#  '27005800-01',
#  '27006500-01',
#  '27006700-01',
#  '27006900-01',
#  '27007000-01',
#  '27007300-01',
#  '27007600-01',
#  '27007800-01',
#  '27008200-01',
#  '27008500-01',
#  '27008600-02',
#  '27008800-01',
#  '27008902-01',
#  '27009100-01',
#  '27009300-01',
#  '27009400-01',
#  '27010000-01',
#  '27010200-01',
#  '27010300-01',
#  '27010400-01',
#  '27010700-01',
#  '27011102-01',
#  '27011601-01',
#  '27011700-01',
#  '27011900-01',
#  '27012300-01',
#  '27012500-01',
#  '27012700-01',
#  '27012900-01',
#  '27013302-02',
#  '27013400-01',
#  '27013700-01',
#  '27014600-01',
#  '27014702-01',
#  '27015300-01',
#  '27015700-01',
#  '27016000-01',
#  '27016500-01',
#  '27016900-01',
#  '27017100-01',
#  '27017500-01',
#  '27017600-01',
#  '27017800-01',
#  '27017901-01',
#  '27018100-01',
#  '27018200-01',
#  '27018401-01',
#  '27018700-01',
#  '27019101-01',
#  '27019200-01',
#  '27019900-01',
#  '27062700-01',
#  '27063400-01',
#  '27064500-01',
#  '27066100-01',
#  '27067000-01',
#  '27067500-01',
#  '27068100-01',
#  '27069300-01',
#  '27071100-01',
#  '27073400-01',
#  '27104501-01',
#  '40002800-01',
#  '62000100-01',
#  '62000200-01',
#  '62000600-01',
#  '62000700-01',
#  '62001300-01',
#  '62001800-01',
#  '62002400-01',
#  '62002800-01',
#  '62003600-01',
#  '62003801-01',
#  '62004901-01',
#  '62005400-01',
#  '62005600-01',
#  '62005700-01',
#  '62005800-01',
#  '62006200-01',
#  '62006700-01',
#  '62006900-01',
#  '62007100-01',
#  '62007200-01',
#  '62007300-01',
#  '62007800-01',
#  '62008200-01',
#  '62018700-01',
#  '62020400-01',
#  '70001600-01',
#  '70001800-01',
#  '70002100-01',
#  '70002200-01',
#  '70002600-01',
#  '70005000-01',
#  '70005200-01',
#  '70005400-01',
#  '70006500-01',
#  '70007200-01',
#  '70007400-01',
#  '70007800-01',
#  '70009100-01',
#  '70009100-02',
#  '70009500-01',
#  '70009800-01',
#  '70012001-01',
#  '82000200-01',
#  '82000400-01',
#  '82000500-01',
#  '82000900-01',
#  '82001000-01',
#  '82001100-01',
#  '82001400-01',
#  '82001501-01',
#  '82001502-01',
#  '82001700-01',
#  '82001800-01',
#  '82001900-01',
#  '82002000-01',
#  '82002100-01',
#  '82002300-01',
#  '82002500-01',
#  '82002602-01',
#  '82002800-01',
#  '82003100-01',
#  '82003300-01',
#  '82003400-01',
#  '82003500-01',
#  '82003600-01',
#  '82003800-01',
#  '82004200-01',
#  '82004400-01',
#  '82004600-01',
#  '82004900-01',
#  '82005202-01',
#  '82005204-01',
#  '82005300-01',
#  '82005400-01',
#  '82005600-01',
#  '82005900-01',
#  '82006200-01',
#  '82006500-01',
#  '82006700-01',
#  '82006800-01',
#  '82007200-01',
#  '82007600-01',
#  '82007700-01',
#  '82008000-01',
#  '82008200-01',
#  '82008700-01',
#  '82008900-01',
#  '82009002-01',
#  '82009100-01',
#  '82009200-01',
#  '82009400-01',
#  '82009700-01',
#  '82010100-01',
#  '82010200-01',
#  '82010300-01',
#  '82010400-01',
#  '82010600-01',
#  '82010700-01',
#  '82010800-01',
#  '82010900-01',
#  '82011000-01',
#  '82011200-01',
#  '82011301-01',
#  '82011500-01',
#  '82011602-01',
#  '82011700-01',
#  '82011800-01',
#  '82011900-01',
#  '82012000-01',
#  '82012200-01',
#  '82012300-01',
#  '82012500-01',
#  '82012600-01',
#  '82013200-01',
#  '82013300-01',
#  '82013401-01',
#  '82013500-01',
#  '82013700-01',
#  '82014000-01',
#  '82014700-01',
#  '82014800-01',
#  '82015100-01',
#  '82015300-01',
#  '82015900-01',
#  '82016200-01',
#  '82016300-01',
#  '82016600-01',
#  '82016700-01',
#  '82028700-01',
#  '82030100-01',
#  '82030500-01',
#  '82030800-01',
#  '82031300-01',
#  '82031800-01',
#  '82033400-01',
#  '82036500-01',
#  '82036800-01',
#  '82039900-01',
#  '82046200-01',
#  '82048200-01',
#  '82048800-01',
#  '82051400-01',
#  '99002487-01'}

# %%
mces_xref_diff
# Out:
# {'13002200-01', '13005300-01', '13010300-01', '40002700-01', '66006100-01'}

# %% [markdown]
# > *Your thoughts here*

# %% [markdown]
# #### Problem 6
#
# Use group_by/aggregation to investigate any missing keys.  Suggest some options for how we might proceed.

# %%
# Your code here

# %% [markdown]
# > *Your thoughts here*

# %% [markdown]
# #### Problem 7
#
# Use select/group_by/aggregation to reduce the lakes table to a table with one row per lake that contains the lake name and corresponding code.

# %%
# Your code here

# %% [markdown]
# #### Problem 8
#
# Make a `dict` that with the lake id as the key and the lake name as the value.  You will want to zip the columns from the last table together and use a `dict` comp.

# %%
# Your code here

# %% [markdown]
# #### Problem 9
#
# Now we want to link the Xref file to the parcel files, which will be done by matching the latitudes and longitudes in the parcel files to `xref.latitude` and `xref.longitude`.  First, let's investigate the relationship between these columns.
#
# 1. Make a `set` of lat/long tuples from the Xref file.<br>
# 2. Make a list of lat/long sets, one for each chunk of each parcel file for 2004+.  Do this with a list comprehension that uses double for clauses.
# 3. Reduce the sets in the list to one set using the union to combine sets.
# 4. Investigate the relationship between the lat/long pairs from the two types of files.  Are there any missing on either side? How many?
#
# Discuss what you have learned and suggest how we might proceed.

# %%
# Your code here

# %% [markdown]
# > *Your thoughts here*

# %% [markdown]
# #### Problem 10
#
# Use select/group_by/aggregation to reduce the lakes table to a table with one row per lake that contains latitude, longitude, and the lake ID code.

# %%
# Your code here

# %% [markdown]
# #### Problem 11
#
# Make a `dict` that with the (lat, long) tuple as the key and the lake code as the value.  You will want to zip the columns from the last table together and use a `dict` comp.

# %%
# Your code here

# %% [markdown]
# #### Problem 12
#
# Now make a `dict` that combines the last two `dict`s into a single `dict` that translates the lat/long tuple into a lake name.

# %%
# Your code here
