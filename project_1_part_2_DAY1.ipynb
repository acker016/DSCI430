# %% [markdown]
# # Project 1 Part 2
#
#
# In this part of the project, you will create `dict`s to link the parcel/property data to the lakes data.  Then we will use `panda`’s to
#
# a. Read each parcel file
# b. Add a column containing the nearest lake
# c. Write the result to a new file.
#
# To accomplish this task, complete the following steps.

# %% [markdown]
# #### Problem 1
#
# Now we want to read in the file `mces_lakes_1999_2014.txt`, which contains water quality measurements for all lakes in the Twin Cities are during the listed years.
#
# Use `!head` to inspect the file and determine the details of it's format (header?, sep=?, etc.).

# %%
# !head ../MinneMUDACProject1/MinneMUDAC_raw_files/mces_lakes_1999_2014.txt
# Out:
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Alimagnet Lake	Burnsville	Dakota	19002100-01
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Armstrong Lake	Oakdale	Washington	82011602-01	Mississippi River - Twin Cities	South Washington WD	1	2010-05-01	0:00	2
# 7105	Lakes Monitoring	Auburn Lake	Laketown Township	Carver	10004401-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	1994-09-06	9:05	1994-09-06	9:05	24			0-4 Categorical Calcul
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Bass Lake	Grant	Washington	82012300-01	Lower St. Croix R
# 7108	Citizen Assisted Monitoring Program (CAMP) f
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Battle Creek Lake	Woodbury	Washington	82009100-01	Mississippi River - Twin Cities	Ramsey-Washington Metro WD	1
# 7108	Citiz
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Benton Lake	Cologne	Carver
# 7105	Lakes Monitoring	Big Carnelian Lake	May Township	Washington	82004900-01	Lower St. Croix River	Carnelia
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Big Comfort Lake	Wyoming Township	Chisago	13005300-01	Lower St. Croix River	Comfort Lake-Forest Lake WD	1	2013-06-12	14:45	2013-06-12	14:45	0				2	Approved		2	Approved			2.3
# 7108	Citizen Assisted Monitoring Program (CAM
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Brickyard Clayhole Lake	Chaska	Carver	10022500-01	Lower Minnesota River	Lower Minnesota River WD	1	2003-05-29	11:30	2003-05-29	11:30	0				1	Approved		1	Approved			4.7	Approved	m		0.022	Approved	mg/L	-93.59982
# 7105	Lakes Monitoring	Bryant Lake	Eden Prairie	Hennepin	27006700-01	Lower Minnesota River	Nine Mile Creek WD	1	1991-04-17	9:40	1991-04-17	9:40	4
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Bush Lake	Bloomington	Hennepin	27004700-01	Lower Minnesota River	Nine Mile Creek WD	1	2007-05-31	13:15	2007-05-31	13:15	0				1	Approved		1	Approved			6.1	Approved	m				mg/L	-93.38283992	44.8380
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Carol Lake	Stillwater Township	Washington	82001700-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2004-05-01	0:00	2004-09-30	0:00	0	2	Approved
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Cedar Island Lake	Maple Grove	Hennepin	27011900-01	Mississippi River - Twin Cities	Shingle Creek
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Cenaiko Lake	Coon Rapids	Anoka	02065400-01	Mississippi River - Twin Cities	Coon Creek WD	1	2006-09-21	0:00	2006-09-21	0:00	0				2	Approved		2	Approved			2.3	Approved	m		0.016	Approved	mg/L	-93.30035632	45.14
# 7105	Lakes Monitoring	Chub Lake	Eureka Township	Dakota	19002000-01	Cannon River	North Cannon River WMO
# 7
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Colby Lake	Woodbury	Washington	82009400-01	Mississippi River - Twin Cities	South Washington WD	1	2002-07-27	0:00	2002-07-27	0:00	0											0.4	Approved	m		0.209	Approved	mg/L
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Courthouse Lake	Chaska	Carver	10000500-01	Lower Minnesota River	Lower Minnesota River WD	1	2007-10-17	10:44	2007-10
# 7105	Lakes Monitoring	Crystal Lake	Burnsville	Dakota	19002700-01
# 7105	Lakes Monitoring	Crystal Lake	Burnsville	Dakota	19002700-01	Lower Minnesota River	Black Dog WMO	1	1988-10-05	8:25	1988-10-05	8:25
# 7105	Lakes Monitoring	DeMontreville Lake	Lake Elmo	Washington	82010100-01	Lower St. Croix River	Valley Branch WD	1	1991-07-24	10:40	1991-06-24	10:40	7													m		0.03	Approved	mg/L	-92.93991097	45.0216610645.0216610661970.6	Approved	m		0.22	Approved	mg/L	-93.25364449	44.75493717
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	George Watch Lake	Lino Lakes	Anoka	02000500-01	Mississippi River - Twin Cities	Rice Creek WD	1	2006
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Long Lake	Apple Valley	Dakota	19002200-01	Mississippi River - Lake Pepin	Vermillion River Watershed JPO	1	2009-05-13	18:21	2009-05-13	18:21	0				1	Approved		4	Approved			0.5	Approved	m		0.149	Approved	mg/L	-93.17320832	44.755920202	45.1186466363roved		4	Approved			0.68	Approved	m		0.065	Approved	mg/L	-93.08905468	45.17640481Branch WD	1	2006-05-14	0:00	2006-05-14	0:00	0				2	Approved		4	Approved			3	Approved	m		0.026	Approved	mg/L	-92.86728656	45.01620735ns Creek WD	1	2000-07-24	0:00	2000-07-24	0:00	0							4	Approved			1.22	Approved	m		0.09	Approved	mg/L	-92.89283249	45.133035089:19	0				4	Approved		4	Approved			0.762	Approved	m		0.095	Approved	mg/L	-92.89283249	45.13303508hip	Washington	82007700-01	Lower St. Croix River	Browns Creek WD	1	2014-05-07	9:09	2014-05-07	9:09	0				3	Approved		3	Approved			1.07	Approved	m		0.052	Approved	mg/L	-92.89283249	45.13303508 Monitoring Program (CAMP) for Lakes	Golden Lake	Circle Pines	Anoka	02004500-01	Mississippi River - Twin Cities	Rice Creek WD	1	2000-07-06	0:00	2000-07-06	0:00	0				2	Approved		2	Approved			1.5	Approved	m		0.05	Approved	mg/L	-93.15271269	45.13923351ippi River - Twin Cities	Rice Creek WD	1	2009-05-18	13:00	2009-05-18	13:00	0				1	Approved		1	Approved			1.8	Approved	m		0.035	Approved	mg/L	-93.15271269	45.13923351ix River	Valley Branch WD	1	1998-06-13	12:00	1998-06-13	12:00	0				2	Approved		2	Approved			2.9	Approved	m		0.11	Approved	mg/L	-92.91150629	45.26928737ed	m		0.168	Approved	mg/L	-92.91150629	45.26928737er	Valley Branch WD	1	2009-04-22	11:30	2009-04-22	11:30	0				3	Approved		4	Approved			0.61	Approved	m		0.143	Approved	mg/L	-92.91197724	44.96377696shington	82011301-01	Lower St. Croix River	Valley Branch WD	1	2009-08-04	11:20	2009-08-04	11:20	0				4	Approved		4	Approved			0.3	Approved	m		0.118	Approved	mg/L	-92.91197724	44.96377696toring Program (CAMP) for Lakes	Goose Lake	Lake Elmo	Washington	82011301-01	Lower St. Croix River	Valley Branch WD	1	2013-06-10	9:25	2013-06-10	9:25	0				4	Approved		4	Approved			0.45	Approved	m		0.113	Approved	mg/L	-92.91197724	44.96377696 Monitoring	Hafften Lake	Greenfield	Hennepin	27019900-01	North Fork Crow River	Pioneer-Sarah Creek WMC	1	2000-05-10	0:00	2000-05-10	0:00	13													m		0.05	Approved	mg/L	-93.67777499	45.09449117	Comfort Lake-Forest Lake WD	1	2011-05-01	0:00	2011-09-30	0:00	0	4	Approved											m				mg/L	-92.89937532	45.25122379-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2006-05-24	14:37	2006-05-24	14:37	0				2	Approved		3	Approved			1.981	Approved	m		0.068	Approved	mg/L	-92.81398535	45.23381325 (CAMP) for Lakes	Hay Lake	Scandia	Washington	82006500-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2007-10-01	13:24	2007-10-01	13:24	0				2	Approved		2	Approved			1.829	Approved	m		0.05	Approved	mg/L	-92.81398535	45.23381325	0				2	Approved		2	Approved			1.981	Approved	m		0.043	Approved	mg/L	-92.81398535	45.2338132582006500-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2010-08-23	10:27	2010-08-23	10:27	0				2	Approved		3	Approved			1.52	Approved	m		0.044	Approved	mg/L	-92.81398535	45.23381325Scandia	Washington	82006500-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2013-06-06	13:39	2013-06-06	13:39	0				2	Approved		2	Approved					m		0.03	Approved	mg/L	-92.81398535	45.23381325sted Monitoring Program (CAMP) for Lakes	Hay Lake	Scandia	Washington	82006500-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2014-07-24	10:19	2014-07-24	10:19	0				3	Approved		3	Approved		>	1.68	Approved	m		0.038	Approved	mg/L	-92.81398535	45.23381325ted Monitoring Program (CAMP) for Lakes	Heims Lake	Wyoming	Chisago	13005600-01	Lower St. Croix River	Comfort Lake-Forest Lake WD	1	2009-07-24	19:30	2009-07-24	19:30	0				2	Approved		4	Approved			0.5	Approved	m		0.032	Approved	mg/L	-92.99323808	45.3165851610:00	2003-08-08	10:00	0				3	Approved						0.2	Approved	m		0.269	Approved	mg/L	-93.23309565	45.05890169.14237332	44.787990960:00	1999-06-09	10:00 ...
# 7108	Citizen Assisted Monitoring Pr
# 7105	Lakes Monitoring	Long Lake	New
# 7105	Lakes Monitoring	Lost Lake	Plymouth	Hennepin	27010300-01	Mississippi River - Twin Cities	Bassett Creek WMC	1	1982-05-0
# 7105	Lake
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	O'Dowd Lake	Shakopee	Scott	70009500-01	Lower Minnesota River	Scott WMO	1	2014-05-24	19:45	2014-05-24	19:45	0				1	Approved		1	Approved			2.2	Approved	m		0.025	Approved	mg/L	-93.5154039	44.74489311394	44.830294344	44.83029434428	45.08458142ver	Riley-Purgatory-Bluff Creek WD	1	2005-09-08	0:00	2005-09-08	0:00	0				3	Approved		2	Approved			0.7	Approved	m		0.085	Approved	mg/L	-93.52556143	44.8697700252556143	44.8697700207-09	8:00	2008-07-09	8:00	0				2	Approved		2	Approved			2.1	Approved	m		0.025	Approved	mg/L	-93.52556143	44.86977002ing Program (CAMP) for Lakes	Lotus Lake	Chanhassen	Carver	10000600-01	Lower Minnesota River	Riley-Purgatory-Bluff Creek WD	1	2009-08-24	7:30	2009-08-24	7:30	0				2	Approved		2	Approved			1.6	Approved	m		0.057	Approved	mg/L	-93.52556143	44.86977002ed			0.7	Approved	m		0.031	Approved	mg/L	-93.52556143	44.86977002pproved											m				mg/L	-92.84729796	45.12194563Citizen Assisted Monitoring Program (CAMP) for Lakes	Louise Lake	Stillwater Township	Washington	82002500-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2008-06-02	12:10	2008-06-02	12:10	2													m		0.151	Approved	mg/L	-92.84729796	45.12194563Lake WD	1	1999-07-09	11:50	1999-07-09	11:50	0				1	Approved		1	Approved			2.7	Approved	m		0.02	Approved	mg/L	-93.41536363	44.734809443	17:15	0				3	Approved		2	Approved			1.7	Approved	m		0.027	Approved	mg/L	-93.41536363	44.73480944ake	May Township	Washington	82004200-01	Lower St. Croix River	Browns Creek WD	1	2011-05-11	8:51	2011-05-11	8:51	0				3	Approved		4	Approved			0.46	Approved	m		0.228	Approved	mg/L	-92.88395835	45.15170647klyn Park	Hennepin	27006500-01	Mississippi River - Twin Cities	Shingle Creek WMC	1	2006-06-17	0:00	2006-06-17	0:00	0				4	Approved		4	Approved			0.4	Approved	m		0.155	Approved	mg/L	-93.39978639	45.072027270				4	Approved		4	Approved			0.4	Approved	m		0.124	Approved	mg/L	-93.39978639	45.07202727tizen Assisted Monitoring Program (CAMP) for Lakes	Magda Lake	Brooklyn Park	Hennepin	27006500-01	Mississippi River - Twin Cities	Shingle Creek WMC	1	2012-09-21	8:00	2012-09-21	8:00	0				4	Approved		4	Approved			0.35	Approved	m		0.182	Approved	mg/L	-93.39978639	45.07202727	45.17440477 St. Croix River	Carnelian-Marine-St. Croix WD	1	2005-07-13	12:00	2005-07-13	12:00	0				3	Approved		5	Approved			0.61	Approved	m				mg/L	-92.88669874	45.17440477St. Croix WD	1	2007-07-24	10:34	2007-07-24	10:34	0				4	Approved		4	Approved			0.305	Approved	m				mg/L	-92.88669874	45.17440477CAMP) for Lakes	Marcott Lake	Inver Grove Heights	Dakota	19004100-01	Mississippi River - Lake Pepin	Lower Mississippi River WMO	1	1995-06-08	9:45	1995-06-08	9:45	0				2	Approved		2	Approved			3.4	Approved	m		0.03	Approved	mg/L	-93.08291903	44.827742874	Approved			0.5	Approved	m		0.15	Approved	mg/L	-93.08291903	44.82774287Maria Lake	Benton Township	Carver	10005800-01	Lower Minnesota River	Carver County WMO	1	2000-08-27	0:00	2000-08-27	0:00	0				5	Approved		5	Approved			0.2	Approved	m		0.68	Approved	mg/L	-93.76988852	44.72243717hip	Carver	10005800-01	Lower Minnesota River	Carver County WMO	1	2001-09-09	0:00	2001-09-09	0:00	0				5	Approved		5	Approved			0.6	Approved	m		0.17	Approved	mg/L	-93.76988852	44.722437170-01	Lower Minnesota River	Carver County WMO	1	2005-09-15	0:00	2005-09-15	0:00	0				3	Approved		4	Approved			0.4	Approved	m		0.237	Approved	mg/L	-93.76988852	44.72243717on River Watershed JPO	1	1981-07-08	9:09	1981-07-08	9:09	0											0.7	Approved	m		0.05	Approved	mg/L	-93.27557035	44.65825741ille	Dakota	19002601-01	Mississippi River - Lake Pepin	Vermillion River Watershed JPO	1	1989-04-18	8:50	1989-04-18	8:50	0											2.4	Approved	m		0.025	Approved	mg/L	-93.27557035	44.65825741035	44.658257415	44.65825741itizen Assisted Monitoring Program (CAMP) for Lakes	Marion Lake	Lakeville	Dakota	19002601-01	Mississippi River - Lake Pepin	Vermillion River Watershed JPO	1	1999-06-12	10:45	1999-06-12	10:45	0				2	Approved		1	Approved			3	Approved	m		0.005	Approved	 ...
# 7105	Lakes Monitoring	Olson Lake	Lake Elmo	Wa
# 7108	Citiz
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Oneka Lake	Hugo	Washington	82014000-01	Mississippi River - Twin Cities	Rice Creek WD	1	2010-08-07	19:51	2010-08-07	19:51	0				3	Approved		3	Approved
# 7105	Lakes Monitoring	Orchard Lake	Lakeville	Dakota	19003100-01	Lower Minnesota River	Black Dog WMO	1	1993-05-09	11:15	1993-05-09	11:15	0											1.4	Approved	m		0.03	Ap
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Orchard Lake	Lakeville	Dakota	19003100-01	Lower Minnesota River	Black Dog WMO	1	2006-05-01	0:00	2006-09-30	0:00	0	3	Approved
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Orchard Lake	Lakeville	Dakota	19003100-01	Lower Minnesota River	Black Dog WMO	1	2011-06-29	12:36	2011-06-29
# 7105	Lakes Monitoring	Park
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Parkers Lake	Plymouth	Hennepin	27010700-01	Mississippi River - Twin Cities	Bassett Creek WMC	1	2005-09-16	0:00	2005-09-16	0:00	0				3	Approved		3	Approved			2.6	Approved	m		0.047	Approved	mg/L	-93.471132
# 7105	Lakes Monitoring	Parley Lake	Laketown Township	Carver	10004200-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	1986-06-30	9:52	1986-06-30	9:52	4													m		0.12	Appr
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Pat Lake	Grant Township	Washington	82012500-01	Lower St. Croix River	Browns Creek WD	1	2009-05-12	9:20	2009-05-12	9:20	0				2	Approved		3	Approved			1.676	Approved	m		0.03
# 7108	Citizen Assisted Monit
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Peltier Lake
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Peter Lake	Medina	Hennepin	27014702-01	South Fork Crow River	Pioneer-Sarah Creek WMC	1	2010-06-13	21:00	2010-06-13	21:00	0				1	Approved		1	Ap
# 71
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Pike Lake	Maple Grove	Hennepin	27011102-01	Mississippi River - Twin Cities	Shingle Creek WMC	1	1997-05-01	0:00	1997-09-30	0:00	0	2	Approved
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Pike Lake	Maple Grove	Hennepin	27011102-01	Mississippi River - Twin Cities	Shingle Creek WMC	1	2003-0
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Pike Lake	Maple Grove	Hennepin	27011102-01	Mississippi River - Twin Cities	Shingle Creek WMC	1	2009-08-23	19:48
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Pine Tree Lake	Grant	Washington	82012200-01	Mississippi River - Twin Cities	Rice Creek WD	1	1996-09-06	16:00	1996-09-06	16:00	0				2	Approved		2	Approved			2.1	Approved	m		0.02	Approved	mg/L
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Spring Lake	Prior Lake	Scott	70005400-01	Lower Minnesota River	Prior Lake-Spring Lake WD	1	2010-09-26	12:20	2010-09-26	12:20	0				2	Approved		2	Approved			0.8	Approved	m		044	Approved	mg/L	-93.46843381	44.701810626207	45.07817668825842333Approved			3	Approved	m		0.02	Approved	mg/L	-92.95386928	45.10231359ities	Shingle Creek WMC	1	1999-09-29	12:00	1999-09-29	12:00	0				3	Approved						1.3	Approved	m		0.11	Approved	mg/L	-93.46584043	45.05251033n WD	1	1998-05-01	0:00	1998-09-30	0:00	0	2	Approved											m				mg/L	-92.89985034	44.92635622ashington	82009200-01	Mississippi River - Twin Cities	South Washington WD	1	2008-08-28	10:30	2008-08-28	10:30	0				4	Approved		4	Approved			1.829	Approved	m		0.028	Approved	mg/L	-92.89985034	44.92635622s Lake	Woodbury	Washington	82009200-01	Mississippi River - Twin Cities	South Washington WD	1	2009-08-17	10:00	2009-08-17	10:00	10													m		0.882	Approved	mg/L	-92.89985034	44.92635622oved	mg/L	-92.89985034	44.926356227577765	44.68670995ake	Greenfield	Hennepin	27019200-01	South Fork Crow River	Pioneer-Sarah Creek WMC	1	1985-10-10	10:10	1985-10-10	10:10	8													m		0.09	Approved	mg/L	-93.74164656	45.06683157s	Regional Park Lake	Cottage Grove	Washington	82008700-01	Mississippi River - Twin Cities	South Washington WD	1	2001-05-16	7:30	2001-05-16	7:30	0				2	Approved		4	Approved			0.7	Approved	m		0.07	Approved	mg/L	-92.90248396	44.80553214ring	Reitz Lake	Laketown Township	Carver	10005200-01	Lower Minnesota River	Carver County WMO	1	1993-05-24	12:30	1993-05-24	12:30	0											1	Approved	m		0.11	Approved	mg/L	-93.74452179	44.83862568nnesota River	Carver County WMO	1	2007-06-02	0:00	2007-06-02	0:00	0				2	Approved		2	Approved			2	Approved	m		0.032	Approved	mg/L	-93.74452179	44.83862568roved		1	Approved			1.2	Approved	m		0.238	Approved	mg/L	-93.74452179	44.83862568n Assisted Monitoring Program (CAMP) for Lakes	Rest Area Pond	West Lakeland Township	Washington	82051400-01	Lower St. Croix River	Valley Branch WD	1	2010-05-28	10:00	2010-05-28	10:00	0											0.46	Approved	m		0.131	Approved	mg/L	-92.81688162	44.95345401nitoring Program (CAMP) for Lakes	Rice Elm Lake	Maple Grove	Hennepin	27011601-01	Mississippi River - Twin Cities	Elm Creek WMC	1	2008-05-01	0:00	2008-09-30	0:00	0	1	Approved											m				mg/L	-93.46614319	45.11672618rie	Carver	10000200-01	Lower Minnesota River	Riley-Purgatory-Bluff Creek WD	1	2006-05-01	0:00	2006-09-30	0:00	0	3	Approved											m				mg/L	-93.51695191	44.8346902700	0				4	Approved		3	Approved			1.6	Approved	m		0.044	Approved	mg/L	-93.51695191	44.83469027Purgatory-Bluff Creek WD	2	1982-01-20	1:00	1982-01-20	1:00	12													m		0.15	Approved	mg/L	-93.52393956	44.83937512sen	Carver	10000200-02	Lower Minnesota River	Riley-Purgatory-Bluff Creek WD	2	1985-07-10	11:32	1985-07-10	11:32	7													m		0.04	Approved	mg/L	-93.52393956	44.83937512-16	10:20	1986-07-16	10:20	10													m		0.48	Approved	mg/L	-93.52393956	44.83937512:50	5													m		0.07	Approved	mg/L	-93.52393956	44.83937512gatory-Bluff Creek WD	2	1997-08-20	11:15	1997-08-20	11:15	0											0.8	Approved	m		0.09	Approved	mg/L	-93.52393956	44.83937512oring Program (CAMP) for Lakes	Rose Lake	Lake Elmo	Washington	82011200-01	Lower St. Croix River	Valley Branch WD	1	2006-07-15	0:00	2006-07-15	0:00	0				4	Approved		4	Approved			0.7	Approved	m		0.068	Approved	mg/L	-92.87012688	44.87117571lley Branch WD	1	2009-04-22	12:45	2009-04-22	12:45	0				3	Approved		4	Approved			0.61	Approved	m		0.181	Approved	mg/L	-92.86991774	44.9639433Township	Carver	10008000-01	Lower Minnesota River	Carver County WMO	1	2006-06-01	0:00	2006-06-01	0:00	0				3	Approved		3	Approved			1.1	Approved	m		0.103	Approved	mg/L	-93.85951756	44.8718362900-01	Mississippi River - Twin Cities	Shingle Creek WMC	1	2008-05-01	0:00	2008-09-30	0:00	0	3	Approved											m				mg/L	-93.32132645	45.04016361	45.22818996proved	mg/L	-92.8040722	45.22818996itoring Program (CAMP) for Lakes	Sand Lake ...
# 7105	Lakes Monitoring	Square Lake	May Township
# 7105	Lakes Monitoring	Square Lake	May Township	Washington	82004600-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	1999-04-21	9:00	1999-04-21	9:00	0				1	Approved
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Square Lake	May Township	Washington	8200460
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Swede Lake	Watertown Township	Carver	10009500-01	South Fork Crow River	Carver County WMO	1	2010-06-24	17:00	2010-06-24	17:00	0				3	Approved		4	Approved			0.6	Approved	m		0.271	Approved	mg/L	-93.8182476	44.9308244519794558881816ved	mg/L	-92.80441146	45.156747ram (CAMP) for Lakes	Square Lake	May Township	Washington	82004600-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2006-08-14	0:00	2006-08-14	0:00	0													m		0.016	Approved	mg/L	-92.80441146	45.15674756747nship	Washington	82004600-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2008-08-06	8:25	2008-08-06	8:25	0				2	Approved		1	Approved			5.182	Approved	m				mg/L	-92.80441146	45.156747010-05-01	0:00	2010-09-30	0:00	0	4	Approved											m				mg/L	-92.80441146	45.15674745.156747. Croix River	Carnelian-Marine-St. Croix WD	1	2011-10-04	8:24	2011-10-04	8:24	0				1	Approved		1	Approved			7.47	Approved	m		0.015	Approved	mg/L	-92.80441146	45.156747	1	Approved		1	Approved			7.01	Approved	m		0.009	Approved	mg/L	-92.80441146	45.1567472.80441146	45.156747MP) for Lakes	St. Joe Lake	Chanhassen	Carver	10001100-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	2004-04-18	0:00	2004-04-18	0:00	0				2	Approved		4	Approved			1.2	Approved	m		0.04	Approved	mg/L	-93.62296909	44.8756457d	m		0.014	Approved	mg/L	-93.62296909	44.8756457-11	0:00	0				2	Approved		1	Approved			2.9	Approved	m		0.038	Approved	mg/L	-93.62296909	44.8756457	Chanhassen	Carver	10001100-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	2007-08-12	0:00	2007-08-12	0:00	0				2	Approved		2	Approved			3.25	Approved	m		0.015	Approved	mg/L	-93.62296909	44.87564577564573.5	Approved	m		0.027	Approved	mg/L	-93.62296909	44.87564570001100-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	2012-10-21	12:00	2012-10-21	12:00	0				2	Approved		1	Approved			2.35	Approved	m		0.013	Approved	mg/L	-93.62296909	44.8756457Croix WD	1	2000-04-13	0:00	2000-04-13	0:00	0				1	Approved		1	Approved			3.2	Approved	m		0.02	Approved	mg/L	-92.8547918	45.18394056ed	m	~	0.04	Approved	mg/L	-92.8547918	45.18394056akes	Staples Lake	May Township	Washington	82002800-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2005-04-20	0:00	2005-04-20	0:00	0				2	Approved		3	Approved			2.438	Approved	m		0.018	Approved	mg/L	-92.8547918	45.18394056-08-28	13:21	2006-08-28	13:21	0				2	Approved		2	Approved			2.743	Approved	m				mg/L	-92.8547918	45.183940562013-06-18	12:30	2013-06-18	12:30	0				2	Approved		2	Approved					m		0.027	Approved	mg/L	-92.8547918	45.18394056	Approved	m		0.017	Approved	mg/L	-92.8547918	45.183940562	44.83822033-93.45387122	44.83822033win Cities	Minnehaha Creek WD	1	1995-10-09	9:45	1995-10-09	9:45	11													m		0.05	Approved	mg/L	-93.6566799	44.86795275lumbia Heights	Anoka	02008000-01	Mississippi River - Twin Cities	Mississippi WMO	1	1998-08-25	14:00	1998-08-25	14:00	0				3	Approved		5	Approved			0.6	Approved	m		0.13	Approved	mg/L	-93.25384371	45.06228428roved		2	Approved			0.3	Approved	m		0.16	Approved	mg/L	-93.25384371	45.06228428llivan Lake	Columbia Heights	Anoka	02008000-01	Mississippi River - Twin Cities	Mississippi WMO	1	2000-09-28	0:00	2000-09-28	0:00	0				2	Approved		4	Approved			0.3	Approved	m		0.15	Approved	mg/L	-93.25384371	45.06228428ed Monitoring Program (CAMP) for Lakes	Sullivan Lake	Columbia Heights	Anoka	02008000-01	Mississippi River - Twin Cities	Mississippi WMO	1	2002-05-13	11:30	2002-05-13	11:30	0				3	Approved		4	Approved			0.3	Approved	m		0.096	Approved	mg/L	-93.25384371	45.06228428	Approved		4	Approved			0.4	Approved	m		0.069	Approved	mg/L	-93.25384371	45.06228428Approved	m				mg/L	-93.09818273	44.8758072610700-01	Lower St. Croix River	Valley Branch WD	1	2005-05-01	0:00	2005-09-30	0:00	0	1	Approved											m				mg/L	-92.89160242	44.99924011ved	m		0.378	Approved	mg/L	-92.89160242	44.999240116	Approved	mg/L	-92.89160242	44.99924011o	Washington	82010700-01	Lower St. Croix River	Valley Branch WD	1	2010-07-25	7:00	2010-07-25	7:00	0	 ...
# 7105	Lakes Monitoring	Upper Prior Lake	Prior Lake	Scott	70007200-01	Lower Minnesota River	Prior Lake-Spring Lake WD	1	2008-10-03	15:10	2008-10-03	15:10	0				4	Approved		3	Approved			0.6	Approved	m		0.085	Ap	Approved			0.7	Approved	m		0.071	Approved	mg/L	-93.44208405	44.71536216663224126959500-01	South Fork Crow River	Carver County WMO	1	2012-07-15	8:30	2012-07-15	8:30	0				3	Approved		4	Approved			0.3	Approved	m		0.247	Approved	mg/L	-93.8182476	44.930824own Township	Carver	10009500-01	South Fork Crow River	Carver County WMO	1	2013-07-22	20:00	2013-07-22	20:00	0				3	Approved		4	Approved			0.8	Approved	m		0.322	Approved	mg/L	-93.8182476	44.930824	Swede Lake	Watertown Township	Carver	10009500-01	South Fork Crow River	Carver County WMO	1	2014-08-01	20:00	2014-08-01	20:00	0				3	Approved		4	Approved			0.4	Approved	m		0.105	Approved	mg/L	-93.8182476	44.930824ssisted Monitoring Program (CAMP) for Lakes	Sweeney Lake	Golden Valley	Hennepin	27003501-01	Mississippi River - Twin Cities	Bassett Creek WMC	1	2000-06-23	0:00	2000-06-23	0:00	0				1	Approved		1	Approved			1.6	Approved	m		0.03	Approved	mg/L	-93.34160616	44.99052075 Cities	Bassett Creek WMC	1	2000-10-09	0:00	2000-10-09	0:00	0				1	Approved		1	Approved			1.3	Approved	m	~	0.04	Approved	mg/L	-93.34160616	44.99052075	44.99052075	-93.34160616	44.99052075n	27003501-01	Mississippi River - Twin Cities	Bassett Creek WMC	1	2007-06-05	0:00	2007-06-05	0:00	0				1	Approved		1	Approved			0.8	Approved	m		0.043	Approved	mg/L	-93.34160616	44.99052075	Approved			1.2	Approved	m		0.036	Approved	mg/L	-93.34160616	44.99052075 Assisted Monitoring Program (CAMP) for Lakes	Sweeney Lake	Golden Valley	Hennepin	27003501-01	Mississippi River - Twin Cities	Bassett Creek WMC	1	2009-06-15	13:00	2009-06-15	13:00	0				1	Approved		1	Approved			1.1	Approved	m		0.057	Approved	mg/L	-93.34160616	44.99052075- Twin Cities	Bassett Creek WMC	1	2010-05-15	14:30	2010-05-15	14:30	0				2	Approved						1	Approved	m		0.027	Approved	mg/L	-93.34160616	44.99052075	18:00	0				3	Approved		4	Approved			0.9	Approved	m		0.063	Approved	mg/L	-93.34160616	44.99052075 Creek WMC	1	2014-05-01	0:00	2014-09-30	0:00	0	0	Approved											m				mg/L	-93.60934728	45.19099213406464	44.87265849	Approved			3	Approved	m		0.03	Approved	mg/L	-93.63406464	44.87265849g/L	-92.82016292	45.18227666sota River	Scott WMO	1	1997-09-15	10:00	1997-09-15	10:00	4													m		0.11	Approved	mg/L	-93.52933474	44.737826645	Lakes Monitoring	Thole Lake	Louisville Township	Scott	70012001-01	Lower Minnesota River	Scott WMO	1	2000-07-31	0:00	2000-07-31	0:00	4													m		0.26	Approved	mg/L	-93.52933474	44.73782664	2002-06-25	0:00	3.5													m		0.118	Approved	mg/L	-93.52933474	44.73782664. Croix WD	1	1980-07-16	8:55	1980-07-16	8:55	0											2.6	Approved	m		0.04	Approved	mg/L	-92.86837105	44.78054925r	Carnelian-Marine-St. Croix WD	1	1983-06-16	10:46	1983-06-16	10:46	7.3													m		0.02	Approved	mg/L	-92.86837105	44.78054925:20	2003-07-15	14:20	0				3	Approved		4	Approved			0.763	Approved	m		0.15	Approved	mg/L	-92.8674582	45.17814441582	45.17814441onitoring Program (CAMP) for Lakes	Turtle Lake	May Township	Washington	82003600-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2014-05-28	15:41	2014-05-28	15:41	0				3	Approved		4	Approved		+	1.37	Approved	m		0.04	Approved	mg/L	-92.8674582	45.1781444191-05-15	9:45	1991-05-15	9:45	6													m		0.37	Approved	mg/L	-93.33618999	45.05077632oved	mg/L	-93.33618999	45.05077632g	Twin Lake	Brooklyn Center	Hennepin	27004201-01	Mississippi River - Twin Cities	Shingle Creek WMC	1	1991-07-23	8:50	1991-07-23	8:50	0											0.6	Approved	m		0.09	Approved	mg/L	-93.33618999	45.050776321-09-19	9:35	9													m		0.45	Approved	mg/L	-93.33618999	45.05077632004201-01	Mississippi River - Twin Cities	Shingle Creek WMC	1	1996-05-30	10:10	1996-05-30	10:10	0											3.9	Approved	m		0.07	Approved	mg/L	-93.33618999	45.05077632ties	Shingle Creek WMC	1	1996-07-09	10:20	1996-07-09	10:20	0											0.9	Approved	m		0.04	Approve ...
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	West Boot Lake	May Township	Washington	82004400-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2005-08-01	0:00	2005-08-01	0:00	0				2	Approved		2	Approved			4.267	Approved	m		0.016	Approved	mg/L	-92.83822036	45.163160333 for Lakes	Upper Prior Lake	Prior Lake	Scott	70007200-01	Lower Minnesota River	Prior Lake-Spring Lake WD	1	2010-09-15	10:40	2010-09-15	10:40	0				3	Approved		3	Approved			1	Approved	m		0.059	Approved	mg/L	-93.44208405	44.715362160				3	Approved		2	Approved			0.7	Approved	m		0.032	Approved	mg/L	-93.44208405	44.71536216or Lakes	Upper Prior Lake	Prior Lake	Scott	70007200-01	Lower Minnesota River	Prior Lake-Spring Lake WD	1	2013-05-01	0:00	2013-09-30	0:00	0	2	Approved											m				mg/L	-93.44208405	44.71536216	Approved	m		0.042	Approved	mg/L	-93.16496542	45.05824113ies	Rice Creek WD	1	2007-06-02	0:00	2007-06-02	0:00	0													m		0.053	Approved	mg/L	-93.16496542	45.05824113MP) for Lakes	Valentine Lake	Arden Hills	Ramsey	62007100-01	Mississippi River - Twin Cities	Rice Creek WD	1	2008-06-26	12:30	2008-06-26	12:30	0				3	Approved		4	Approved			2.24	Approved	m		0.089	Approved	mg/L	-93.16496542	45.05824113 Watershed JPO	1	1995-06-12	19:20	1995-06-12	19:20	0				2	Approved		2	Approved			0.8	Approved	m		0.04	Approved	mg/L	-93.20902364	44.7150895496-06-03	19:00	1996-06-03	19:00	0				2	Approved		2	Approved			1.1	Approved	m		0.05	Approved	mg/L	-93.20902364	44.71508954-19	13:00	0				1	Approved		1	Approved			1.5	Approved	m		0.04	Approved	mg/L	-93.20902364	44.715089546	Approved	m				mg/L	-93.20902364	44.71508954MP) for Lakes	Valley Lake	Lakeville	Dakota	19034800-01	Mississippi River - Lake Pepin	Vermillion River Watershed JPO	1	2000-08-31	0:00	2000-08-31	0:00	0				2	Approved		1	Approved			1.5	Approved	m		0.05	Approved	mg/L	-93.20902364	44.71508954akeville	Dakota	19034800-01	Mississippi River - Lake Pepin	Vermillion River Watershed JPO	1	2001-08-20	14:00	2001-08-20	14:00	0				2	Approved		3	Approved			2.1	Approved	m		0.06	Approved	mg/L	-93.20902364	44.71508954	2002-07-09	8:30	2002-07-09	8:30	0				3	Approved		4	Approved			1.2	Approved	m				mg/L	-93.20902364	44.71508954.058	Approved	mg/L	-93.20902364	44.7150895408954Lake	Lakeville	Dakota	19034800-01	Mississippi River - Lake Pepin	Vermillion River Watershed JPO	1	2005-05-24	0:00	2005-05-24	0:00	0				2	Approved		2	Approved			1.6	Approved	m		0.025	Approved	mg/L	-93.20902364	44.715089541	Mississippi River - Lake Pepin	Vermillion River Watershed JPO	1	2006-05-16	0:00	2006-05-16	0:00	0				3	Approved		3	Approved			2.2	Approved	m		0.025	Approved	mg/L	-93.20902364	44.71508954Lake Pepin	Vermillion River Watershed JPO	1	2007-05-03	0:00	2007-05-03	0:00	0				2	Approved		1	Approved			1.9	Approved	m		0.028	Approved	mg/L	-93.20902364	44.71508954ssippi River - Lake Pepin	Vermillion River Watershed JPO	1	2008-05-01	0:00	2008-09-30	0:00	0	2	Approved											m				mg/L	-93.20902364	44.71508954- Lake Pepin	Vermillion River Watershed JPO	1	2009-05-01	0:00	2009-09-30	0:00	0	3	Approved											m				mg/L	-93.20902364	44.71508954pin	Vermillion River Watershed JPO	1	2010-04-13	11:45	2010-04-13	11:45	0				2	Approved		2	Approved			2	Approved	m		0.065	Approved	mg/L	-93.20902364	44.71508954hed JPO	1	2010-10-14	15:10	2010-10-14	15:10	0				2	Approved		1	Approved			1.2	Approved	m		0.07	Approved	mg/L	-93.20902364	44.715089548	11:37	2012-04-18	11:37	0				2	Approved		1	Approved			1.5	Approved	m		0.046	Approved	mg/L	-93.20902364	44.715089542013-09-30	0:00	0	0	Approved											m				mg/L	-93.20902364	44.71508954ed	m		0.021	Approved	mg/L	-93.20902364	44.71508954m (CAMP) for Lakes	Virginia Lake	Victoria	Carver	10001500-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	2000-05-29	0:00	2000-05-29	0:00	0				4	Approved		2	Approved			2.4	Approved	m		0.04	Approved	mg/L	-93.63573281	44.88296987	Approved	m		0.06	Approved	mg/L	-93.63573281	44.88296987ppi River - Twin Cities	Minnehaha Creek WD	1	2002-06-30	0:00	2002-06-30	0:00	0				3	Approved		3	Appr ...
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	West Boot Lake	May Township	Was
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Wood Lake	Burnsville	Dakota	19002400-01	Lower Minnesota River	Black Dog WMO	1	2004-05-25	3:00	2004-05-25	3:00	0				2	Approved		2	Approved			1.79	Approved	m		0.044	Approved	mg/L	-93.2658604	44.7411182727744.790068366803535992571144.963396955Westwood Lake	St. Louis Park	Hennepin	27071100-01	Mississippi River - Twin Cities	Bassett Creek WMC	1	1993-08-04	11:45	1993-08-04	11:45	0				2	Approved						1.4	Approved	m		0.03	Approved	mg/L	-93.38765176	44.97082571ett Creek WMC	1	2002-05-10	15:45	2002-05-10	15:45	0				2	Approved		5	Approved			1	Approved	m	~	0.046	Approved	mg/L	-93.38765176	44.97082571d	m		0.028	Approved	mg/L	-93.38765176	44.97082571uth Fork Crow River	Pioneer-Sarah Creek WMC	1	1985-05-01	0:00	1985-09-30	0:00	0	1	Approved											m				mg/L	-93.72754301	44.93568243pin	27018401-01	South Fork Crow River	Pioneer-Sarah Creek WMC	1	2001-06-11	0:00	2001-06-11	0:00	0											1.4	Approved	m		0.07	Approved	mg/L	-93.72754301	44.93568243h Creek WMC	1	2004-09-14	0:00	2004-09-14	0:00	0											0.7	Approved	m		0.069	Approved	mg/L	-93.72754301	44.93568243ow River	Pioneer-Sarah Creek WMC	1	2009-07-22	10:55	2009-07-22	10:55	0				4	Approved		3	Approved			0.85	Approved	m		0.072	Approved	mg/L	-93.72754301	44.93568243984-07-16	10:23	0											3.3	Approved	m		0.02	Approved	mg/L	-92.98289597	45.074977980:00	2006-05-04	0:00	0				2	Approved		2	Approved			0.7	Approved	m		0.055	Approved	mg/L	-92.89308991	45.22389054	2007-05-31	0:00	0				3	Approved		3	Approved			0.4	Approved	m		0.115	Approved	mg/L	-92.89308991	45.22389054(CAMP) for Lakes	White Rock Lake	Scandia	Washington	82007200-01	Mississippi River - Twin Cities	Rice Creek WD	1	2008-06-12	15:45	2008-06-12	15:45	0				2	Approved		2	Approved			0.7	Approved	m		0.074	Approved	mg/L	-92.89308991	45.22389054toring Program (CAMP) for Lakes	White Rock Lake	Scandia	Washington	82007200-01	Mississippi River - Twin Cities	Rice Creek WD	1	2011-08-23	10:00	2011-08-23	10:00	0				3	Approved		2	Approved			0.8	Approved	m		0.054	Approved	mg/L	-92.89308991	45.22389054007200-01	Mississippi River - Twin Cities	Rice Creek WD	1	2013-08-06	12:00	2013-08-06	12:00	0				2	Approved		2	Approved			1.2	Approved	m		0.047	Approved	mg/L	-92.89308991	45.223890545-05-10	17:15	1995-05-10	17:15	0				2	Approved		2	Approved			1.1	Approved	m		0.09	Approved	mg/L	-92.91260488	44.92794439Approved	mg/L	-92.91260488	44.92794439shington	82009002-01	Mississippi River - Twin Cities	South Washington WD	1	1997-04-19	15:30	1997-04-19	15:30	0				2	Approved		2	Approved			0.9	Approved	m		0.07	Approved	mg/L	-92.91260488	44.92794439proved		3	Approved			0.8	Approved	m		0.12	Approved	mg/L	-92.91260488	44.92794439for Lakes	Wilmes Lake	Woodbury	Washington	82009002-01	Mississippi River - Twin Cities	South Washington WD	1	1998-09-15	12:00	1998-09-15	12:00	0				2	Approved		2	Approved			1.9	Approved	m		0.04	Approved	mg/L	-92.91260488	44.9279443911:15	1999-08-17	11:15	0				4	Approved		4	Approved			0.6	Approved	m		0.1	Approved	mg/L	-92.91260488	44.92794439ng Program (CAMP) for Lakes	Wilmes Lake	Woodbury	Washington	82009002-01	Mississippi River - Twin Cities	South Washington WD	1	2000-10-01	0:00	2000-10-01	0:00	0				4	Approved		4	Approved			1.2	Approved	m		0.17	Approved	mg/L	-92.91260488	44.92794439-02	0:00	2001-10-02	0:00	0				3	Approved		3	Approved			0.8	Approved	m		0.08	Approved	mg/L	-92.91260488	44.92794439AMP) for Lakes	Wilmes Lake	Woodbury	Washington	82009002-01	Mississippi River - Twin Cities	South Washington WD	1	2003-05-04	0:00	2003-05-04	0:00	0				2	Approved		2	Approved			1	Approved	m		0.086	Approved	mg/L	-92.91260488	44.9279443900	2004-05-16	0:00	0				2	Approved		1	Approved			3	Approved	m		0.086	Approved	mg/L	-92.91260488	44.92794439P) for Lakes	Wilmes Lake	Woodbury	Washington	82009002-01	Mississippi River - Twin Cities	South Washington WD	1	2005-07-01	0:00	2005-07-01	0:00	0				3	Approved		3	Approved			1	Approved	m		0.066	Approved	mg/L	-92.91260488	44.92794439-08-10	0:00	0				4	Approved		3	App ...
# 7105	Lakes Monitoring	Zumbra Lake	Victoria	Carver	10004100-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	2002-10-14	0:00	2002-10-14	0:00	7													m	~	0.012	Approved	mg/L	-93.66768906	44.88381717.88381717177d			0.9	Approved	m		0.08	Approved	mg/L	-93.90614956	44.78311027Minnesota River	Black Dog WMO	1	2006-07-03	0:00	2006-07-03	0:00	0				5	Approved		4	Approved			0.78	Approved	m		0.066	Approved	mg/L	-93.2658604	44.74111827oved	mg/L	-93.2658604	44.74111827ower Minnesota River	Black Dog WMO	1	2008-08-21	10:20	2008-08-21	10:20	0				3	Approved		4	Approved			0.85	Approved	m		0.053	Approved	mg/L	-93.2658604	44.74111827itoring Program (CAMP) for Lakes	Wood Lake	Burnsville	Dakota	19002400-01	Lower Minnesota River	Black Dog WMO	1	2010-05-01	17:40	2010-05-01	17:40	0				3	Approved		2	Approved			3.1	Approved	m		0.013	Approved	mg/L	-93.2658604	44.74111827:50	0				3	Approved		4	Approved			2	Approved	m		0.046	Approved	mg/L	-93.2658604	44.74111827	Wood Lake	Burnsville	Dakota	19002400-01	Lower Minnesota River	Black Dog WMO	1	2012-06-26	17:30	2012-06-26	17:30	0				3	Approved		2	Approved			1	Approved	m		0.073	Approved	mg/L	-93.2658604	44.74111827ed	m		0.03	Approved	mg/L	-93.2658604	44.741118274-10-26	16:20	2014-10-26	16:20	0				2	Approved		2	Approved			1.6	Approved	m		0.035	Approved	mg/L	-93.2658604	44.74111827ashington	82013200-01	Lower St. Croix River	Browns Creek WD	1	2007-09-17	14:26	2007-09-17	14:26	0				3	Approved		3	Approved			2.438	Approved	m		0.058	Approved	mg/L	-92.90332792	45.06868739onitoring Program (CAMP) for Lakes	Woodpile Lake	Grant Township	Washington	82013200-01	Lower St. Croix River	Browns Creek WD	1	2008-09-23	9:54	2008-09-23	9:54	0				3	Approved		4	Approved			1.524	Approved	m		0.04	Approved	mg/L	-92.90332792	45.06868739ved		4	Approved			2.438	Approved	m		0.037	Approved	mg/L	-92.90332792	45.06868739	82013200-01	Lower St. Croix River	Browns Creek WD	1	2010-09-01	11:48	2010-09-01	11:48	0				2	Approved		2	Approved			0.61	Approved	m		0.079	Approved	mg/L	-92.90332792	45.06868739 River	Browns Creek WD	1	2011-07-18	8:25	2011-07-18	8:25	0				2	Approved		2	Approved			6.4	Approved	m		0.038	Approved	mg/L	-92.90332792	45.06868739akes	Woodpile Lake	Grant Township	Washington	82013200-01	Lower St. Croix River	Browns Creek WD	1	2012-07-24	10:19	2012-07-24	10:19	0				2	Approved		2	Approved			1.67	Approved	m		0.045	Approved	mg/L	-92.90332792	45.06868739ed	mg/L	-92.90332792	45.0686873925	14:15	2014-08-25	14:15	0				2	Approved		2	Approved			2.74	Approved	m		0.026	Approved	mg/L	-92.90332792	45.0686873917oved	m		0.005	Approved	mg/L	-93.66768906	44.88381717-21	8:40	1990-09-21	8:40	7													m		0.005	Approved	mg/L	-93.66768906	44.883817174100-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	2002-08-05	0:00	2002-08-05	0:00	0											1.2	Approved	m	~	0.025	Approved	mg/L	-93.66768906	44.88381717

# %% [markdown]
# #### Problem 2
#
# Sometimes the easiest way to deal with a problematic file is to open it in JMP or Excel then save it using that program.  Use JMP to read in `mces_lakes_1999_2014.txt` and export/save it as a csv file.
#
# 1. On a Mac, you will select **File > Export > Text File**.  The default setting are fine here, just change the file extension from `dat` to `csv` to clearly communicate the format.
# 2. On a PC, you will select **File > Save As** and change the output type to csv.
#
# Now read this new version of the file using `pandas`. **Make sure you read the `latitude` and `longitude` columns as string!**

# %%
import pandas as pd
mces_lakes_iter = pd.read_csv('../MinneMUDACProject1/MinneMUDAC_raw_files/mces_lakes_1999_2014.csv')
mces_lakes_iter.dtypes
# Out:
# /home/fs5518xn/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (16,19,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# PROJECT_ID                              int64
# DATA_SET_TITLE                         object
# LAKE_NAME                              object
# CITY                                   object
# COUNTY                                 object
# DNR_ID_Site_Number                     object
# MAJOR_WATERSHED                        object
# WATER_PLANNING_AUTHORITY               object
# LAKE_SITE_NUMBER                        int64
# START_DATE                             object
# START_HOURMIN24                        object
# END_DATE                               object
# END_HOURMIN24                          object
# SAMPLE_DEPTH_IN_METERS                float64
# Seasonal_Lake_Grade_RESULT            float64
# Seasonal_Lake_Grade_QUALIFIER          object
# Seasonal_Lake_Grade_Units              object
# Physical_Condition_RESULT             float64
# Physical_Condition_QUALIFIER           object
# Physical_Condition_Units               object
# Recreational_Suitability_RESULT       float64
# Recreational_Suitability_QUALIFIER     object
# Recreational_Suitability_Units         object
# Secchi_Depth_RESULT_SIGN               object
# Secchi_Depth_RESULT                   float64
# Secchi_Depth_QUALIFIER                 object
# Secchi_Depth_Units                     object
# Total_Phosphorus_RESULT_SIGN           object
# Total_Phosphorus_RESULT               float64
# Total_Phosphorus_QUALIFIER             object
# Total_Phosphorus_Units                 object
# longitude                             float64
# latitude                              float64
# dtype: object

# %%
date_cols = ['START_DATE','END_DATE']
from toolz import first
mces_lakes_iter = pd.read_csv('../MinneMUDACProject1/MinneMUDAC_raw_files/mces_lakes_1999_2014.csv',
                     parse_dates=date_cols)
mces_lakes_iter.longitude = mces_lakes_iter.longitude.astype(str)
mces_lakes_iter.latitude = mces_lakes_iter.latitude.astype(str)
mces_lakes_iter.dtypes
# Out:
# /home/fs5518xn/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (16,19,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# PROJECT_ID                                     int64
# DATA_SET_TITLE                                object
# LAKE_NAME                                     object
# CITY                                          object
# COUNTY                                        object
# DNR_ID_Site_Number                            object
# MAJOR_WATERSHED                               object
# WATER_PLANNING_AUTHORITY                      object
# LAKE_SITE_NUMBER                               int64
# START_DATE                            datetime64[ns]
# START_HOURMIN24                               object
# END_DATE                              datetime64[ns]
# END_HOURMIN24                                 object
# SAMPLE_DEPTH_IN_METERS                       float64
# Seasonal_Lake_Grade_RESULT                   float64
# Seasonal_Lake_Grade_QUALIFIER                 object
# Seasonal_Lake_Grade_Units                     object
# Physical_Condition_RESULT                    float64
# Physical_Condition_QUALIFIER                  object
# Physical_Condition_Units                      object
# Recreational_Suitability_RESULT              float64
# Recreational_Suitability_QUALIFIER            object
# Recreational_Suitability_Units                object
# Secchi_Depth_RESULT_SIGN                      object
# Secchi_Depth_RESULT                          float64
# Secchi_Depth_QUALIFIER                        object
# Secchi_Depth_Units                            object
# Total_Phosphorus_RESULT_SIGN                  object
# Total_Phosphorus_RESULT                      float64
# Total_Phosphorus_QUALIFIER                    object
# Total_Phosphorus_Units                        object
# longitude                                     object
# latitude                                      object
# dtype: object

# %%
mces_lakes_iter.head()
# Out:
#    PROJECT_ID                                     DATA_SET_TITLE   LAKE_NAME  \
# 0        7108  Citizen Assisted Monitoring Program (CAMP) for...  Acorn Lake
# 1        7108  Citizen Assisted Monitoring Program (CAMP) for...  Acorn Lake
# 2        7108  Citizen Assisted Monitoring Program (CAMP) for...  Acorn Lake
# 3        7108  Citizen Assisted Monitoring Program (CAMP) for...  Acorn Lake
# 4        7108  Citizen Assisted Monitoring Program (CAMP) for...  Acorn Lake
#
#       CITY      COUNTY DNR_ID_Site_Number        MAJOR_WATERSHED  \
# 0  Oakdale  Washington        82010200-01  Lower St. Croix River
# 1  Oakdale  Washington        82010200-01  Lower St. Croix River
# 2  Oakdale  Washington        82010200-01  Lower St. Croix River
# 3  Oakdale  Washington        82010200-01  Lower St. Croix River
# 4  Oakdale  Washington        82010200-01  Lower St. Croix River
#
#   WATER_PLANNING_AUTHORITY  LAKE_SITE_NUMBER START_DATE  ...  \
# 0         Valley Branch WD                 1 2006-04-16  ...
# 1         Valley Branch WD                 1 2006-05-01  ...
# 2         Valley Branch WD                 1 2006-05-02  ...
# 3         Valley Branch WD                 1 2006-05-16  ...
# 4         Valley Branch WD                 1 2006-05-30  ...
#
#   Secchi_Depth_RESULT_SIGN Secchi_Depth_RESULT Secchi_Depth_QUALIFIER  \
# 0                      NaN                1.00               Approved
# 1                      NaN                 NaN                    NaN
# 2                      NaN                0.66               Approved
# 3                      NaN                0.66               Approved
# 4                      NaN                0.50               Approved
#
#    Secchi_Depth_Units  Total_Phosphorus_RESULT_SIGN Total_Phosphorus_RESULT  \
# 0                   m                           NaN                   0.156
# 1                   m                           NaN                     NaN
# 2                   m                           NaN                   0.107
# 3                   m                           NaN                   0.141
# 4                   m                           NaN                   0.029
#
#   Total_Phosphorus_QUALIFIER  Total_Phosphorus_Units     longitude  \
# 0                   Approved                    mg/L  -92.97171054
# 1                        NaN                    mg/L  -92.97171054
# 2                   Approved                    mg/L  -92.97171054
# 3                   Approved                    mg/L  -92.97171054
# 4                   Approved                    mg/L  -92.97171054
#
#       latitude
# 0  45.01655642
# 1  45.01655642
# 2  45.01655642
# 3  45.01655642
# 4  45.01655642
#
# [5 rows x 33 columns]

# %% [markdown]
# #### Problem 3
#
# Now we want to read in the file `Parcel_Lake_Monitoring_Site_Xref.txt`, which is as cross-reference (Xref) file that is used to make the bridge between the parcel data and the lakes data.
#
# 1. Use `!head` to inspect the file and determine the details of it's format (header?, sep=?, etc.).
# 2. Read the file using `pandas`.

# %%
# !head ../MinneMUDACProject1/MinneMUDAC_raw_files/Parcel_Lake_Monitoring_Site_Xref.txt
# Out:
# Parcel_PIN	Monit_MAP_CODE1	Monit_SITE_CODE	Monit_LAKE_SITE	Distance_Parcel_Monitoring_Site_meters	Lake_Hydroid	Distance_Parcel_Lake_meters	centroid_long	centroid_lat	Parcel_pkey
# 	19007900-01	19007900	1	2815.4927104148851	110517277058	2571.5267922258381	-93.11451	44.94283	2163034
# 	19007900-01	19007900	1	2753.4746875312162	110517277058	2515.3738022144425	-93.11539	44.94234	2163035
# 	19007900-01	19007900	1	2748.8106650822624	110517277058	2511.9249588634261	-93.11556	44.94231	2163036
# 	19007900-01	19007900	1	2738.7500558227048	110517277058	2502.9916401143814	-93.11572	44.94223	2163037
# 	19007900-01	19007900	1	2700.5414124735426	110517277058	2465.2062339003005	-93.1158	44.94189	2163038
# 	19007900-01	19007900	1	2890.2197211400312	110517277058	2631.4612562849106	-93.11218	44.94325	2163039
# 	19007900-01	19007900	1	3338.9566080000855	110517277058	3074.8658002505599	-93.11036	44.94711	2163040
# 	19007900-01	19007900	1	3338.129273460172	110517277058	3074.6709497432862	-93.11048	44.94712	2163041
# 	19007900-01	19007900	1	3304.2646291849906	110517277058	3040.0914556198632	-93.11042	44.9468	2163042

# %%
par_iter = pd.read_csv('../MinneMUDACProject1/MinneMUDAC_raw_files/Parcel_Lake_Monitoring_Site_Xref.txt',
                      header =0, sep= '\t')
par_iter.centroid_lat = par_iter.centroid_lat.astype(str)
par_iter.centroid_long = par_iter.centroid_long.astype(str)
par_iter.dtypes
# Out:
# Parcel_PIN                                float64
# Monit_MAP_CODE1                            object
# Monit_SITE_CODE                             int64
# Monit_LAKE_SITE                             int64
# Distance_Parcel_Monitoring_Site_meters    float64
# Lake_Hydroid                                int64
# Distance_Parcel_Lake_meters               float64
# centroid_long                              object
# centroid_lat                               object
# Parcel_pkey                                 int64
# dtype: object

# %%
par_iter.head()
# Out:
#    Parcel_PIN Monit_MAP_CODE1  Monit_SITE_CODE  Monit_LAKE_SITE  \
# 0         NaN     19007900-01         19007900                1
# 1         NaN     19007900-01         19007900                1
# 2         NaN     19007900-01         19007900                1
# 3         NaN     19007900-01         19007900                1
# 4         NaN     19007900-01         19007900                1
#
#    Distance_Parcel_Monitoring_Site_meters  Lake_Hydroid  \
# 0                             2815.492710  110517277058
# 1                             2753.474688  110517277058
# 2                             2748.810665  110517277058
# 3                             2738.750056  110517277058
# 4                             2700.541412  110517277058
#
#    Distance_Parcel_Lake_meters centroid_long centroid_lat  Parcel_pkey
# 0                  2571.526792     -93.11451     44.94283      2163034
# 1                  2515.373802     -93.11539     44.94234      2163035
# 2                  2511.924959     -93.11556     44.94231      2163036
# 3                  2502.991640     -93.11572     44.94223      2163037
# 4                  2465.206234      -93.1158     44.94189      2163038

# %% [markdown]
# #### Problem 4
#
# We need to find a way to link these two files.  Inspect the columns for each file and suggest a column from each that can be used to make a link.

# %% [markdown]
# > *Your thoughts here*

# %% [markdown]
# #### Problem 5
#
# Let's investigate these columns and use `set`s to explore.
#
# 1. For each file, make a `set` of the contents of the respective file.
# 2. Explore the relationship between the files using `intersection` and `difference`.
#
# What did you learn about these columns in regards to using them as a link between the files?  Any problems?

# %%
# Your code here

# %% [markdown]
# > *Your thoughts here*

# %% [markdown]
# #### Problem 6
#
# Use group_by/aggregation to investigate any missing keys.  Suggest some options for how we might proceed.

# %%
# Your code here

# %% [markdown]
# > *Your thoughts here*

# %% [markdown]
# #### Problem 7
#
# Use select/group_by/aggregation to reduce the lakes table to a table with one row per lake that contains the lake name and corresponding code.

# %%
# Your code here

# %% [markdown]
# #### Problem 8
#
# Make a `dict` that with the lake id as the key and the lake name as the value.  You will want to zip the columns from the last table together and use a `dict` comp.

# %%
# Your code here

# %% [markdown]
# #### Problem 9
#
# Now we want to link the Xref file to the parcel files, which will be done by matching the latitudes and longitudes in the parcel files to `xref.latitude` and `xref.longitude`.  First, let's investigate the relationship between these columns.
#
# 1. Make a `set` of lat/long tuples from the Xref file.<br>
# 2. Make a list of lat/long sets, one for each chunk of each parcel file for 2004+.  Do this with a list comprehension that uses double for clauses.
# 3. Reduce the sets in the list to one set using the union to combine sets.
# 4. Investigate the relationship between the lat/long pairs from the two types of files.  Are there any missing on either side? How many?
#
# Discuss what you have learned and suggest how we might proceed.

# %%
# Your code here

# %% [markdown]
# > *Your thoughts here*

# %% [markdown]
# #### Problem 10
#
# Use select/group_by/aggregation to reduce the lakes table to a table with one row per lake that contains latitude, longitude, and the lake ID code.

# %%
# Your code here

# %% [markdown]
# #### Problem 11
#
# Make a `dict` that with the (lat, long) tuple as the key and the lake code as the value.  You will want to zip the columns from the last table together and use a `dict` comp.

# %%
# Your code here

# %% [markdown]
# #### Problem 12
#
# Now make a `dict` that combines the last two `dict`s into a single `dict` that translates the lat/long tuple into a lake name.

# %%
# Your code here
