# %% [markdown]
# # Project 1 Part 2
#
#
# In this part of the project, you will create `dict`s to link the parcel/property data to the lakes data.  Then we will use `panda`’s to
#
# a. Read each parcel file
# b. Add a column containing the nearest lake
# c. Write the result to a new file.
#
# To accomplish this task, complete the following steps.

# %% [markdown]
# #### Problem 1
#
# Now we want to read in the file `mces_lakes_1999_2014.txt`, which contains water quality measurements for all lakes in the Twin Cities are during the listed years.
#
# Use `!head` to inspect the file and determine the details of it's format (header?, sep=?, etc.).

# %%
# !head ../MinneMUDACProject1/MinneMUDAC_raw_files/mces_lakes_1999_2014.txt
# Out:
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Alimag
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Armstrong Lake	Oakdale	Washington	82011602-01	Mississippi River - Twin Cities	South Washington WD	1	2010-05-01	0:00	2
# 7105	Lakes Monitoring	Bald Eagle Lake	White Bear Township	Ramsey	62000200-01	Mississippi River - Twin Cities	Rice Creek WD	1	2004-09-02	0
# 7108	Citizen
# 7105	Lakes Monitoring	Bavaria Lake	Chaska	Carver	10001900-01	Lower Minnesota River
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Benton Lake	Cologne	Carver	10006900-01	Lower Minnesota River	Carver County WMO	1	1999-05-11	11:20	1999-05-11	11:20	0				2	Approved
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Benz Lake	Grant	Washington	82012000-01	Lower St. Croix River	Browns Creek WD	1	2012-07-09	15:26	2012-07-09	15:26	0				3	Approved		4	Appr
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Big Carnelian Lake	May Township	Washington	82004900-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2014-09-04	8:39	2014-09-
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Big Marine Lake	May Township	Washington	82005204-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2005-07-06	0:00	2005-
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Bone Lake	Scandia	Washington	82005400-01	Lower St. Croix River	Comfort Lake-Forest Lake WD	1	2013-07-31	13:
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Burandt Lake	Waconia	Carver	10008400-01	Lower Minnesota River	Carver County WMO	1	1999-07-25	19:30	1999-07-25	19:30	0				3	Approved
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Byllesby Lake	S
# 7108	Citizen Assisted Monitoring Pro
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Cedar Lake	Cedar Lake T
# 7105	Lakes Monitoring	Centerville Lake	Lino Lakes	Anoka	02000600-01	Mississippi River - Twin Cities	Rice Cree
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Clear Lake	Forest Lake Township	Washington	82016300-01	Mississippi River - Twin Cities	Rice Creek WD	1	2002-05-13	0:00	2002-05-13	0:00	0				1	Approved		2	Appr
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Cobblecrest Lake	St. Louis Park	Hennepin	27005300-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	2008-06-15	22:30	2008-06-15	22:30
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Colby Lake	Woodbury	Washington	82009400-01	Missis
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Courthouse Lake	Chaska	Carver	10000500-01	Lower Minnesota Rive
# 7105	Lakes Monitoring	Crystal Lake	Burnsville	Dakota	19002700-01	Lower Minnesota River	Blac
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Crystal Lake	Burnsville	Dakota	19002700-01	Lower M
# 7105	Lakes Monitoring	DeMontreville Lake	Lake Elmo	Washington	82010100-01	Lower St. Croix River	Valley Branch WD	1	1995-08-31	9:35	1995-08-31	9:35	4													m		0.05	Approved	mg/
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Goose Lake	Lake Elmo	Washington	82011301-01	L
# 7105	Lakes Monitoring	Lower Prior Lake	Prior Lake	Scott	70002600-01	Lower Minnesota River	Prior Lake-Spring Lake WD	1
01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	2002-10-14	0:00	2002-10-14	0:00	7													m	~	0.012	Approved	mg/L	-93.66768906	44.88381717.88381717177d			0.9	Approved	m		0.08	Approved	mg/L	-93.90614956	44.78311027d	m		0.056	Approved	mg/L	-93.2658604	44.74111827d Lake	Burnsville	Dakota	19002400-01	Lower Minnesota River	Black Dog WMO	1	2003-09-22	13:00	2003-09-22	13:00	0				4	Approved		4	Approved			0.84	Approved	m		0.071	Approved	mg/L	-93.2658604	44.74111827roved	m		0.059	Approved	mg/L	-93.2658604	44.74111827ver	Black Dog WMO	1	2005-10-08	0:00	2005-10-08	0:00	0				3	Approved		4	Approved			1.22	Approved	m		0.088	Approved	mg/L	-93.2658604	44.7411182708	Citizen Assisted Monitoring Program (CAMP) for Lakes	Wood Lake	Burnsville	Dakota	19002400-01	Lower Minnesota River	Black Dog WMO	1	2007-04-18	0:00	2007-04-18	0:00	0				2	Approved		4	Approved			2.6	Approved	m		0.024	Approved	mg/L	-93.2658604	44.7411182701	0:00	2008-09-30	0:00	0	2	Approved											m				mg/L	-93.2658604	44.74111827urnsville	Dakota	19002400-01	Lower Minnesota River	Black Dog WMO	1	2009-06-25	10:18	2009-06-25	10:18	0				3	Approved		4	Approved			2.73	Approved	m		0.02	Approved	mg/L	-93.2658604	44.74111827proved	m		0.049	Approved	mg/L	-93.2658604	44.74111827	Wood Lake	Burnsville	Dakota	19002400-01	Lower Minnesota River	Black Dog WMO	1	2012-06-26	17:30	2012-06-26	17:30	0				3	Approved		2	Approved			1	Approved	m		0.073	Approved	mg/L	-93.2658604	44.74111827033	Approved	mg/L	-93.2658604	44.74111827ing Program (CAMP) for Lakes	Woodpile Lake	Grant Township	Washington	82013200-01	Lower St. Croix River	Browns Creek WD	1	2010-05-26	11:45	2010-05-26	11:45	0				3	Approved		3	Approved			4.57	Approved	m		0.025	Approved	mg/L	-92.90332792	45.0686873925	14:15	2014-08-25	14:15	0				2	Approved		2	Approved			2.74	Approved	m		0.026	Approved	mg/L	-92.90332792	45.06868739oved	m		0.005	Approved	mg/L	-93.66768906	44.88381717D	1	2002-10-01	0:00	2002-10-01	0:00	8													m	~	0.015	Approved	mg/L	-93.66768906	44.88381717

# %% [markdown]
# #### Problem 2
#
# Sometimes the easiest way to deal with a problematic file is to open it in JMP or Excel then save it using that program.  Use JMP to read in `mces_lakes_1999_2014.txt` and export/save it as a csv file.
#
# 1. On a Mac, you will select **File > Export > Text File**.  The default setting are fine here, just change the file extension from `dat` to `csv` to clearly communicate the format.
# 2. On a PC, you will select **File > Save As** and change the output type to csv.
#
# Now read this new version of the file using `pandas`. **Make sure you read the `latitude` and `longitude` columns as string!**

# %%
df_iter = pd.read_csv('../MinneMUDACProject1/MinneMUDAC_raw_files/mces_lakes_1999_2014.csv')
.dtypes
# Out:
# /home/fs5518xn/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (16,19,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# PROJECT_ID                              int64
# DATA_SET_TITLE                         object
# LAKE_NAME                              object
# CITY                                   object
# COUNTY                                 object
# DNR_ID_Site_Number                     object
# MAJOR_WATERSHED                        object
# WATER_PLANNING_AUTHORITY               object
# LAKE_SITE_NUMBER                        int64
# START_DATE                             object
# START_HOURMIN24                        object
# END_DATE                               object
# END_HOURMIN24                          object
# SAMPLE_DEPTH_IN_METERS                float64
# Seasonal_Lake_Grade_RESULT            float64
# Seasonal_Lake_Grade_QUALIFIER          object
# Seasonal_Lake_Grade_Units              object
# Physical_Condition_RESULT             float64
# Physical_Condition_QUALIFIER           object
# Physical_Condition_Units               object
# Recreational_Suitability_RESULT       float64
# Recreational_Suitability_QUALIFIER     object
# Recreational_Suitability_Units         object
# Secchi_Depth_RESULT_SIGN               object
# Secchi_Depth_RESULT                   float64
# Secchi_Depth_QUALIFIER                 object
# Secchi_Depth_Units                     object
# Total_Phosphorus_RESULT_SIGN           object
# Total_Phosphorus_RESULT               float64
# Total_Phosphorus_QUALIFIER             object
# Total_Phosphorus_Units                 object
# longitude                             float64
# latitude                              float64
# dtype: object

# %%
new_types = {'longitude': str, 'latitude' : str}
d

# %% [markdown]
# #### Problem 3
#
# Now we want to read in the file `Parcel_Lake_Monitoring_Site_Xref.txt`, which is as cross-reference (Xref) file that is used to make the bridge between the parcel data and the lakes data.
#
# 1. Use `!head` to inspect the file and determine the details of it's format (header?, sep=?, etc.).
# 2. Read the file using `pandas`.

# %%
# Your code here

# %% [markdown]
# #### Problem 4
#
# We need to find a way to link these two files.  Inspect the columns for each file and suggest a column from each that can be used to make a link.

# %% [markdown]
# > *Your thoughts here*

# %% [markdown]
# #### Problem 5
#
# Let's investigate these columns and use `set`s to explore.
#
# 1. For each file, make a `set` of the contents of the respective file.
# 2. Explore the relationship between the files using `intersection` and `difference`.
#
# What did you learn about these columns in regards to using them as a link between the files?  Any problems?

# %%
# Your code here

# %% [markdown]
# > *Your thoughts here*

# %% [markdown]
# #### Problem 6
#
# Use group_by/aggregation to investigate any missing keys.  Suggest some options for how we might proceed.

# %%
# Your code here

# %% [markdown]
# > *Your thoughts here*

# %% [markdown]
# #### Problem 7
#
# Use select/group_by/aggregation to reduce the lakes table to a table with one row per lake that contains the lake name and corresponding code.

# %%
# Your code here

# %% [markdown]
# #### Problem 8
#
# Make a `dict` that with the lake id as the key and the lake name as the value.  You will want to zip the columns from the last table together and use a `dict` comp.

# %%
# Your code here

# %% [markdown]
# #### Problem 9
#
# Now we want to link the Xref file to the parcel files, which will be done by matching the latitudes and longitudes in the parcel files to `xref.latitude` and `xref.longitude`.  First, let's investigate the relationship between these columns.
#
# 1. Make a `set` of lat/long tuples from the Xref file.<br>
# 2. Make a list of lat/long sets, one for each chunk of each parcel file for 2004+.  Do this with a list comprehension that uses double for clauses.
# 3. Reduce the sets in the list to one set using the union to combine sets.
# 4. Investigate the relationship between the lat/long pairs from the two types of files.  Are there any missing on either side? How many?
#
# Discuss what you have learned and suggest how we might proceed.

# %%
# Your code here

# %% [markdown]
# > *Your thoughts here*

# %% [markdown]
# #### Problem 10
#
# Use select/group_by/aggregation to reduce the lakes table to a table with one row per lake that contains latitude, longitude, and the lake ID code.

# %%
# Your code here

# %% [markdown]
# #### Problem 11
#
# Make a `dict` that with the (lat, long) tuple as the key and the lake code as the value.  You will want to zip the columns from the last table together and use a `dict` comp.

# %%
# Your code here

# %% [markdown]
# #### Problem 12
#
# Now make a `dict` that combines the last two `dict`s into a single `dict` that translates the lat/long tuple into a lake name.

# %%
# Your code here
