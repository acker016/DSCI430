# %% [markdown]
# # Project 1 Part 2
#
#
# In this part of the project, you will create `dict`s to link the parcel/property data to the lakes data.  Then we will use `panda`’s to
#
# a. Read each parcel file
# b. Add a column containing the nearest lake
# c. Write the result to a new file.
#
# To accomplish this task, complete the following steps.

# %% [markdown]
# #### Problem 1
#
# Now we want to read in the file `mces_lakes_1999_2014.txt`, which contains water quality measurements for all lakes in the Twin Cities are during the listed years.
#
# Use `!head` to inspect the file and determine the details of it's format (header?, sep=?, etc.).

# %%
# !head ../MinneMUDACProject1/MinneMUDAC_raw_files/mces_lakes_1999_2014.txt
# Out:
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Alimagnet Lake	Burnsville	Dakota	19002100-01	Mississippi River - Lake
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Armstrong Lake	Oakdale	Washington	82011602-01	Mississippi River - Twin Cities	South Washington WD	1	2006-06-23	0:00	2006-06-23	0:00	0
# 7105	Lakes Monitoring	Bald Eagle Lake	White Bear Township	Ramsey	62000200-01	Mississippi River - Twin Cities	Rice Creek WD	1	2004-09-02	0
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Bass Lake	Grant	Washington	82012300-01	Lower St. Croix River	Browns Creek WD	1	2009-05-06	11:15	2009-05-06	11:15	0			0-4 Categorical Calculated Seasonally: 4 good & 0 bad	2	Approved	1-5 Categorical: 1
# 7105	Lakes Monitoring	Bavaria Lake	Chaska	Carver	10001900-01	Lower Minnesota River	Carver County WMO	1	1987-07-21	9:35	1987-07-21	9:35	13			0-4 Categorical Calculate
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Bavaria Lake	Chaska	Carver	10001900-01	Lower Minnesota River	Carver County WMO	1	2012-06-30	10:15	2012-06-30	10:15	0				4	Approved		3
# 7105	Lakes Monitoring	Crystal Lake	Burnsville	Dakota	19002700-01	Lower Minnesota River	Black Dog WMO	1	2012-12-03	14:50	2012-12-03	14:50	0				2	Approved		2	Approved			3.5	Approved	m				mg/L	-93.27036573	44.72296805d	m		0.028	Approved	mg/L	-93.27036573	44.72296805520835617777871066119.72101119199ogram (CAMP) for Lakes	Benz Lake	Grant	Washington	82012000-01	Lower St. Croix River	Browns Creek WD	1	2009-05-01	0:00	2009-09-30	0:00	0	1	Approved											m				mg/L	-92.89111722	45.11128554			m		0.02	Approved	mg/L	-92.94889445	45.32234969er	Comfort Lake-Forest Lake WD	1	2014-09-29	12:10	2014-09-29	12:10	0				2	Approved		2	Approved			1.2	Approved	m	~	0.007	Approved	mg/L	-92.94889445	45.32234969-06-25	0:00	2002-06-25	0:00	0							5	Approved					m		0.114	Approved	mg/L	-92.86574543	45.20886188 (CAMP) for Lakes	Big Marine Lake	May Township	Washington	82005204-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2013-08-29	13:46	2013-08-29	13:46	0				2	Approved		2	Approved			3.5	Approved	m		0.014	Approved	mg/L	-92.86574543	45.20886188Approved			2.75	Approved	m		0.047	Approved	mg/L	-92.86026082	45.28659868d Clayhole Lake	Chaska	Carver	10022500-01	Lower Minnesota River	Lower Minnesota River WD	1	2009-06-24	8:50	2009-06-24	8:50	0				1	Approved		1	Approved			4.5	Approved	m		0.013	Approved	mg/L	-93.59982271	44.7940071879043	Cannon River	North Cannon River WMO	3	2013-06-28	12:15	2013-06-28	12:15	0				3	Approved		4	Approved			0.4	Approved	m		0.203	Approved	mg/L	-92.97382842	44.5163533ssippi River - Twin Cities	Ramsey-Washington Metro WD	1	1988-08-23	9:55	1988-08-23	9:55	9													m		0.57	Approved	mg/L	-92.97989336	44.90598763g/L	-93.39037061	44.72747129ip	Scott	70009100-02	Lower Minnesota River	Scott WMO	2	2013-08-25	8:15	2013-08-25	8:15	0				2	Approved		2	Approved			0.7	Approved	m		0.247	Approved	mg/L	-93.51362198	44.59563088ed	mg/L	-93.54437165	44.89464656ogram (CAMP) for Lakes	Clear Lake	Forest Lake Township	Washington	82016300-01	Mississippi River - Twin Cities	Rice Creek WD	1	2004-05-25	0:00	2004-05-25	0:00	0											1.7	Approved	m		0.029	Approved	mg/L	-93.00000905	45.26003767 Lake	St. Louis Park	Hennepin	27005300-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	2013-06-19	15:30	2013-06-19	15:30	0				2	Approved		4	Approved			0.9	Approved	m		0.04	Approved	mg/L	-93.39348337	44.95013m (CAMP) for Lakes	Cornelia Lake	Edina	Hennepin	27002802-01	Lower Minnesota River	Nine Mile Creek WD	1	2003-05-24	0:00	2003-05-24	0:00	0				2	Approved		4	Approved			0.6	Approved	m		0.055	Approved	mg/L	-93.33952406	44.88277422	-93.34158462	45.20835617akes Monitoring	Crystal Lake	Burnsville	Dakota	19002700-01	Lower Minnesota River	Black Dog WMO	1	1997-06-23	9:15	1997-06-23	9:15	9													m		0.08	Approved	mg/L	-93.27036573	44.72296805
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 7105	Lakes Monitoring	Hydes Lake	Waconia
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	McDonald Lake	Baytown Township	Washington	82001000-01	Lower St. Croix River	Valley Branch WD	1	2005-08-07	0:00	2005-08-07	0:00	0				2	Approved		4	Approved			1.8	Approved	m		0.038	Approved	mg/L	-92.84392332	45.016962787809879997411277428786466363	1.5	Approved	m		0.17	Approved	mg/L	-93.87281084	44.814450971.3	Approved	m		0.051	Approved	mg/L	-93.87281084	44.814450970				2	Approved		2	Approved			1.9	Approved	m		0.033	Approved	mg/L	-93.87281084	44.81445097	2004-05-11	11:20	2004-05-11	11:20	0				3	Approved		2	Approved			1.5	Approved	m		0.038	Approved	mg/L	-93.87281084	44.81445097L	-93.87281084	44.81445097roved	mg/L	-93.87281084	44.814450978	Approved	mg/L	-93.87281084	44.81445097pproved			1.3	Approved	m		0.196	Approved	mg/L	-93.87281084	44.81445097			4	Approved		4	Approved			1.1	Approved	m		0.252	Approved	mg/L	-93.87281084	44.814450978	11:37	2011-09-08	11:37	0				3	Approved		3	Approved			1.5	Approved	m		0.103	Approved	mg/L	-93.87281084	44.81445097	Hydes Lake	Waconia Township	Carver	10008800-01	Lower Minnesota River	Carver County WMO	1	2012-08-21	9:50	2012-08-21	9:50	0													m		0.118	Approved	mg/L	-93.87281084	44.81445097h Fork Crow River	Pioneer-Sarah Creek WMC	1	1983-05-05	11:32	1983-05-05	11:32	9													m		0.05	Approved	mg/L	-93.64602759	45.02692955							m		0.81	Approved	mg/L	-93.64602759	45.026929551439ower St. Croix River	Sunrise River WMO	1	2005-08-15	0:00	2005-08-15	0:00	0				2	Approved		2	Approved			1.3	Approved	m		0.017	Approved	mg/L	-93.09488494	45.36691861a	02002200-01	Lower St. Croix River	Sunrise River WMO	1	2007-09-06	9:00	2007-09-06	9:00	0				2	Approved						1.9	Approved	m		0.016	Approved	mg/L	-93.09488494	45.3669186191-09-16	9:40	10													m		0.12	Approved	mg/L	-92.92227254	45.01606807 Lake	Arden Hills	Ramsey	62007800-01	Mississippi River - Twin Cities	Rice Creek WD	1	1985-08-08	10:17	1985-08-08	10:17	11													m		0.41	Approved	mg/L	-93.17432065	45.04380898	2000-06-12	0:00	0							4	Approved			0.6	Approved	m		0.08	Approved	mg/L	-93.61649595	45.080409620	2006-09-06	0:00	0													m		0.812	Approved	mg/L	-92.90761071	45.12373418091	Approved	mg/L	-92.90761071	45.12373418g Program (CAMP) for Lakes	July Lake	Hugo - Grant	Washington	82031800-01	Lower St. Croix River	Browns Creek WD	1	2011-06-06	9:22	2011-06-06	9:22	0				3	Approved		4	Approved			1.07	Approved	m		0.089	Approved	mg/L	-92.90761071	45.12373418 Grant	Washington	82031800-01	Lower St. Croix River	Browns Creek WD	1	2012-05-30	10:12	2012-05-30	10:12	0				2	Approved		3	Approved			0.91	Approved	m		0.086	Approved	mg/L	-92.90761071	45.12373418Minnesota River	Black Dog WMO	1	2006-09-20	13:30	2006-09-20	13:30	0				3	Approved		4	Approved			0.75	Approved	m		0.061	Approved	mg/L	-93.2520238	44.72650508915576	44.7070964700	2007-09-30	0:00	0	2	Approved											m				mg/L	-92.8917326	45.09536417en Assisted Monitoring Program (CAMP) for Lakes	Kramer Pond	Lake Elmo	Washington	82011700-01	Lower St. Croix River	Valley Branch WD	1	2008-10-16	9:45	2008-10-16	9:45	0				4	Approved		4	Approved			0.152	Approved	m		0.472	Approved	mg/L	-92.89510948	44.95392659Lakes	Lac Lavon Lake	Apple Valley	Dakota	19044600-01	Lower Minnesota River	Black Dog WMO	1	2002-08-11	0:00	2002-08-11	0:00	0				2	Approved		1	Approved			2.6	Approved	m	~	0.012	Approved	mg/L	-93.24520003	44.720617086	13:25	2002-09-06	13:25	0				3	Approved		4	Approved			1	Approved	m	~	0.02	Approved	mg/L	-93.24047	45.12336446oved	mg/L	-93.28746428	44.71229881. Croix River	Comfort Lake-Forest Lake WD	1	2014-06-12	9:49	2014-06-12	9:49	0				2	Approved		2	Approved			1.37	Approved	m		0.013	Approved	mg/L	-92.85700713	45.30537008002300-01	Lower St. Croix River	Middle St. Croix River WMO	1	2008-10-20	9:06	2008-10-20	9:06	0				2	Approved		3	Approved			2.286	Approved	m		0.028	Approved	mg/L	-92.82307526	45.04910509	Approved			7.62	Approved	m		0.015	Approved	mg/L	-92.79566883	45.11864663ved		3	Approved			2.7	Approved	m		0.08	Approved	mg/L	-93.17263308	45.03504895k Crow  ...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Seidl Lake	Inver Grove Heights	Dakota	19009500-01	Mississippi River - Twin Cities	Lower Mississippi River WMO	1	2004-05-11	0:00	2004-05-11	0:00	0				2	Approved		4	Approved			1.37	Approved	m		0.191	Approved	mg/L	-93.05329582	44.88348937737248	Approved	mg/L	-93.49817264	44.85899641 Assisted Monitoring Program (CAMP) for Lakes	Mitchell Lake	Eden Prairie	Hennepin	27007000-01	Lower Minnesota River	Riley-Purgatory-Bluff Creek WD	1	2014-08-17	16:00	2014-08-17	16:00	0				1	Approved		1	Approved			1.3	Approved	m		0.03	Approved	mg/L	-93.49817264	44.85899641			0.31	Approved	m		0.19	Approved	mg/L	-92.87389184	45.18272507CAMP) for Lakes	North Twin Lake	Stillwater Township	Washington	82001800-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2013-05-22	10:50	2013-05-22	10:50	0				1	Approved		4	Approved					m		0.031	Approved	mg/L	-92.84712498	45.084581420	0				3	Approved		4	Approved			2.25	Approved	m		0.06	Approved	mg/L	-93.7948637	44.95543434	Approved			1.6	Approved	m		0.024	Approved	mg/L	-92.7886394	44.83029434Program (CAMP) for Lakes	O'Connors Lake	Denmark Township	Washington	82000200-01	Lower St. Croix River	South Washington WD	1	2014-05-20	16:00	2014-05-20	16:00	0				2	Approved		4	Approved			3	Approved	m		0.017	Approved	mg/L	-92.7886394	44.83029434	70009500-01	Lower Minnesota River	Scott WMO	1	1994-04-19	9:15	1994-04-19	9:15	6.5													m		0.02	Approved	mg/L	-93.5154039	44.7448931e	Scott	70009500-01	Lower Minnesota River	Scott WMO	1	1994-08-25	9:15	1994-08-25	9:15	4													m		0.09	Approved	mg/L	-93.5154039	44.7448931es Monitoring	O'Dowd Lake	Shakopee	Scott	70009500-01	Lower Minnesota River	Scott WMO	1	1997-07-21	10:30	1997-07-21	10:30	7													m		0.07	Approved	mg/L	-93.5154039	44.7448931oved	mg/L	-93.5154039	44.7448931				2.9	Approved	m	~	0.018	Approved	mg/L	-93.5154039	44.7448931a River	Scott WMO	1	2002-10-15	0:00	2002-10-15	0:00	0											2	Approved	m		0.064	Approved	mg/L	-93.5154039	44.7448931Shakopee	Scott	70009500-01	Lower Minnesota River	Scott WMO	1	2005-08-30	0:00	2005-08-30	0:00	0											0.7	Approved	m		0.063	Approved	mg/L	-93.5154039	44.7448931 Monitoring Program (CAMP) for Lakes	O'Dowd Lake	Shakopee	Scott	70009500-01	Lower Minnesota River	Scott WMO	1	2006-09-24	0:00	2006-09-24	0:00	0				2	Approved		2	Approved			1.2	Approved	m		0.043	Approved	mg/L	-93.5154039	44.7448931	O'Dowd Lake	Shakopee	Scott	70009500-01	Lower Minnesota River	Scott WMO	1	2007-10-15	12:54	2007-10-15	12:54	0				2	Approved		2	Approved			1.7	Approved	m		0.041	Approved	mg/L	-93.5154039	44.7448931ott	70009500-01	Lower Minnesota River	Scott WMO	1	2008-10-17	18:15	2008-10-17	18:15	0				2	Approved		2	Approved			1.9	Approved	m		0.033	Approved	mg/L	-93.5154039	44.7448931wer Minnesota River	Scott WMO	1	2009-10-17	14:30	2009-10-17	14:30	0				2	Approved		2	Approved			2	Approved	m		0.021	Approved	mg/L	-93.5154039	44.7448931oring Program (CAMP) for Lakes	Olson Lake	Lake Elmo	Washington	82010300-01	Lower St. Croix River	Valley Branch WD	1	2005-10-03	0:00	2005-10-03	0:00	0				3	Approved		3	Approved			1.372	Approved	m		0.04	Approved	mg/L	-92.94542621	45.01857051 Croix River	Valley Branch WD	1	2014-05-01	0:00	2014-09-30	0:00	0	4	Approved											m				mg/L	-92.94542621	45.01857051s Monitoring	Oneka Lake	Hugo	Washington	82014000-01	Mississippi River - Twin Cities	Rice Creek WD	1	1992-05-01	0:00	1992-09-30	0:00	0	3	Approved											m				mg/L	-92.96876765	45.1792351414Washington	82014000-01	Mississippi River - Twin Cities	Rice Creek WD	1	2012-09-18	17:30	2012-09-18	17:30	0				3	Approved		4	Approved					m		0.022	Approved	mg/L	-92.96876765	45.17923514:40	1981-08-06	10:40	0											2.8	Approved	m		0.02	Approved	mg/L	-93.31089353	44.7022537oved	m		0.045	Approved	mg/L	-93.31089353	44.7022537Approved	mg/L	-93.31089353	44.7022537d	mg/L	-93.31089353	44.7022537oved	mg/L	-93.31089353	44.7022537.7022537chard Lake	Lakeville	Dakota	19003100-01	Lower Minnesota River	Black Dog WMO	1	1998-10-14	9:30	1998-10-1 ...
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Sweeney Lake	Golden Valley	Hennepin	27003501-01	Mississippi River - Twin Cities	Bassett Creek WMC	1	2006-05-10	0:00	2006-05-10	0:00	0											1	Approved	m		0.039	Approved	mg/L	44.99052075ved	mg/L	-93.34160616	44.99052075755816882584233398-09-28	10:00	0				2	Approved		2	Approved			2	Approved	m		0.2	Approved	mg/L	-92.94485894	45.25287409/L	-92.98615998	45.028184846:55	0				1	Approved		2	Approved			1.1	Approved	m		0.05	Approved	mg/L	-93.04268875	44.83258423kes	Simley Lake	Inver Grove Heights	Dakota	19003700-01	Mississippi River - Twin Cities	Lower Mississippi River WMO	1	2013-06-14	11:50	2013-06-14	11:50	0				1	Approved		1	Approved			2.3	Approved	m		0.029	Approved	mg/L	-93.04268875	44.832584239:30	0				2	Approved		5	Approved			0.9	Approved	m		0.02	Approved	mg/L	-93.37042248	44.93426779	Approved		3	Approved			1	Approved	m		0.198	Approved	mg/L	-93.33291166	45.00574348eek WD	1	2009-10-13	9:00	2009-10-13	9:00	0				2	Approved		3	Approved			2.896	Approved	m		0.051	Approved	mg/L	-92.90602156	45.14138345South School Section Lake	Hugo	Washington	82015100-01	Lower St. Croix River	Browns Creek WD	1	2010-09-28	8:51	2010-09-28	8:51	0				2	Approved		3	Approved			1.07	Approved	m		0.061	Approved	mg/L	-92.90602156	45.14138345ram (CAMP) for Lakes	South School Section Lake	Hugo	Washington	82015100-01	Lower St. Croix River	Browns Creek WD	1	2011-08-29	8:32	2011-08-29	8:32	0				3	Approved		3	Approved			1.07	Approved	m		0.12	Approved	mg/L	-92.90602156	45.141383450602156	45.1413834508-21	10:05	2013-08-21	10:05	0				4	Approved		4	Approved			0.6	Approved	m		0.074	Approved	mg/L	-92.90602156	45.14138345llwater	Washington	82001900-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2001-07-17	0:00	2001-07-17	0:00	0				3	Approved		4	Approved			0.61	Approved	m		0.06	Approved	mg/L	-92.84708907	45.07817668	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2004-07-21	0:00	2004-07-21	0:00	0				2	Approved						2.591	Approved	m		0.034	Approved	mg/L	-92.84708907	45.0781766808	2006-05-31	14:08	0				3	Approved		3	Approved			1.829	Approved	m		0.071	Approved	mg/L	-92.84708907	45.078176682.84708907	45.078176681:56	2008-10-20	11:56	0				4	Approved		4	Approved			1.372	Approved	m		0.077	Approved	mg/L	-92.84708907	45.07817668m		0.042	Approved	mg/L	-92.84708907	45.07817668			3.2	Approved	m		0.29	Approved	mg/L	-93.46843381	44.7018106200	1982-04-22	1:00	0											1.2	Approved	m		0.123	Approved	mg/L	-93.46843381	44.701810624.70181062		1.2	Approved	m	~	0.05	Approved	mg/L	-93.46843381	44.70181062Lower Minnesota River	Prior Lake-Spring Lake WD	1	2006-05-01	0:00	2006-09-30	0:00	0	2	Approved											m				mg/L	-93.46843381	44.70181062Croix River	Carnelian-Marine-St. Croix WD	1	1982-05-27	2:00	1982-05-27	2:00	0											8.1	Approved	m		0.01	Approved	mg/L	-92.80441146	45.156747Monitoring	Square Lake	May Township	Washington	82004600-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	1983-08-25	11:50	1983-08-25	11:50	0											8.5	Approved	m		0.015	Approved	mg/L	-92.80441146	45.156747oix River	Carnelian-Marine-St. Croix WD	1	1993-07-21	19:00	1993-07-21	19:00	0				2	Approved		1	Approved			5	Approved	m		0.005	Approved	mg/L	-92.80441146	45.156747	1	Approved			6.1	Approved	m		0.01	Approved	mg/L	-92.80441146	45.156747	82004600-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	1999-08-05	8:00	1999-08-05	8:00	7													m		0.01	Approved	mg/L	-92.80441146	45.1567472.80441146	45.156747e-St. Croix WD	1	2000-10-02	0:00	2000-10-02	0:00	0				1	Approved		1	Approved			5.95	Approved	m		0.01	Approved	mg/L	-92.80441146	45.156747	1	Approved		1	Approved			7.01	Approved	m		0.009	Approved	mg/L	-92.80441146	45.1567472.80441146	45.156747MP) for Lakes	St. Joe Lake	Chanhassen	Carver	10001100-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	2004-04-18	0:00	2004-04-18	0:00	0				2	Approved		4	Approved			1.2	Approved	m		0.04	Approved	mg/L	-93.62296909	44.8756457-93.45387122	44.83822033win Cities	Minnehaha Creek WD	1	1995 ...
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Sweene
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Tamarack Lake
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Tamarack Lake	Victoria	Carver	10001000-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	2009-09-26	10:00	2009-09-26	10:00	0				1	Approved		1
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Wing Lake	Minnetonka	Hennepin	27009100-01	Lower Minnesota River	Nine Mile Creek WD	1	2013-07-30	18:50	2013-07-30	18:50	0				3	Approved		5	Approved			0.7	Approved	m		0.07	Approved	mg/L	-93.47439386	44.9026577224.9642803535992571144.963396955r - Twin Cities	Ramsey-Washington Metro WD	1	1994-06-17	16:30	1994-06-17	16:30	0											2.8	Approved	m		0.07	Approved	mg/L	-92.98107418	44.95041029s Lake	Oakdale	Washington	82011500-01	Mississippi River - Twin Cities	Ramsey-Washington Metro WD	1	1995-06-28	8:00	1995-06-28	8:00	0											3	Approved	m		0.08	Approved	mg/L	-92.98107418	44.95041029roved			3	Approved	m		0.02	Approved	mg/L	-92.98107418	44.95041029ng Program (CAMP) for Lakes	Terrapin Lake	May Township	Washington	82003100-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2006-08-29	0:00	2006-08-29	0:00	0													m		0.024	Approved	mg/L	-92.82016292	45.182276665.182276667-07	10:20	4													m		0.06	Approved	mg/L	-93.52933474	44.7378266476	Approved	mg/L	-93.52933474	44.73782664ownship	Washington	82003600-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2008-09-03	12:48	2008-09-03	12:48	0				2	Approved		3	Approved			1.067	Approved	m				mg/L	-92.8674582	45.17814441ed					m		0.471	Approved	mg/L	-92.8674582	45.17814441klyn Center	Hennepin	27004201-01	Mississippi River - Twin Cities	Shingle Creek WMC	1	1985-09-04	12:14	1985-09-04	12:14	0											1.1	Approved	m		0.065	Approved	mg/L	-93.33693618	45.17772432Twin Lake	Brooklyn Center	Hennepin	27004201-01	Mississippi River - Twin Cities	Shingle Creek WMC	1	1996-05-01	0:00	1996-09-30	0:00	0	0	Approved											m				mg/L	-93.33618999	45.05077632 (CAMP) for Lakes	Twin Lake	Brooklyn Center	Hennepin	27004201-01	Mississippi River - Twin Cities	Shingle Creek WMC	1	1997-06-12	12:00	1997-06-12	12:00	0				2	Approved		2	Approved			3.2	Approved	m		0.04	Approved	mg/L	-93.33618999	45.05077632er - Twin Cities	Shingle Creek WMC	1	2002-05-12	16:15	2002-05-12	16:15	0				2	Approved		4	Approved			1.6	Approved	m	~	0.023	Approved	mg/L	-93.33618999	45.05077632077632Citizen Assisted Monitoring Program (CAMP) for Lakes	Twin Lake	Brooklyn Center	Hennepin	27004201-01	Mississippi River - Twin Cities	Shingle Creek WMC	1	2006-09-21	0:00	2006-09-21	0:00	0				3	Approved		3	Approved			0.3	Approved	m		0.161	Approved	mg/L	-93.33618999	45.05077632007-06-24	0:00	0				3	Approved		4	Approved			0.7	Approved	m		0.117	Approved	mg/L	-93.33618999	45.05077632AMP) for Lakes	Twin Lake	Brooklyn Center	Hennepin	27004201-01	Mississippi River - Twin Cities	Shingle Creek WMC	1	2008-05-01	0:00	2008-09-30	0:00	0	2	Approved											m				mg/L	-93.33618999	45.05077632ississippi River - Twin Cities	Shingle Creek WMC	1	2009-08-02	16:00	2009-08-02	16:00	0				3	Approved		4	Approved			0.5	Approved	m		0.271	Approved	mg/L	-93.33618999	45.0507763227004201-01	Mississippi River - Twin Cities	Shingle Creek WMC	1	2012-10-21	18:00	2012-10-21	18:00	0													m		0.035	Approved	mg/L	-93.33618999	45.0507763244208405	44.71536216ssisted Monitoring Program (CAMP) for Lakes	Upper Prior Lake	Prior Lake	Scott	70007200-01	Lower Minnesota River	Prior Lake-Spring Lake WD	1	2002-07-14	0:00	2002-07-14	0:00	0				3	Approved		2	Approved			0.8	Approved	m		0.084	Approved	mg/L	-93.44208405	44.715362167153621696-06-03	19:00	1996-06-03	19:00	0				2	Approved		2	Approved			1.1	Approved	m		0.05	Approved	mg/L	-93.20902364	44.71508954-19	13:00	0				1	Approved		1	Approved			1.5	Approved	m		0.04	Approved	mg/L	-93.20902364	44.715089546	Approved	m				mg/L	-93.20902364	44.71508954akeville	Dakota	19034800-01	Mississippi River - Lake Pepin	Vermillion River Watershed JPO	1	2001-08-20	14:00	2001-08-20	14:00	0				2	Approved		3	Approved			2.1	Approved	m		0.06	Approved	mg/L	-93.20902364	44.71508954	2002-07-09	8:30	2002-07-09	8:30	0				3	Approved		4	Approved			1.2	Approved	m				mg/L	-93.20902364	44.71508954.058	Approved	mg/L	-93.20902364	44.71508954089541	Mississippi River - Lake Pepin	Vermillion River Watershed ...
# 7108	Citiz
# 7105	Lakes Monitoring	Zumbra Lake	Victoria	Carver	10004100-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	2002-10-14	0:00	2002-10-14	0:00	7													m	~	0.012	Approved	mg/L	-93.66768906	44.88381717.88381717177d			0.9	Approved	m		0.08	Approved	mg/L	-93.90614956	44.78311027	10006600-01	Lower Minnesota River	Carver County WMO	1	2011-05-01	0:00	2011-09-30	0:00	0	0	Approved											m				mg/L	-93.83268694	44.79006836River - Twin Cities	Minnehaha Creek WD	1	1980-07-07	9:05	1980-07-07	9:05	0											0.5	Approved	m		0.09	Approved	mg/L	-93.57203608	45.0052207	1997-05-05	10:40	1997-05-05	10:40	0				1	Approved		1	Approved			1.1	Approved	m		0.05	Approved	mg/L	-93.2658604	44.74111827ver	Black Dog WMO	1	2005-10-08	0:00	2005-10-08	0:00	0				3	Approved		4	Approved			1.22	Approved	m		0.088	Approved	mg/L	-93.2658604	44.74111827ing Program (CAMP) for Lakes	Woodpile Lake	Grant Township	Washington	82013200-01	Lower St. Croix River	Browns Creek WD	1	2010-05-26	11:45	2010-05-26	11:45	0				3	Approved		3	Approved			4.57	Approved	m		0.025	Approved	mg/L	-92.90332792	45.06868739Approved			1.98	Approved	m				mg/L	-92.90332792	45.06868739er	Browns Creek WD	1	2013-04-29	9:56	2013-04-29	9:56	0				2	Approved		2	Approved			3.35	Approved	m		0.039	Approved	mg/L	-92.90332792	45.06868739

# %% [markdown]
# #### Problem 2
#
# Sometimes the easiest way to deal with a problematic file is to open it in JMP or Excel then save it using that program.  Use JMP to read in `mces_lakes_1999_2014.txt` and export/save it as a csv file.
#
# 1. On a Mac, you will select **File > Export > Text File**.  The default setting are fine here, just change the file extension from `dat` to `csv` to clearly communicate the format.
# 2. On a PC, you will select **File > Save As** and change the output type to csv.
#
# Now read this new version of the file using `pandas`. **Make sure you read the `latitude` and `longitude` columns as string!**

# %%
import pandas as pd
df_iter = pd.read_csv('../MinneMUDACProject1/MinneMUDAC_raw_files/mces_lakes_1999_2014.csv')
df_iter.dtypes
# Out:
# /home/fs5518xn/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (16,19,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# PROJECT_ID                              int64
# DATA_SET_TITLE                         object
# LAKE_NAME                              object
# CITY                                   object
# COUNTY                                 object
# DNR_ID_Site_Number                     object
# MAJOR_WATERSHED                        object
# WATER_PLANNING_AUTHORITY               object
# LAKE_SITE_NUMBER                        int64
# START_DATE                             object
# START_HOURMIN24                        object
# END_DATE                               object
# END_HOURMIN24                          object
# SAMPLE_DEPTH_IN_METERS                float64
# Seasonal_Lake_Grade_RESULT            float64
# Seasonal_Lake_Grade_QUALIFIER          object
# Seasonal_Lake_Grade_Units              object
# Physical_Condition_RESULT             float64
# Physical_Condition_QUALIFIER           object
# Physical_Condition_Units               object
# Recreational_Suitability_RESULT       float64
# Recreational_Suitability_QUALIFIER     object
# Recreational_Suitability_Units         object
# Secchi_Depth_RESULT_SIGN               object
# Secchi_Depth_RESULT                   float64
# Secchi_Depth_QUALIFIER                 object
# Secchi_Depth_Units                     object
# Total_Phosphorus_RESULT_SIGN           object
# Total_Phosphorus_RESULT               float64
# Total_Phosphorus_QUALIFIER             object
# Total_Phosphorus_Units                 object
# longitude                             float64
# latitude                              float64
# dtype: object

# %%
new_types = {'longitude': str, 'latitude' : str}
from toolz import first
df_iter = pd.read_csv('../MinneMUDACProject1/MinneMUDAC_raw_files/mces_lakes_1999_2014.csv',
                     parse_dates = ['START_DATE', 'END_DATE'])
df_iter.dtypes
# Out:
# /home/fs5518xn/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (16,19,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    PROJECT_ID                                     DATA_SET_TITLE   LAKE_NAME  \
# 0        7108  Citizen Assisted Monitoring Program (CAMP) for...  Acorn Lake
# 1        7108  Citizen Assisted Monitoring Program (CAMP) for...  Acorn Lake
# 2        7108  Citizen Assisted Monitoring Program (CAMP) for...  Acorn Lake
# 3        7108  Citizen Assisted Monitoring Program (CAMP) for...  Acorn Lake
# 4        7108  Citizen Assisted Monitoring Program (CAMP) for...  Acorn Lake
#
#       CITY      COUNTY DNR_ID_Site_Number        MAJOR_WATERSHED  \
# 0  Oakdale  Washington        82010200-01  Lower St. Croix River
# 1  Oakdale  Washington        82010200-01  Lower St. Croix River
# 2  Oakdale  Washington        82010200-01  Lower St. Croix River
# 3  Oakdale  Washington        82010200-01  Lower St. Croix River
# 4  Oakdale  Washington        82010200-01  Lower St. Croix River
#
#   WATER_PLANNING_AUTHORITY  LAKE_SITE_NUMBER START_DATE  ...  \
# 0         Valley Branch WD                 1 2006-04-16  ...
# 1         Valley Branch WD                 1 2006-05-01  ...
# 2         Valley Branch WD                 1 2006-05-02  ...
# 3         Valley Branch WD                 1 2006-05-16  ...
# 4         Valley Branch WD                 1 2006-05-30  ...
#
#   Secchi_Depth_RESULT_SIGN Secchi_Depth_RESULT Secchi_Depth_QUALIFIER  \
# 0                      NaN                1.00               Approved
# 1                      NaN                 NaN                    NaN
# 2                      NaN                0.66               Approved
# 3                      NaN                0.66               Approved
# 4                      NaN                0.50               Approved
#
#    Secchi_Depth_Units  Total_Phosphorus_RESULT_SIGN Total_Phosphorus_RESULT  \
# 0                   m                           NaN                   0.156
# 1                   m                           NaN                     NaN
# 2                   m                           NaN                   0.107
# 3                   m                           NaN                   0.141
# 4                   m                           NaN                   0.029
#
#   Total_Phosphorus_QUALIFIER  Total_Phosphorus_Units  longitude   latitude
# 0                   Approved                    mg/L -92.971711  45.016556
# 1                        NaN                    mg/L -92.971711  45.016556
# 2                   Approved                    mg/L -92.971711  45.016556
# 3                   Approved                    mg/L -92.971711  45.016556
# 4                   Approved                    mg/L -92.971711  45.016556
#
# [5 rows x 33 columns]

# %% [markdown]
# #### Problem 3
#
# Now we want to read in the file `Parcel_Lake_Monitoring_Site_Xref.txt`, which is as cross-reference (Xref) file that is used to make the bridge between the parcel data and the lakes data.
#
# 1. Use `!head` to inspect the file and determine the details of it's format (header?, sep=?, etc.).
# 2. Read the file using `pandas`.

# %%
# Your code here

# %% [markdown]
# #### Problem 4
#
# We need to find a way to link these two files.  Inspect the columns for each file and suggest a column from each that can be used to make a link.

# %% [markdown]
# > *Your thoughts here*

# %% [markdown]
# #### Problem 5
#
# Let's investigate these columns and use `set`s to explore.
#
# 1. For each file, make a `set` of the contents of the respective file.
# 2. Explore the relationship between the files using `intersection` and `difference`.
#
# What did you learn about these columns in regards to using them as a link between the files?  Any problems?

# %%
# Your code here

# %% [markdown]
# > *Your thoughts here*

# %% [markdown]
# #### Problem 6
#
# Use group_by/aggregation to investigate any missing keys.  Suggest some options for how we might proceed.

# %%
# Your code here

# %% [markdown]
# > *Your thoughts here*

# %% [markdown]
# #### Problem 7
#
# Use select/group_by/aggregation to reduce the lakes table to a table with one row per lake that contains the lake name and corresponding code.

# %%
# Your code here

# %% [markdown]
# #### Problem 8
#
# Make a `dict` that with the lake id as the key and the lake name as the value.  You will want to zip the columns from the last table together and use a `dict` comp.

# %%
# Your code here

# %% [markdown]
# #### Problem 9
#
# Now we want to link the Xref file to the parcel files, which will be done by matching the latitudes and longitudes in the parcel files to `xref.latitude` and `xref.longitude`.  First, let's investigate the relationship between these columns.
#
# 1. Make a `set` of lat/long tuples from the Xref file.<br>
# 2. Make a list of lat/long sets, one for each chunk of each parcel file for 2004+.  Do this with a list comprehension that uses double for clauses.
# 3. Reduce the sets in the list to one set using the union to combine sets.
# 4. Investigate the relationship between the lat/long pairs from the two types of files.  Are there any missing on either side? How many?
#
# Discuss what you have learned and suggest how we might proceed.

# %%
# Your code here

# %% [markdown]
# > *Your thoughts here*

# %% [markdown]
# #### Problem 10
#
# Use select/group_by/aggregation to reduce the lakes table to a table with one row per lake that contains latitude, longitude, and the lake ID code.

# %%
# Your code here

# %% [markdown]
# #### Problem 11
#
# Make a `dict` that with the (lat, long) tuple as the key and the lake code as the value.  You will want to zip the columns from the last table together and use a `dict` comp.

# %%
# Your code here

# %% [markdown]
# #### Problem 12
#
# Now make a `dict` that combines the last two `dict`s into a single `dict` that translates the lat/long tuple into a lake name.

# %%
# Your code here
