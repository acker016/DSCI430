# %% [markdown]
# # Project 1 Part 2
#
#
# In this part of the project, you will create `dict`s to link the parcel/property data to the lakes data.  Then we will use `panda`’s to
#
# a. Read each parcel file
# b. Add a column containing the nearest lake
# c. Write the result to a new file.
#
# To accomplish this task, complete the following steps.

# %%
import pandas as pd
from dfply import *

# %% [markdown]
# #### Problem 1
#
# Now we want to read in the file `mces_lakes_1999_2014.txt`, which contains water quality measurements for all lakes in the Twin Cities are during the listed years.
#
# Use `!head` to inspect the file and determine the details of it's format (header?, sep=?, etc.).

# %%
# !head ../MinneMUDACProject1/MinneMUDAC_raw_files/mces_lakes_1999_2014.txt
# Out:
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Alim
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Armstrong Lake	Oakdale	Washington	82011602-01	Mississippi River - Twin
# 7105	Lakes Monitoring	Auburn Lake	Laketown Township	Carver	10004401-01	Mississippi River - Twin Cities	Minnehaha Creek WD	1	1991-08-09	11:15	1991-08-09	11:15	10			0-4 Categorical Calculated Seasonally: 4 good & 0 bad			1-5 Categorical: 1 good & 5 bad			1-5 Categorical: 1 good & 5 bad				m		0.12	Approved	mg/L	-93.69389292	44.86790
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Bass Lake	Grant	Washington	82012300-01	Lower St. Croix River	Browns Creek WD	1	1999-09-18	12:30	1999-09-18	12:30	0			0-4 Categorical Calculated Seasonally: 4 good & 0 bad	3	Approve
# 7108	Citizen Assisted Monit
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Battle Creek Lake	Woodbury	Wa
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Bavaria Lake	Chas
# 7108	Citizen Assisted Moni
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Benz Lake	Grant	Washington	82012000-01	Lower St. Croix River	Browns Creek WD	1	2011-07-06	8:53	2011-07-06	8:53	0				3	Approved		5	Approved			1.83	Approved	m		0.116	Approved	mg/L	-92.891
# 7105	Lakes Monitoring	Big Carnelian Lake	May Township	Washington	82004900-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	1994-07-14	9:25	1994-07-14	9:25	0											2	Approved	m		0.03	Approved	mg/L	-9
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Big Comfort Lake	Wyoming Township	Chisago	13005300-01	Lower St. Croix River	Comfort Lake-Forest La
# 7105	Lakes Monitoring	Big Marine Lake	May Township	Washington	82005204-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2011-08-31	13:30	2011-08-31	13:30	0				1	Approved		1	App
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Brickyard Clayhole Lake	Chaska	Carver	10022500-01	Lower Minnesota River	Lower Minnesota River WD	1	2005-04-29	0:00	2005-04-29	0:00	0				1	Approved		1	Approved			4.4	Approv
# 7105	Lakes Monitoring	Bryant Lake	Eden Prairie	Hennepin	27006700-01	Lower Minnesota River	Nine Mile Creek WD	1	1989-06-15	12:20	1989-06-15	12:20	0											1.4	Approve
# 7108	Citizen Assi
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Carol Lake	Stillwater Township	Washington	82001700-01	Lower St. Croix River	Carnelian-Marine-St. Croix WD	1	2004-05-01	0:00	2004-09-30	0:00	0	2	Approved
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Carver Lake	Woodbury	Washington	82016600-01	Mississippi River - Twin Cities	Ramsey-Washington Metro WD	1	1996-06-29	12:00	1996-06-29	12:00	0				3	Approved		2	Approved			1.7	Approved	m		0.03	Approved	mg/L	-
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Cedar Island Lake	Maple Grov
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Cenaiko La
# 7105	Lakes Monitoring	Centerville Lake	Lino Lakes	Anoka	02000600-01	Mississippi River - Twin Cities	Rice Creek WD	1	2003-05-01	0:00	2003-09-30	0:00	0	2
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	Chub Lake	Eureka Township	Dakota	19002000-01	Cannon River	North Cannon River WMO	1	1993-05-15	8:45	1993-05-15	8:45	0				2	Approved		3	Approved
# 7108	Citiz
# 7108	Citizen Assisted Monitoring Pro
# 7108	Citizen Assisted Monitoring Program (CAMP) for Lakes	
L	-93.72754301	44.93568243ngton	82016700-01	Mississippi River - Twin Cities	Rice Creek WD	1	1980-08-13	9:25	1980-08-13	9:25	0											2.3	Approved	m		0.02	Approved	mg/L	-92.98289597	45.07497798hite Rock Lake	Scandia	Washington	82007200-01	Mississippi River - Twin Cities	Rice Creek WD	1	2010-05-13	17:40	2010-05-13	17:40	0				1	Approved		1	Approved					m		0.045	Approved	mg/L	-92.89308991	45.22389054	0.048	Approved	mg/L	-92.89308991	45.22389054ississippi River - Twin Cities	Rice Creek WD	1	2012-05-01	0:00	2012-09-30	0:00	0	2	Approved											m				mg/L	-92.89308991	45.22389054007200-01	Mississippi River - Twin Cities	Rice Creek WD	1	2013-08-06	12:00	2013-08-06	12:00	0				2	Approved		2	Approved			1.2	Approved	m		0.047	Approved	mg/L	-92.89308991	45.22389054Approved	mg/L	-92.91260488	44.92794439for Lakes	Wilmes Lake	Woodbury	Washington	82009002-01	Mississippi River - Twin Cities	South Washington WD	1	1998-09-15	12:00	1998-09-15	12:00	0				2	Approved		2	Approved			1.9	Approved	m		0.04	Approved	mg/L	-92.91260488	44.92794439ved	mg/L	-92.91260488	44.92794439pproved	m		0.052	Approved	mg/L	-92.91260488	44.92794439mg/L	-92.91260488	44.92794439002-01	Mississippi River - Twin Cities	South Washington WD	1	2008-06-14	13:00	2008-06-14	13:00	0				2	Approved		2	Approved			1.3	Approved	m		0.063	Approved	mg/L	-92.91260488	44.92794439roved		2	Approved			1.4	Approved	m		0.078	Approved	mg/L	-92.91260488	44.92794439ram (CAMP) for Lakes	Wilmes Lake	Woodbury	Washington	82009002-01	Mississippi River - Twin Cities	South Washington WD	1	2010-10-03	14:30	2010-10-03	14:30	0				3	Approved		3	Approved			1.2	Approved	m		0.116	Approved	mg/L	-92.91260488	44.92794439shington WD	1	2012-04-22	15:00	2012-04-22	15:00	0				1	Approved		1	Approved			1.7	Approved	m		0.068	Approved	mg/L	-92.91260488	44.92794439itizen A ...

# %% [markdown]
# #### Problem 2
#
# Sometimes the easiest way to deal with a problematic file is to open it in JMP or Excel then save it using that program.  Use JMP to read in `mces_lakes_1999_2014.txt` and export/save it as a csv file.
#
# 1. On a Mac, you will select **File > Export > Text File**.  The default setting are fine here, just change the file extension from `dat` to `csv` to clearly communicate the format.
# 2. On a PC, you will select **File > Save As** and change the output type to csv.
#
# Now read this new version of the file using `pandas`. **Make sure you read the `latitude` and `longitude` columns as string!**

# %%
import pandas as pd
mces_lakes_iter = pd.read_csv('../MinneMUDACProject1/MinneMUDAC_raw_files/mces_lakes_1999_2014.csv')
mces_lakes_iter.dtypes
# Out:
# /home/fs5518xn/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (16,19,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# PROJECT_ID                              int64
# DATA_SET_TITLE                         object
# LAKE_NAME                              object
# CITY                                   object
# COUNTY                                 object
# DNR_ID_Site_Number                     object
# MAJOR_WATERSHED                        object
# WATER_PLANNING_AUTHORITY               object
# LAKE_SITE_NUMBER                        int64
# START_DATE                             object
# START_HOURMIN24                        object
# END_DATE                               object
# END_HOURMIN24                          object
# SAMPLE_DEPTH_IN_METERS                float64
# Seasonal_Lake_Grade_RESULT            float64
# Seasonal_Lake_Grade_QUALIFIER          object
# Seasonal_Lake_Grade_Units              object
# Physical_Condition_RESULT             float64
# Physical_Condition_QUALIFIER           object
# Physical_Condition_Units               object
# Recreational_Suitability_RESULT       float64
# Recreational_Suitability_QUALIFIER     object
# Recreational_Suitability_Units         object
# Secchi_Depth_RESULT_SIGN               object
# Secchi_Depth_RESULT                   float64
# Secchi_Depth_QUALIFIER                 object
# Secchi_Depth_Units                     object
# Total_Phosphorus_RESULT_SIGN           object
# Total_Phosphorus_RESULT               float64
# Total_Phosphorus_QUALIFIER             object
# Total_Phosphorus_Units                 object
# longitude                             float64
# latitude                              float64
# dtype: object

# %%
date_cols = ['START_DATE','END_DATE']
from toolz import first
mces_lakes_iter = pd.read_csv('../MinneMUDACProject1/MinneMUDAC_raw_files/mces_lakes_1999_2014.csv',
                     parse_dates=date_cols)
mces_lakes_iter.longitude = round(mces_lakes_iter.longitude, 5)
mces_lakes_iter.latitude = round(mces_lakes_iter.latitude, 5)
mces_lakes_iter.head()
# Out:
# /home/fs5518xn/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (16,19,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    PROJECT_ID                                     DATA_SET_TITLE   LAKE_NAME  \
# 0        7108  Citizen Assisted Monitoring Program (CAMP) for...  Acorn Lake
# 1        7108  Citizen Assisted Monitoring Program (CAMP) for...  Acorn Lake
# 2        7108  Citizen Assisted Monitoring Program (CAMP) for...  Acorn Lake
# 3        7108  Citizen Assisted Monitoring Program (CAMP) for...  Acorn Lake
# 4        7108  Citizen Assisted Monitoring Program (CAMP) for...  Acorn Lake
#
#       CITY      COUNTY DNR_ID_Site_Number        MAJOR_WATERSHED  \
# 0  Oakdale  Washington        82010200-01  Lower St. Croix River
# 1  Oakdale  Washington        82010200-01  Lower St. Croix River
# 2  Oakdale  Washington        82010200-01  Lower St. Croix River
# 3  Oakdale  Washington        82010200-01  Lower St. Croix River
# 4  Oakdale  Washington        82010200-01  Lower St. Croix River
#
#   WATER_PLANNING_AUTHORITY  LAKE_SITE_NUMBER START_DATE  ...  \
# 0         Valley Branch WD                 1 2006-04-16  ...
# 1         Valley Branch WD                 1 2006-05-01  ...
# 2         Valley Branch WD                 1 2006-05-02  ...
# 3         Valley Branch WD                 1 2006-05-16  ...
# 4         Valley Branch WD                 1 2006-05-30  ...
#
#   Secchi_Depth_RESULT_SIGN Secchi_Depth_RESULT Secchi_Depth_QUALIFIER  \
# 0                      NaN                1.00               Approved
# 1                      NaN                 NaN                    NaN
# 2                      NaN                0.66               Approved
# 3                      NaN                0.66               Approved
# 4                      NaN                0.50               Approved
#
#    Secchi_Depth_Units  Total_Phosphorus_RESULT_SIGN Total_Phosphorus_RESULT  \
# 0                   m                           NaN                   0.156
# 1                   m                           NaN                     NaN
# 2                   m                           NaN                   0.107
# 3                   m                           NaN                   0.141
# 4                   m                           NaN                   0.029
#
#   Total_Phosphorus_QUALIFIER  Total_Phosphorus_Units longitude  latitude
# 0                   Approved                    mg/L -92.97171  45.01656
# 1                        NaN                    mg/L -92.97171  45.01656
# 2                   Approved                    mg/L -92.97171  45.01656
# 3                   Approved                    mg/L -92.97171  45.01656
# 4                   Approved                    mg/L -92.97171  45.01656
#
# [5 rows x 33 columns]

# %%
mces_lakes_iter.longitude = mces_lakes_iter.longitude.astype(str)
mces_lakes_iter.latitude = mces_lakes_iter.latitude.astype(str)
mces_lakes_iter.dtypes
# Out:
# PROJECT_ID                                     int64
# DATA_SET_TITLE                                object
# LAKE_NAME                                     object
# CITY                                          object
# COUNTY                                        object
# DNR_ID_Site_Number                            object
# MAJOR_WATERSHED                               object
# WATER_PLANNING_AUTHORITY                      object
# LAKE_SITE_NUMBER                               int64
# START_DATE                            datetime64[ns]
# START_HOURMIN24                               object
# END_DATE                              datetime64[ns]
# END_HOURMIN24                                 object
# SAMPLE_DEPTH_IN_METERS                       float64
# Seasonal_Lake_Grade_RESULT                   float64
# Seasonal_Lake_Grade_QUALIFIER                 object
# Seasonal_Lake_Grade_Units                     object
# Physical_Condition_RESULT                    float64
# Physical_Condition_QUALIFIER                  object
# Physical_Condition_Units                      object
# Recreational_Suitability_RESULT              float64
# Recreational_Suitability_QUALIFIER            object
# Recreational_Suitability_Units                object
# Secchi_Depth_RESULT_SIGN                      object
# Secchi_Depth_RESULT                          float64
# Secchi_Depth_QUALIFIER                        object
# Secchi_Depth_Units                            object
# Total_Phosphorus_RESULT_SIGN                  object
# Total_Phosphorus_RESULT                      float64
# Total_Phosphorus_QUALIFIER                    object
# Total_Phosphorus_Units                        object
# longitude                                     object
# latitude                                      object
# dtype: object

# %% [markdown]
# #### Problem 3
#
# Now we want to read in the file `Parcel_Lake_Monitoring_Site_Xref.txt`, which is as cross-reference (Xref) file that is used to make the bridge between the parcel data and the lakes data.
#
# 1. Use `!head` to inspect the file and determine the details of it's format (header?, sep=?, etc.).
# 2. Read the file using `pandas`.

# %%
# !head ../MinneMUDACProject1/MinneMUDAC_raw_files/Parcel_Lake_Monitoring_Site_Xref.txt
# Out:
# Parcel_PIN	Monit_MAP_CODE1	Monit_SITE_CODE	Monit_LAKE_SITE	Distance_Parcel_Monitoring_Site_meters	Lake_Hydroid	Distance_Parcel_Lake_meters	centroid_long	centroid_lat	Parcel_pkey
# 	19007900-01	19007900	1	2815.4927104148851	110517277058	2571.5267922258381	-93.11451	44.94283	2163034
# 	19007900-01	19007900	1	2753.4746875312162	110517277058	2515.3738022144425	-93.11539	44.94234	2163035
# 	19007900-01	19007900	1	2748.8106650822624	110517277058	2511.9249588634261	-93.11556	44.94231	2163036
# 	19007900-01	19007900	1	2738.7500558227048	110517277058	2502.9916401143814	-93.11572	44.94223	2163037
# 	19007900-01	19007900	1	2700.5414124735426	110517277058	2465.2062339003005	-93.1158	44.94189	2163038
# 	19007900-01	19007900	1	2890.2197211400312	110517277058	2631.4612562849106	-93.11218	44.94325	2163039
# 	19007900-01	19007900	1	3338.9566080000855	110517277058	3074.8658002505599	-93.11036	44.94711	2163040
# 	19007900-01	19007900	1	3338.129273460172	110517277058	3074.6709497432862	-93.11048	44.94712	2163041
# 	19007900-01	19007900	1	3304.2646291849906	110517277058	3040.0914556198632	-93.11042	44.9468	2163042

# %%
xref_iter = pd.read_csv('../MinneMUDACProject1/MinneMUDAC_raw_files/Parcel_Lake_Monitoring_Site_Xref.txt',
                      header =0, sep= '\t')
xref_iter.centroid_lat = round(xref_iter.centroid_lat, 5)
xref_iter.centroid_long = round(xref_iter.centroid_long, 5)
xref_iter.head()
# Out:
#    Parcel_PIN Monit_MAP_CODE1  Monit_SITE_CODE  Monit_LAKE_SITE  \
# 0         NaN     19007900-01         19007900                1
# 1         NaN     19007900-01         19007900                1
# 2         NaN     19007900-01         19007900                1
# 3         NaN     19007900-01         19007900                1
# 4         NaN     19007900-01         19007900                1
#
#    Distance_Parcel_Monitoring_Site_meters  Lake_Hydroid  \
# 0                             2815.492710  110517277058
# 1                             2753.474688  110517277058
# 2                             2748.810665  110517277058
# 3                             2738.750056  110517277058
# 4                             2700.541412  110517277058
#
#    Distance_Parcel_Lake_meters  centroid_long  centroid_lat  Parcel_pkey
# 0                  2571.526792      -93.11451      44.94283      2163034
# 1                  2515.373802      -93.11539      44.94234      2163035
# 2                  2511.924959      -93.11556      44.94231      2163036
# 3                  2502.991640      -93.11572      44.94223      2163037
# 4                  2465.206234      -93.11580      44.94189      2163038

# %%
xref_iter.centroid_lat = xref_iter.centroid_lat.astype(str)
xref_iter.centroid_long = xref_iter.centroid_long.astype(str)
xref_iter.dtypes
# Out:
# Parcel_PIN                                float64
# Monit_MAP_CODE1                            object
# Monit_SITE_CODE                             int64
# Monit_LAKE_SITE                             int64
# Distance_Parcel_Monitoring_Site_meters    float64
# Lake_Hydroid                                int64
# Distance_Parcel_Lake_meters               float64
# centroid_long                              object
# centroid_lat                               object
# Parcel_pkey                                 int64
# dtype: object

# %% [markdown]
# #### Problem 4
#
# We need to find a way to link these two files.  Inspect the columns for each file and suggest a column from each that can be used to make a link.

# %% [markdown]
# We could use the DNR_ID_Site_Number column from the lakes data set and the Monit_MAP_CODE1 column from the xref data

# %% [markdown]
# #### Problem 5
#
# Let's investigate these columns and use `set`s to explore.
#
# 1. For each file, make a `set` of the contents of the respective file.
# 2. Explore the relationship between the files using `intersection` and `difference`.
#
# What did you learn about these columns in regards to using them as a link between the files?  Any problems?

# %%
mces_lakes = set(mces_lakes_iter.DNR_ID_Site_Number)
len(mces_lakes)
# Out:
# 349

# %%
xref = set(xref_iter.Monit_MAP_CODE1)
len(xref)
# Out:
# 440

# %%
mces_xref = mces_lakes.intersection(xref)
len(mces_xref)
# Out:
# 344

# %%
mces_xref_diff = mces_lakes.difference(xref)
len(mces_xref_diff)
# Out:
# 5

# %%
mces_xref
# Out:
# {'02000300-01',
#  '02000400-01',
#  '02000500-01',
#  '02000600-01',
#  '02000700-01',
#  '02000900-01',
#  '02001300-01',
#  '02002200-01',
#  '02002600-01',
#  '02003400-01',
#  '02004200-01',
#  '02004500-01',
#  '02005300-01',
#  '02007200-01',
#  '02007501-01',
#  '02007900-01',
#  '02008000-01',
#  '02008100-01',
#  '02008400-01',
#  '02009100-01',
#  '02013000-01',
#  '02013300-01',
#  '02058500-01',
#  '02065400-01',
#  '10000200-01',
#  '10000200-02',
#  '10000500-01',
#  '10000600-01',
#  '10000700-01',
#  '10000900-01',
#  '10000900-02',
#  '10001000-01',
#  '10001100-01',
#  '10001200-01',
#  '10001300-01',
#  '10001400-01',
#  '10001500-01',
#  '10001800-01',
#  '10001900-01',
#  '10002800-01',
#  '10002900-01',
#  '10003100-01',
#  '10004100-01',
#  '10004200-01',
# #### Problem 6
#
# Use group_by/aggregation to investigate any missing keys.  Suggest some options for how we might proceed.

# %%
from dfply import *
(mces_lakes_iter
 >> select(X.DNR_ID_Site_Number, X.LAKE_NAME)
 >> group_by(X.DNR_ID_Site_Number, X.LAKE_NAME)
 >> summarise(cnt = n(X.DNR_ID_Site_Number))
 >> filter_by(~X.DNR_ID_Site_Number.isin(mces_xref)))
# Out:
#             LAKE_NAME DNR_ID_Site_Number  cnt
# 80        Fourth Lake        13002200-01   10
# 84   Big Comfort Lake        13005300-01  264
# 88         Lendt Lake        13010300-01   12
# 203      Sanborn Lake        40002700-01    3
# 230         Cody Lake        66006100-01    4

# %%
probs_keys = (mces_lakes_iter
                 >>filter_by(~X.DNR_ID_Site_Number.isin(mces_xref)))

# %% [markdown]
# > We don't want to include these keys continuing now from this point

# %% [markdown]
# #### Problem 7
#
# Use select/group_by/aggregation to reduce the lakes table to a table with one row per lake that contains the lake name and corresponding code.

# %%
(mces_lakes_iter
 >> select(X.LAKE_NAME, X.DNR_ID_Site_Number)
 >> group_by(X.LAKE_NAME, X.DNR_ID_Site_Number)
 >> summarise(cnt = n(X.LAKE_NAME))
 >> filter_by(X.DNR_ID_Site_Number.isin(mces_xref))
 )
# Out:
#     DNR_ID_Site_Number                   LAKE_NAME   cnt
# 0          82010200-01                  Acorn Lake    35
# 1          82028700-01                  Alice Lake    12
# 2          19002100-01              Alimagnet Lake   229
# 3          19009400-01               Anderson Pond    33
# 4          10001200-01                    Ann Lake    83
# 5          27015300-01                Ardmore Lake    45
# 6          82011602-01              Armstrong Lake   192
# 7          10006300-01             Assumption Lake     2
# 8          10004401-01                 Auburn Lake   333
# 9          10002800-01                    Aue Lake     1
# 10         62000200-01             Bald Eagle Lake   156
# 11         02001300-01                Baldwin Lake     2
# 12         82007600-01                 Barker Lake    85
# 13         10010900-01                 Barnes Lake     1
# 14         82003500-01                   Bass Lake     9
# 15         82012300-01                   Bass Lake   478
# 16         82009100-01           Battle Creek Lake    55
# 17         10001900-01                Bavaria Lake   524
# 18         82001100-01                    Bay Pond    85
# 19         10006900-01                 Benton Lake   193
# 20         82012000-01                   Benz Lake   159
# 21         10010300-01               Berliner Lake     1
# 22         82039900-01                 Beutel Pond    15
# 23         82004900-01          Big Carnelian Lake   312
# 25         82005204-01             Big Marine Lake   372
# 26         10024900-01              Big Woods Lake    13
# 27         13004200-01                  Birch Lake    32
# 28         62002400-01                  Birch Lake     2
# 29         82005400-01                   Bone Lake   369
# 30         10011000-01                  Brand Lake     1
# ..                 ...                         ...   ...
# 319        70012001-01                  Thole Lake   184
# 320        19006700-01                 Thomas Lake     2
# 321        10010800-01                  Tiger Lake     1
# 322        82003600-01                 Turtle Lake   136
# 323        27004201-01                   Twin Lake  1001
# 324        70007200-01            Upper Prior Lake   341
# 325        62003801-01                Vadnais Lake    15
# 326        62007100-01              Valentine Lake   104
# 327        19034800-01                 Valley Lake   271
# 328        10001500-01               Virginia Lake    83
# 329        62008200-01                Wabasso Lake    77
# 330        10005900-01                Waconia Lake   435
# 331        10004800-01              Wasserman Lake   402
# 332        27011700-01                 Weaver Lake   178
# 333        82011900-01                  Weber Pond    36
# 334        82004400-01              West Boot Lake   169
# 335        82048800-01  West Lakeland Storage Site    32
# 336        27071100-01               Westwood Lake   168
# 337        27018401-01              Whaletail Lake   189
# 338        82016700-01             White Bear Lake    46
# 339        82007200-01             White Rock Lake   130
# 340        82009002-01                 Wilmes Lake   282
# 341        27008200-01                Windsor Lake    27
# 342        27009100-01                   Wing Lake   111
# 343        10006600-01                Winkler Lake   121
# 344        27015700-01               Wolsfeld Lake     4
# 345        19002400-01                   Wood Lake   264
# 346        82013200-01               Woodpile Lake   121
# 347        10010500-01          Young America Lake     1
# 348        10004100-01                 Zumbra Lake    81
#
# [344 rows x 3 columns]

# %% [markdown]
# #### Problem 8
#
# Make a `dict` that with the lake id as the key and the lake name as the value.  You will want to zip the columns from the last table together and use a `dict` comp.

# %%
LakeID_to_LakName ={LakID: Name for (LakID, Name) in zip(mces_lakes_iter.DNR_ID_Site_Number, mces_lakes_iter.LAKE_NAME)}
LakeID_to_LakName
# Out:
# {'82010200-01': 'Acorn Lake',
#  '82028700-01': 'Alice Lake',
#  '19002100-01': 'Alimagnet Lake',
#  '19009400-01': 'Anderson Pond',
#  '10001200-01': 'Ann Lake',
#  '27015300-01': 'Ardmore Lake',
#  '82011602-01': 'Armstrong Lake',
#  '10006300-01': 'Assumption Lake',
#  '10004401-01': 'Auburn Lake',
#  '10002800-01': 'Aue Lake',
#  '62000200-01': 'Bald Eagle Lake',
#  '02001300-01': 'Baldwin Lake',
#  '82007600-01': 'Barker Lake',
#  '10010900-01': 'Barnes Lake',
#  '82003500-01': 'Bass Lake',
#  '82012300-01': 'Bass Lake',
#  '82009100-01': 'Battle Creek Lake',
#  '10001900-01': 'Bavaria Lake',
#  '82001100-01': 'Bay Pond',
#  '10006900-01': 'Benton Lake',
#  '82012000-01': 'Benz Lake',
#  '10010300-01': 'Berliner Lake',
#  '82039900-01': 'Beutel Pond',
#  '82004900-01': 'Big Carnelian Lake',
#  '13005300-01': 'Big Comfort Lake',
#  '82005204-01': 'Big Marine Lake',
#  '10024900-01': 'Big Woods Lake',
#  '13004200-01': 'Birch Lake',
#  '62002400-01': 'Birch Lake',
#  '82005400-01': 'Bone Lake',
#  '10011000-01': 'Brand Lake',
#  '10010700-01': 'Braunworth Lake',
#  '82030800-01': 'Brick Pond',
#  '10022500-01': 'Brickyard Clayhole Lake',
#  '27006700-01': 'Bryant Lake',
#  '70006500-01': 'Buck Lake',
#  '10008400-01': 'Burandt Lake',
#  '27004700-01': 'Bush Lake',
#  '19000600-01': 'Byllesby Lake',
#  '19000600-03': 'Byllesby Lake',
#  '27003100-01': 'Calhoun Lake',
#  '10012700-01': 'Campbell Lake',
#  '82036500-01': 'Capaul Pond',
#  '82001700-01': 'Carol Lake',
#  '82016600-01': 'Carver Lake',
#  '70001800-01': 'Cates Lake',
#  '27011900-01': 'Cedar Island Lake',
#  '70009100-01': 'Cedar Lake',
#  '19007500-01': 'Schultz Lake',
#  '10001800-01': 'Schutz Lake',
#  '19019800-01': 'Scout Lake',
#  '82005300-01': 'Sea Lake',
#  '99002487-01': 'Sed Basin Adj to Valley Lake',
#  '19009500-01': 'Seidl Lake',
#  '27008902-01': 'Shady Oak Lake',
#  '27008600-02': 'Shavers Lake',
#  '82016200-01': 'Shields Lake',
#  '62000100-01': 'Silver Lake',
#  '19003700-01': 'Simley Lake',
#  '27007300-01': 'Smetana Lake',
#  '62007300-01': 'Snail Lake',
#  '27066100-01': 'South Oak Lake',
#  '27064500-01': 'South Rice Lake',
#  '82015100-01': 'South School Section Lake',
#  '82001900-01': 'South Twin Lake',
#  '70005400-01': 'Spring Lake',
#  '82004600-01': 'Square Lake',
#  '10001100-01': 'St. Joe Lake',
#  '82002800-01': 'Staples Lake',
#  '27007800-01': 'Staring Lake',
#  '10004500-01': 'Stieger Lake',
#  '27063400-01': 'Success Lake',
#  '62002800-01': 'Sucker Lake',
#  '02008000-01': 'Sullivan Lake',
#  '19005000-01': 'Sunfish Lake',
#  '82010700-01': 'Sunfish Lake',
#  '82013300-01': 'Sunnybrook Lake',
#  '82015300-01': 'Sunset Lake',
#  '19045100-01': 'Sunset Pond',
#  '10001300-01': 'Susan Lake',
#  '10009500-01': 'Swede Lake',
#  '27003501-01': 'Sweeney Lake',
#  '27017100-01': 'Sylvan Lake',
#  '10001000-01': 'Tamarack Lake',
#  '82011500-01': 'Tanners Lake',
#  '82003100-01': 'Terrapin Lake',
#  '13002400-01': 'Third Lake',
#  '70012001-01': 'Thole Lake',
#  '19006700-01': 'Thomas Lake',
#  '10010800-01': 'Tiger Lake',
#  '82003600-01': 'Turtle Lake',
#  '27004201-01': 'Twin Lake',
#  '70007200-01': 'Upper Prior Lake',
#  '62003801-01': 'Vadnais Lake',
#  '62007100-01': 'Valentine Lake',
#  '19034800-01': 'Valley Lake',
#  '10001500-01': 'Virginia Lake',
#  '62008200-01': 'Wabasso Lake',
#  '10005900-01': 'Waconia Lake',
#  '10004800-01': 'Wasserman Lake',
#  '27011700-01': 'Weaver Lake',
#  '82011900-01': 'Weber Pond',
#  '82004400-01': 'West Boot Lake',
#  '82048800-01': 'West Lakeland Storage Site',
#  '27071100-01': 'Westwood Lake',
#  '27018401-01': 'Whaletail Lake',
#  '82016700-01': 'White Bear Lake',
#  '82007200-01': 'White Rock Lake',
#  '82009002-01': 'Wilmes Lake',
#  '27008200-01': 'Windsor Lake',
#  '27009100-01': 'Wing Lake',
#  '10006600-01': 'Winkler Lake',
#  '27015700-01': 'Wolsfeld Lake',
#  '19002400-01': 'Wood Lake',
#  '82013200-01': 'Woodpile Lake',
#  '10010500-01': 'Young America Lake',
#  '10004100-01': 'Zumbra Lake'}

# %% [markdown]
# #### Problem 9
#
# Now we want to link the Xref file to the parcel files, which will be done by matching the latitudes and longitudes in the parcel files to `xref.latitude` and `xref.longitude`.  First, let's investigate the relationship between these columns.
#
# 1. Make a `set` of lat/long tuples from the Xref file.<br>
# 2. Make a list of lat/long sets, one for each chunk of each parcel file for 2004+.  Do this with a list comprehension that uses double for clauses.
# 3. Reduce the sets in the list to one set using the union to combine sets.
# 4. Investigate the relationship between the lat/long pairs from the two types of files.  Are there any missing on either side? How many?
#
# Discuss what you have learned and suggest how we might proceed.

# %%
xref_iter.dtypes
# Out:
# Parcel_PIN                                float64
# Monit_MAP_CODE1                            object
# Monit_SITE_CODE                             int64
# Monit_LAKE_SITE                             int64
# Distance_Parcel_Monitoring_Site_meters    float64
# Lake_Hydroid                                int64
# Distance_Parcel_Lake_meters               float64
# centroid_long                              object
# centroid_lat                               object
# Parcel_pkey                                 int64
# dtype: object

# %%
xref_iter.head()
# Out:
#    Parcel_PIN Monit_MAP_CODE1  Monit_SITE_CODE  Monit_LAKE_SITE  \
# 0         NaN     19007900-01         19007900                1
# 1         NaN     19007900-01         19007900                1
# 2         NaN     19007900-01         19007900                1
# 3         NaN     19007900-01         19007900                1
# 4         NaN     19007900-01         19007900                1
#
#    Distance_Parcel_Monitoring_Site_meters  Lake_Hydroid  \
# 0                             2815.492710  110517277058
# 1                             2753.474688  110517277058
# 2                             2748.810665  110517277058
# 3                             2738.750056  110517277058
# 4                             2700.541412  110517277058
#
#    Distance_Parcel_Lake_meters centroid_long centroid_lat  Parcel_pkey
# 0                  2571.526792     -93.11451     44.94283      2163034
# 1                  2515.373802     -93.11539     44.94234      2163035
# 2                  2511.924959     -93.11556     44.94231      2163036
# 3                  2502.991640     -93.11572     44.94223      2163037
# 4                  2465.206234      -93.1158     44.94189      2163038

# %%
len(set(xref_iter.centroid_long))
# Out:
# 117327

# %%
len(set(xref_iter.centroid_lat))
# Out:
# 90174

# %%
xref_latlong =set(zip(xref_iter.centroid_lat, xref_iter.centroid_long))
xref_latlong
# Out:
# {('44.86591', '-93.29691'),
#  ('44.92084', '-93.25076'),
#  ('44.96712', '-93.59526'),
#  ('45.17223', '-93.2866'),
#  ('44.87211', '-93.2596'),
#  ('44.83866', '-92.79824'),
#  ('45.01388', '-93.14783'),
#  ('45.0849', '-93.01282'),
#  ('44.81505', '-93.13622'),
#  ('44.92669', '-93.41091'),
#  ('44.87388', '-93.35771'),
#  ('44.81288', '-93.38138'),
#  ('45.07178', '-93.28489'),
#  ('44.71481', '-93.41465'),
#  ('44.93189', '-92.92926'),
#  ('45.03069', '-93.43154'),
#  ('44.76052', '-93.31429'),
#  ('44.81298', '-92.91482'),
#  ('45.04474', '-93.39431'),
#  ('44.93668', '-93.42356'),
#  ('44.92621', '-93.54245'),
#  ('44.80075', '-93.16545'),
#  ('45.03389', '-93.23108'),
#  ('44.7723', '-93.26114'),
#  ('44.95502', '-93.43313'),
#  ('44.99115', '-93.30009'),
#  ('44.97945', '-93.57124'),
#  ('44.57179', '-93.56368'),
#  ('44.88328', '-93.61915'),
#  ('44.97125', '-93.30798'),
#  ('44.89489', '-93.35908'),
#  ('44.92616', '-93.5253'),
#  ('45.32025', '-93.15113'),
#  ('45.14234', '-93.24952'),
#  ('45.17789', '-93.39628'),
#  ('44.9322', '-93.21622'),
#  ('45.11678', '-93.31114'),
#  ('44.78617', '-93.51794'),
#  ('45.09956', '-93.28565'),
#  ('45.10507', '-93.3259'),
#  ('44.85689', '-93.32082'),
#  ('45.12883', '-93.31249'),
#  ('45.01562', '-93.40605'),
#  ('44.76259', '-93.22024'),
#  ('44.84278', '-93.65998'),
#  ('45.10772', '-93.13319'),
#  ('45.13809', '-93.25775'),
#  ('44.94471', '-92.97886'),
#  ('44.99596', '-93.34635'),
#  ('45.38427', '-93.05407'),
#  ('44.90978', '-93.10371'),
#  ('44.8346', '-93.03897'),
#  ('44.9596', '-93.12987'),
#  ('45.02724', '-93.47399'),
#  ('45.26473', '-93.16892'),
#  ('45.12132', '-93.2539'),
#  ('45.05863', '-92.82128'),
#  ('44.93257', '-93.22232'),
#  ...}

# %%
from glob import glob
parcel_files = glob('../MinneMUDACProject1/MinneMUDAC_raw_files/*_metro_tax_parcels.txt')
parcel_files = [file for file in parcel_files if not '2002' in file and not '2003' in file and not '2015' in file]
#parcel_files = [file for file in parcel_files if not '2003' in file]
#parcel_files = [file for file in parcel_files if not '2015' in file]
parcel_files
# Out:
# ['../MinneMUDACProject1/MinneMUDAC_raw_files/2004_metro_tax_parcels.txt',
#  '../MinneMUDACProject1/MinneMUDAC_raw_files/2005_metro_tax_parcels.txt',
#  '../MinneMUDACProject1/MinneMUDAC_raw_files/2006_metro_tax_parcels.txt',
#  '../MinneMUDACProject1/MinneMUDAC_raw_files/2007_metro_tax_parcels.txt',
#  '../MinneMUDACProject1/MinneMUDAC_raw_files/2008_metro_tax_parcels.txt',
#  '../MinneMUDACProject1/MinneMUDAC_raw_files/2009_metro_tax_parcels.txt',
#  '../MinneMUDACProject1/MinneMUDAC_raw_files/2010_metro_tax_parcels.txt',
#  '../MinneMUDACProject1/MinneMUDAC_raw_files/2011_metro_tax_parcels.txt',
#  '../MinneMUDACProject1/MinneMUDAC_raw_files/2012_metro_tax_parcels.txt',
#  '../MinneMUDACProject1/MinneMUDAC_raw_files/2013_metro_tax_parcels.txt',
#  '../MinneMUDACProject1/MinneMUDAC_raw_files/2014_metro_tax_parcels.txt']

# %%
set_latlong = set([])
dtypes = {'centroid_lat' : str, 'centroid_long': str}
for file in parcel_files:
    print('starting to process file {0}\n\n'.format(file))
    for i,ch in enumerate(pd.read_csv(file, chunksize=500000, sep= '|', engine = 'python', dtype = dtypes)):
        print('processing chunk {0}'.format(i))
        set_latlong = set_latlong.union(set(zip(ch.centroid_lat, ch.centroid_long)))
# Out:
# starting to process file ../MinneMUDACProject1/MinneMUDAC_raw_files/2004_metro_tax_parcels.txt
#
#
# processing chunk 0
# processing chunk 1
# processing chunk 2
# processing chunk 3
# starting to process file ../MinneMUDACProject1/MinneMUDAC_raw_files/2005_metro_tax_parcels.txt
#
#
# processing chunk 0
# processing chunk 1
# processing chunk 2
# processing chunk 3
# starting to process file ../MinneMUDACProject1/MinneMUDAC_raw_files/2006_metro_tax_parcels.txt
#
#
# processing chunk 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-f4c6a47f2c36> in <module>()
#       3 for file in parcel_files:
#       4     print('starting to process file {0}\n\n'.format(file))
# ----> 5     for i,ch in enumerate(pd.read_csv(file, chunksize=500000, sep= '|', engine = 'python', dtype = dtypes)):
#       6         print('processing chunk {0}'.format(i))
#       7         set_latlong = set_latlong.union(set(zip(ch.centroid_lat, ch.centroid_long)))
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/pandas/io/parsers.py in __next__(self)
#    1113     def __next__(self):
#    1114         try:
# -> 1115             return self.get_chunk()
#    1116         except StopIteration:
#    1117             self.close()
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/pandas/io/parsers.py in get_chunk(self, size)
#    1171                 raise StopIteration
#    1172             size = min(size, self.nrows - self._currow)
# -> 1173         return self.read(nrows=size)
#    1174
#    1175
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1137     def read(self, nrows=None):
#    1138         nrows = _validate_integer('nrows', nrows)
# -> 1139         ret = self._engine.read(nrows)
#    1140
#    1141         # May alter columns / col_dict
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, rows)
#    2419         columns, data = self._do_date_conversions(columns, data)
#    2420
# -> 2421         data = self._convert_data(data)
#    2422         index, columns = self._make_index(data, alldata, columns, indexnamerow)
#    2423
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/pandas/io/parsers.py in _convert_data(self, data)
#    2485         return self._convert_to_ndarrays(data, clean_na_values,
#    2486                                          clean_na_fvalues, self.verbose,
# -> 2487                                          clean_conv, clean_dtypes)
#    2488
#    2489     def _infer_columns(self):
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/pandas/io/parsers.py in _convert_to_ndarrays(self, dct, na_values, na_fvalues, verbose, converters, dtypes)
#    1688                 cvals, na_count = self._infer_types(
#    1689                     values, set(col_na_values) | col_na_fvalues,
# -> 1690                     try_num_bool)
#    1691
#    1692                 # type specified in dtype param or cast_type is an EA
#
# ~/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/pandas/io/parsers.py in _infer_types(self, values, na_values, try_num_bool)
#    1738         if try_num_bool:
#    1739             try:
# -> 1740                 result = lib.maybe_convert_numeric(values, na_values, False)
#    1741                 na_count = isna(result).sum()
#    1742             except Exception:
#
# KeyboardInterrupt:

# %%
len(set_latlong)
# Out:
# 2209539

# %%
lake_xref_latlong = set_latlong.union(xref_latlong)
len(lake_xref_latlong)
# Out:
# 2688767

# %%
xref_lakes_latlong2 = set_latlong.intersection(xref_latlong)
len(xref_lakes_latlong2)
# Out:
# 2209538

# %%
lake_xref_latlong3 = set_latlong.difference(xref_latlong)
len(lake_xref_latlong3)
# Out:
# 1

# %% [markdown]
# > There is exactly 1 that doesn't match up

# %% [markdown]
# #### Problem 10
#
# Use select/group_by/aggregation to reduce the lakes table to a table with one row per lake that contains latitude, longitude, and the lake ID code.

# %%
from toolz import first
first_chunk = first(set_latlong)
first_chunk
# Out:
# ('44.77965', '-93.26173')

# %%
mces_lakes_iter.columns
# Out:
# Index(['PROJECT_ID', 'DATA_SET_TITLE', 'LAKE_NAME', 'CITY', 'COUNTY',
#        'DNR_ID_Site_Number', 'MAJOR_WATERSHED', 'WATER_PLANNING_AUTHORITY',
#        'LAKE_SITE_NUMBER', 'START_DATE', 'START_HOURMIN24', 'END_DATE',
#        'END_HOURMIN24', 'SAMPLE_DEPTH_IN_METERS', 'Seasonal_Lake_Grade_RESULT',
#        'Seasonal_Lake_Grade_QUALIFIER', 'Seasonal_Lake_Grade_Units',
#        'Physical_Condition_RESULT', 'Physical_Condition_QUALIFIER',
#        'Physical_Condition_Units', 'Recreational_Suitability_RESULT',
#        'Recreational_Suitability_QUALIFIER', 'Recreational_Suitability_Units',
#        'Secchi_Depth_RESULT_SIGN', 'Secchi_Depth_RESULT',
#        'Secchi_Depth_QUALIFIER', 'Secchi_Depth_Units',
#        'Total_Phosphorus_RESULT_SIGN', 'Total_Phosphorus_RESULT',
#        'Total_Phosphorus_QUALIFIER', 'Total_Phosphorus_Units', 'longitude',
#        'latitude'],
#       dtype='object')

# %%
mces_lakes_iter.dtypes
# Out:
# PROJECT_ID                                     int64
# DATA_SET_TITLE                                object
# LAKE_NAME                                     object
# CITY                                          object
# COUNTY                                        object
# DNR_ID_Site_Number                            object
# MAJOR_WATERSHED                               object
# WATER_PLANNING_AUTHORITY                      object
# LAKE_SITE_NUMBER                               int64
# START_DATE                            datetime64[ns]
# START_HOURMIN24                               object
# END_DATE                              datetime64[ns]
# END_HOURMIN24                                 object
# SAMPLE_DEPTH_IN_METERS                       float64
# Seasonal_Lake_Grade_RESULT                   float64
# Seasonal_Lake_Grade_QUALIFIER                 object
# Seasonal_Lake_Grade_Units                     object
# Physical_Condition_RESULT                    float64
# Physical_Condition_QUALIFIER                  object
# Physical_Condition_Units                      object
# Recreational_Suitability_RESULT              float64
# Recreational_Suitability_QUALIFIER            object
# Recreational_Suitability_Units                object
# Secchi_Depth_RESULT_SIGN                      object
# Secchi_Depth_RESULT                          float64
# Secchi_Depth_QUALIFIER                        object
# Secchi_Depth_Units                            object
# Total_Phosphorus_RESULT_SIGN                  object
# Total_Phosphorus_RESULT                      float64
# Total_Phosphorus_QUALIFIER                    object
# Total_Phosphorus_Units                        object
# longitude                                     object
# latitude                                      object
# dtype: object

# %%
(mces_lakes_iter
 #>> mutate(latlong = list(zip(X.latitude, X.longitude)))
 >> select((X.latitude, X.longitude), X.DNR_ID_Site_Number)
 >> group_by(X.DNR_ID_Site_Number, X.latitude, X.longitude)
 >> summarise(cnt = n(X.DNR_ID_Site_Number))
 )
# Out:
#      longitude  latitude DNR_ID_Site_Number  cnt
# 0    -93.03887  45.12456        02000300-01   12
# 1    -93.05837  45.17785        02000400-01  249
# 2    -93.08905   45.1764        02000500-01  226
# 3    -93.07493  45.16261        02000600-01  144
# 4    -93.11033  45.16845        02000700-01   70
# 5    -93.09866  45.15293        02000900-01  102
# 6    -93.13615   45.1387        02001300-01    2
# 7    -93.09488  45.36692        02002200-01  154
# 8    -93.11468  45.35144        02002600-01  166
# 9     -93.0834  45.38582        02003400-01   64
# 10   -93.13715  45.31767        02004200-01   75
# 11   -93.15271  45.13923        02004500-01  276
# 12   -93.22068  45.25728        02005300-01   80
# 13   -93.24047  45.12336        02007200-01  100
# 14   -93.24417  45.07589        02007501-01   30
# 15    -93.2331   45.0589        02007900-01  124
# 16   -93.25384  45.06228        02008000-01  141
# 17   -93.23224  45.03685        02008100-01   20
# 18   -93.34158  45.20836        02008400-01  143
# 19   -93.33582  45.35716        02009100-01  189
# 20   -93.44717  45.33766        02013000-01   31
# 21   -93.50292  45.33357        02013300-01  182
# 22   -93.15409  45.17253        02058500-01   92
# 23   -93.30036  45.14037        02065400-01  228
# 24   -93.51695  44.83469        10000200-01  168
# 25    -93.5239  44.83466        10000200-02   14
# 26   -93.52394  44.83938        10000200-02  539
# 27   -93.59003  44.78927        10000500-01  296
# 28   -93.52556  44.86977        10000600-01  193
# 29   -93.55827  44.87705        10000700-01   87
# ..         ...       ...                ...  ...
# 338  -92.96992  45.05206        82013401-01   55
# 339  -92.97449  45.04336        82013500-01   55
# 340  -92.97808  44.82295        82013700-01   71
# 341  -92.97797  45.12243        82013700-01  373
# 342  -92.96877  45.17924        82014000-01  105
# 343  -92.98956  45.15763        82014700-01    3
# 344  -92.91253  45.15178        82014800-01   90
# 345  -92.90602  45.14138        82015100-01  217
# 346  -92.94157  45.13527        82015300-01  295
# 347  -92.96664  45.12242        82015900-01    5
# 348  -92.96655  45.28221        82015900-01  884
# 349  -92.94486  45.25287        82016200-01  256
# 350  -93.00001  45.26004        82016300-01  294
# 351  -92.97989  44.90599        82016600-01  143
# 352   -92.9829  45.07498        82016700-01   46
# 353  -92.76043  45.21804        82028700-01   12
# 354  -92.83846  45.14368        82030100-01   48
# 355  -92.84687  45.05653        82030500-01   79
# 356  -92.81844    45.043        82030800-01   45
# 357  -92.86729  45.01621        82031300-01   84
# 358  -92.90761  45.12373        82031800-01   91
# 359  -92.89173  45.09536        82033400-01  252
# 360  -92.94208  45.03805        82036500-01   29
# 361  -92.90855  45.03273        82036800-01  176
# 362  -92.92604  44.99381        82039900-01   15
# 363  -92.87497  44.98917        82046200-01   36
# 364  -92.82652  44.96768        82048200-01   31
# 365  -92.84742   44.9634        82048800-01   32
# 366  -92.81688  44.95345        82051400-01  116
# 367  -93.21132  44.71558        99002487-01   58
#
# [368 rows x 4 columns]

# %% [markdown]
# HINT FOR PROJECT IN CLASS:
#     with open('new.csv', 'w' ) as out:
#     lines = ','.join(lat, long,code) for (lat,long), code in lat_long_to_code.items() -list comp
#     for line in lines
#         print(line,file =out)
#
# that was the purely python way
# the pandas way is
# df_to_csv('new.csv', index=False)
#
# other things wanted dataframe
# pd.DataFrame({'lat': list comp,
#               'long': list comp,
#               'code': list comp })

# %%
summarise?

# %% [markdown]
# #### Problem 11
#
# Make a `dict` that with the (lat, long) tuple as the key and the lake code as the value.  You will want to zip the columns from the last table together and use a `dict` comp.

# %%
latlong_ID_dict = {zip(mces_lakes_iter.latitude, mces_lakes_iter.longitude) : ID for (zip(mces_lakes_iter.latitude, mces_lakes_iter.longitude), ID) in }
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-297d41e29dec> in <module>()
# ----> 1 ID_latlong ={(lat, long): ID for ((lat, long), ID) in zip(mces_lakes_iter.latitude, mces_lakes_iter.longitude, mces_lakes_iter.DNR_ID_Site_Number)}
#       2 ID_latlong
#
# <ipython-input-71-297d41e29dec> in <dictcomp>(.0)
# ----> 1 ID_latlong ={(lat, long): ID for ((lat, long), ID) in zip(mces_lakes_iter.latitude, mces_lakes_iter.longitude, mces_lakes_iter.DNR_ID_Site_Number)}
#       2 ID_latlong
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# #### Problem 12
#
# Now make a `dict` that combines the last two `dict`s into a single `dict` that translates the lat/long tuple into a lake name.

# %%
# Your code here
